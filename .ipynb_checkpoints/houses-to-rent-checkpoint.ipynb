# %% [markdown]
# # Dataset de imóveis para aluguel em Fortaleza
#
# Neste trabalho, vamos explorar dados de imóveis para aluguel na cidade de Fortaleza presentes no site do [viva real](https://www.vivareal.com.br/aluguel/ceara/fortaleza/) e no [zap imoveis](https://www.zapimoveis.com.br/aluguel/imoveis/ce+fortaleza/?transacao=Aluguel&tipo=Im%C3%B3vel%20usado&pagina=1&onde=,Cear%C3%A1,Fortaleza,,,,,city,BR%3ECeara%3ENULL%3EFortaleza,-3.73272,-38.527013)
#
# O objetivo é a partir dos dados presentes nestes sites, unir as informações em um único dataset com todos os imóveis para aluguel.

# %% [markdown]
# A princípio, a estratégia para obter os dados seria utilizar *scraping*, raspando as páginas html desses sites. Porém, ao navegar além da primeira página em ambos os sites, é possível observar que os dados de páginas subsequentes é retornado por meio de chamadas *HTTP* para uma API pública dessas plataformas. Com base nisso, foi possível replicar as requisições usadas pelas páginas *web*, evitando a necessidade de raspar o html das páginas.

# %% [markdown]
# # Fluxo de processamento dos dados
#
# Com base nas observações iniciais sobre as plataformas, vamos dividir o trabalho em 3 etapas
#
# 1. Salvar dados da API e persistir em arquivos
# 2. A partir dos dados de cada requisição, montar um dataset para o VivaReal e ZapImóveis
#   - Avaliar cada dataset separadamente e realizar ajustes de modo que seja possível unir ambos os datasets
# 3. Montar dataset final, unindo os 2 datasets e aplicar sobre esse dataset tratamentos finais nos dados, como remoção de duplicações e de valores nulos

# %%
from json import dump as json_dump, load as json_load, dumps
import os
import requests
import math
from tqdm import tqdm, trange
from time import sleep
import pandas as pd
from pandas import DataFrame as df
import numpy as np

# Ensure all columns from a dataframe are shown, since the dataframes used here have like 30 columns
# this is needed
pd.set_option("display.max_columns", None)

def jsonprint(json_data):
  print(dumps(json_data, indent=2))

# %%
BASE_PATH = '.'
VIVAREAL_PATH = f'{BASE_PATH}/vivareal'
ZAP_IMOVEIS_PATH = f'{BASE_PATH}/zap-imoveis'

if not os.path.isdir(VIVAREAL_PATH):
  os.mkdir(VIVAREAL_PATH)

if not os.path.isdir(ZAP_IMOVEIS_PATH):
  os.mkdir(ZAP_IMOVEIS_PATH)

# indica se vamos reutilizar dados das requisições salvos anteriormente ou não. 
# USE_PRE_SAVED_REQUESTS = False fará com que os dados sejam obtidos novamente da API do VivaReal e ZapImóveis.
USE_PRE_SAVED_REQUESTS = True

# %% [markdown]
# ## Obtenção de dados do VivaReal e ZapImoveis
#
# Conforme exposto, vamos usar a API do VivaReal e ZapImóveis para obter os dados dos imóveis. As API's possuem paginação utilizando *offsets**, onde informamos a partir de qual ponto devem ser retornados os dados, por exemplo, os imóveis após o décimo resultado, assim, podemos pegar os 10 primeiros imóveis, depois mais 10 imóveis após os 10 primeiros, assim sucessivamente. O resultado de cada requisição é salvo em um arquivo `json`.

# %%
vivareal_headers = {'x-domain': 'www.vivareal.com.br', 'User-Agent': 'PostmanRuntime/7.29.0'}

def get_vivareal_page(page, page_size):
  current_from = page_size * page
  vivareal_url = f'https://glue-api.vivareal.com/v2/listings?addressCity=Fortaleza&addressLocationId=BR%3ECeara%3ENULL%3EFortaleza&addressNeighborhood=&addressState=Cear%C3%A1&addressCountry=Brasil&addressStreet=&addressZone=&addressPointLat=-3.73272&addressPointLon=-38.527013&business=RENTAL&facets=amenities&unitTypes=&unitSubTypes=&unitTypesV3=&usageTypes=&listingType=USED&parentId=null&categoryPage=RESULT&stamps=&includeFields=search(result(listings(listing(displayAddressType%2Camenities%2CusableAreas%2CconstructionStatus%2ClistingType%2Cdescription%2Ctitle%2CunitTypes%2CnonActivationReason%2CpropertyType%2CunitSubTypes%2Cid%2Cportal%2CparkingSpaces%2Caddress%2Csuites%2CpublicationType%2CexternalId%2Cbathrooms%2CusageTypes%2CtotalAreas%2CadvertiserId%2Cbedrooms%2CpricingInfos%2CshowPrice%2Cstatus%2CadvertiserContact%2CvideoTourLink%2CwhatsappNumber%2Cstamps)%2Caccount(id%2Cname%2ClogoUrl%2ClicenseNumber%2CshowAddress%2ClegacyVivarealId%2Cphones)%2Cmedias%2CaccountLink%2Clink))%2CtotalCount)%2Cpage%2CseasonalCampaigns%2CfullUriFragments%2Cnearby(search(result(listings(listing(displayAddressType%2Camenities%2CusableAreas%2CconstructionStatus%2ClistingType%2Cdescription%2Ctitle%2CunitTypes%2CnonActivationReason%2CpropertyType%2CunitSubTypes%2Cid%2Cportal%2CparkingSpaces%2Caddress%2Csuites%2CpublicationType%2CexternalId%2Cbathrooms%2CusageTypes%2CtotalAreas%2CadvertiserId%2Cbedrooms%2CpricingInfos%2CshowPrice%2Cstatus%2CadvertiserContact%2CvideoTourLink%2CwhatsappNumber%2Cstamps)%2Caccount(id%2Cname%2ClogoUrl%2ClicenseNumber%2CshowAddress%2ClegacyVivarealId%2Cphones)%2Cmedias%2CaccountLink%2Clink))%2CtotalCount))%2Cexpansion(search(result(listings(listing(displayAddressType%2Camenities%2CusableAreas%2CconstructionStatus%2ClistingType%2Cdescription%2Ctitle%2CunitTypes%2CnonActivationReason%2CpropertyType%2CunitSubTypes%2Cid%2Cportal%2CparkingSpaces%2Caddress%2Csuites%2CpublicationType%2CexternalId%2Cbathrooms%2CusageTypes%2CtotalAreas%2CadvertiserId%2Cbedrooms%2CpricingInfos%2CshowPrice%2Cstatus%2CadvertiserContact%2CvideoTourLink%2CwhatsappNumber%2Cstamps)%2Caccount(id%2Cname%2ClogoUrl%2ClicenseNumber%2CshowAddress%2ClegacyVivarealId%2Cphones)%2Cmedias%2CaccountLink%2Clink))%2CtotalCount))%2Caccount(id%2Cname%2ClogoUrl%2ClicenseNumber%2CshowAddress%2ClegacyVivarealId%2Cphones%2Cphones)%2Cfacets%2Cowners(search(result(listings(listing(displayAddressType%2Camenities%2CusableAreas%2CconstructionStatus%2ClistingType%2Cdescription%2Ctitle%2CunitTypes%2CnonActivationReason%2CpropertyType%2CunitSubTypes%2Cid%2Cportal%2CparkingSpaces%2Caddress%2Csuites%2CpublicationType%2CexternalId%2Cbathrooms%2CusageTypes%2CtotalAreas%2CadvertiserId%2Cbedrooms%2CpricingInfos%2CshowPrice%2Cstatus%2CadvertiserContact%2CvideoTourLink%2CwhatsappNumber%2Cstamps)%2Caccount(id%2Cname%2ClogoUrl%2ClicenseNumber%2CshowAddress%2ClegacyVivarealId%2Cphones)%2Cmedias%2CaccountLink%2Clink))%2CtotalCount))&size={page_size}&from={current_from}&q=&developmentsSize=5&__vt=&levels=CITY&ref=&pointRadius=&isPOIQuery='

  return requests.get(vivareal_url, headers = vivareal_headers)

def create_vivareal_reader(page_size):
  return lambda page: get_vivareal_page(page, page_size)

def compute_number_of_results(first_page_request):
  return first_page_request.json()["page"]["uriPagination"]["total"]

def get_number_of_pages(number_of_results, page_size):
  return math.ceil(number_of_results / page_size) + 1

def get_vivareal_file_path(page):
  return f"{VIVAREAL_PATH}/request-{page}.json"

# %%
if not USE_PRE_SAVED_REQUESTS:

  VIVAREAL_PAGE_SIZE = 100

  vivareal_reader = create_vivareal_reader(VIVAREAL_PAGE_SIZE)

  # retrieve metadata about number of pages to process
  first_page = vivareal_reader(0)

  number_of_results = compute_number_of_results(first_page)
  number_of_pages = get_number_of_pages(number_of_results, VIVAREAL_PAGE_SIZE)

  print(f"Starting to process {number_of_results} results...")
  print(f"Number of pages: {number_of_pages}")

  # save first page
  f = open(get_vivareal_file_path(0), 'w')
  json_dump(first_page.json(), f)
  f.close()

  with tqdm(total=number_of_pages) as pbar:
      pbar.update(1)

      # include final page
      for page in range(1, number_of_pages):
        sleep(1.2) # wait a bit to avoid issues about too many requests
        result = vivareal_reader(page)
        result_json = result.json()
        f = open(get_vivareal_file_path(page), 'w')
        json_dump(result_json, f)
        f.close()

        pbar.update(1)

# %%
zapimoveis_headers = {'x-domain': 'www.vivareal.com.br', 'User-Agent': 'PostmanRuntime/7.29.0'}
def get_zapimoveis_page(page, page_size):
  current_from = page_size * page
  zapimoveis_url = f'https://glue-api.zapimoveis.com.br/v2/listings?0=U&1=n&2=i&3=t&4=T&5=y&6=p&7=e&8=_&9=N&10=O&11=N&12=E&categoryPage=RESULT&business=RENTAL&listingType=USED&parentId=null&addressCountry=&addressState=Cear%C3%A1&addressCity=Fortaleza&addressZone=&addressNeighborhood=&addressStreet=&addressAccounts=&addressType=CITY&addressLocationId=BR%3ECeara%3ENULL%3EFortaleza&addressPointLat=-3.73272&addressPointLon=-38.527013&addressUrl=%2Faluguel%2Fimoveis%2Fce%2Bfortaleza%2F&size={page_size}&from={current_from}&includeFields=search(result(listings(listing(listingsCount,sourceId,displayAddressType,amenities,usableAreas,constructionStatus,listingType,description,title,stamps,createdAt,floors,unitTypes,nonActivationReason,providerId,propertyType,unitSubTypes,unitsOnTheFloor,legacyId,id,portal,unitFloor,parkingSpaces,updatedAt,address,suites,publicationType,externalId,bathrooms,usageTypes,totalAreas,advertiserId,advertiserContact,whatsappNumber,bedrooms,acceptExchange,pricingInfos,showPrice,resale,buildings,capacityLimit,status,priceSuggestion),account(id,name,logoUrl,licenseNumber,showAddress,legacyVivarealId,legacyZapId,minisite),medias,accountLink,link)),totalCount),page,fullUriFragments,superPremium(search(result(listings(listing(listingsCount,sourceId,displayAddressType,amenities,usableAreas,constructionStatus,listingType,description,title,stamps,createdAt,floors,unitTypes,nonActivationReason,providerId,propertyType,unitSubTypes,unitsOnTheFloor,legacyId,id,portal,unitFloor,parkingSpaces,updatedAt,address,suites,publicationType,externalId,bathrooms,usageTypes,totalAreas,advertiserId,advertiserContact,whatsappNumber,bedrooms,acceptExchange,pricingInfos,showPrice,resale,buildings,capacityLimit,status,priceSuggestion),account(id,name,logoUrl,licenseNumber,showAddress,legacyVivarealId,legacyZapId,minisite),medias,accountLink,link)),totalCount)),owners(search(result(listings(listing(listingsCount,sourceId,displayAddressType,amenities,usableAreas,constructionStatus,listingType,description,title,stamps,createdAt,floors,unitTypes,nonActivationReason,providerId,propertyType,unitSubTypes,unitsOnTheFloor,legacyId,id,portal,unitFloor,parkingSpaces,updatedAt,address,suites,publicationType,externalId,bathrooms,usageTypes,totalAreas,advertiserId,advertiserContact,whatsappNumber,bedrooms,acceptExchange,pricingInfos,showPrice,resale,buildings,capacityLimit,status,priceSuggestion),account(id,name,logoUrl,licenseNumber,showAddress,legacyVivarealId,legacyZapId,minisite),medias,accountLink,link)),totalCount))&cityWiseStreet=1&developmentsSize=3&superPremiumSize=3&levels=CITY&ref=%2Faluguel%2Fimoveis%2Fce%2Bfortaleza%2F&__zt=mtc:deduplication,hero:a'

  return requests.get(zapimoveis_url, headers = zapimoveis_headers)

def create_zapimoveis_reader(page_size):
  return lambda page: get_zapimoveis_page(page, page_size)

def get_zapimoveis_file_path(page):
  return f"{ZAP_IMOVEIS_PATH}/request-{page}.json"

# %%
if not USE_PRE_SAVED_REQUESTS:
  ZAPIMOVEIS_PAGE_SIZE = 100

  zapimoveis_reader = create_zapimoveis_reader(ZAPIMOVEIS_PAGE_SIZE)

  # retrieve metadata about number of pages to process
  first_page = zapimoveis_reader(0)

  number_of_results = compute_number_of_results(first_page)
  number_of_pages = get_number_of_pages(number_of_results, ZAPIMOVEIS_PAGE_SIZE)

  print(f"Starting to process {number_of_results} results...")
  print(f"Number of pages: {number_of_pages}")

  # save first page
  f = open(get_zapimoveis_file_path(0), 'w')
  json_dump(first_page.json(), f)
  f.close()

  with tqdm(total=number_of_pages) as pbar:
      pbar.update(1)

      # include final page
      for page in range(1, number_of_pages):
        sleep(1.2) # wait a bit to avoid issues about too many requests
        result = zapimoveis_reader(page)
        result_json = result.json()
        f = open(get_zapimoveis_file_path(page), 'w')
        json_dump(result_json, f)
        f.close()

        pbar.update(1)

# %% [markdown]
# ## Construção de dataframes a partir dos dados brutos
#
# Uma vez que os dados brutos foram coletados, podemos unificar todos esses dados em *dataframes* do pandas

# %% [markdown]
# ### VivaReal

# %%
# filter non-request files
number_of_vivareal_files = len(list(filter(lambda e: e.startswith("request-"), os.listdir(VIVAREAL_PATH))))

fp = open(get_vivareal_file_path(0), "r")
vivareal_sample_json = json_load(fp)
fp.close()

# %% [markdown]
# Abaixo, podemos ver o retorno bruto de uma requisição, no caso, o da primeira requisição.

# %%
jsonprint(vivareal_sample_json)
# Out:
# {
#   "search": {
#     "result": {
#       "listings": [
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "ELEVATOR",
#               "GATED_COMMUNITY",
#               "GARDEN",
#               "PLAYGROUND",
#               "PARTY_HALL",
#               "CONCIERGE_24H",
#               "ELECTRONIC_GATE"
#             ],
#             "usableAreas": [
#               "70"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "IM\u00d3VEL IMPEC\u00c1VEL! L I N D A V I S T A M A R! <br><br>\u00c1rea aproximada 70,00 m\u00b2;<br>01 Su\u00edtes (Vista Mar, Arm\u00e1rios Projetados Fixos, Banheiro Box Vidro);<br>01 Dormit\u00f3rio (Vista Mar, Arm\u00e1rios Projetados Fixos, Banheiro Box Vidro);<br>01 Sala de Estar / Jantar (Vista Mar);<br>01 Cozinha (Arm\u00e1rios Projetados Fixos);<br>02 Vagas de Garagens (COBERTAS) Obs.: Bem ESPA\u00c7OSA;<br><br>Condom\u00ednio incluso (G\u00e1s);",
#             "title": "Apartamento para aluguel tem 70 metros quadrados com 2 quartos em Meireles - Fortaleza - Cear\u00e1",
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "id": "2562524561",
#             "portal": "GRUPOZAP",
#             "parkingSpaces": [
#               2
#             ],
#             "address": {
#               "country": "BR",
#               "zipCode": "60170000",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "160",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.495875,
#                 "source": "GOOGLE",
#                 "lat": -3.72788
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Avenida Desembargador Moreira",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Meireles",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Meireles",
#               "poisList": [
#                 "BS:\u00d4nibus para Cumbuco",
#                 "TS:\u00d4nibus para Cumbuco",
#                 "TS:Papicu",
#                 "TS:Mucuripe",
#                 "CS:Uri Mercado",
#                 "CS:Minimercado Bempertim",
#                 "CS:Cort Carnes Nobres",
#                 "CS:Napadaria",
#                 "CS:Aquablu",
#                 "PH:Farm\u00e1cia i9",
#                 "PH:Farm\u00e1cia TeleJuca",
#                 "PH:Pharmapele",
#                 "PH:Farm\u00e1cia Aldesul",
#                 "PH:Aldesul"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               2
#             ],
#             "publicationType": "PREMIUM",
#             "externalId": "QGC3OEKO",
#             "bathrooms": [
#               2
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "70"
#             ],
#             "advertiserId": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#             "bedrooms": [
#               2
#             ],
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "3430"
#                 },
#                 "yearlyIptu": "110",
#                 "price": "2700",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "730"
#               }
#             ],
#             "showPrice": true,
#             "status": "ACTIVE",
#             "advertiserContact": {
#               "phones": [
#                 "85985685000"
#               ]
#             },
#             "videoTourLink": "",
#             "whatsappNumber": "85985685000",
#             "stamps": []
#           },
#           "account": {
#             "id": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#             "name": "DSF Escrit\u00f3rio",
#             "logoUrl": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/vr.images.sp/0f08930e5548898fe535cb43f603302c.jpg",
#             "licenseNumber": "",
#             "showAddress": true,
#             "legacyVivarealId": 229354,
#             "phones": {
#               "primary": "85985685000",
#               "mobile": "85985685000"
#             }
#           },
#           "medias": [
#             {
#               "id": "4002c07c7518e073ce268a04f6cfb04f",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/4002c07c7518e073ce268a04f6cfb04f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1d1b1306b5ce2f0947d6f3212388499b",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1d1b1306b5ce2f0947d6f3212388499b/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b6b93d85eb4308e04691e0c80a1cf109",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b6b93d85eb4308e04691e0c80a1cf109/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2456a692845b0a54049dabcff57487ac",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2456a692845b0a54049dabcff57487ac/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1b191ac0f84a627504c745d6058c3c6e",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1b191ac0f84a627504c745d6058c3c6e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2bd97b3c097d26c3a25306e1e86f01f0",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2bd97b3c097d26c3a25306e1e86f01f0/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5f3fcab5fcdc201c5de248ebafb4f657",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5f3fcab5fcdc201c5de248ebafb4f657/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f58db1169dccfa16b88d7c7bdfd7df58",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/f58db1169dccfa16b88d7c7bdfd7df58/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "8cff5fa909b6f23dacb9df3f6f9376ac",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/8cff5fa909b6f23dacb9df3f6f9376ac/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "4086958514e35d9311a7a55fa921a56e",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/4086958514e35d9311a7a55fa921a56e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a7cdfacd6c4df2abb755185e26a5c586",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/a7cdfacd6c4df2abb755185e26a5c586/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1017e1fb8f8d7d9bd03689cc8b0f0931",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1017e1fb8f8d7d9bd03689cc8b0f0931/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2e349bdcb1daa84b78b1e418a67e2271",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2e349bdcb1daa84b78b1e418a67e2271/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c37f0eb5cf0bf72e062c7ec2b0b482e4",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c37f0eb5cf0bf72e062c7ec2b0b482e4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "04539b4c33850af938371cf6fb897f60",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/04539b4c33850af938371cf6fb897f60/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5f44be42298deffaf3ba703ae67a32f7",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5f44be42298deffaf3ba703ae67a32f7/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "43fce6664eff42147447db1624b71193",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/43fce6664eff42147447db1624b71193/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "aeb7dc795d4b8905414be602db3c9558",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/aeb7dc795d4b8905414be602db3c9558/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d9c7937e70bf381db10a303d897e4d69",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/d9c7937e70bf381db10a303d897e4d69/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "82797a706dfecc3cc92e4186c605c94e",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/82797a706dfecc3cc92e4186c605c94e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e8cef6ebf71326719c0ee5ec3a84c938",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/e8cef6ebf71326719c0ee5ec3a84c938/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "DSF Escrit\u00f3rio",
#             "href": "/229354/dsf-escritorio/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Meireles",
#               "street": "Avenida Desembargador Moreira",
#               "streetNumber": "160"
#             },
#             "name": "Apartamento com 2 Quartos para alugar, 70m\u00b2",
#             "href": "/imovel/apartamento-2-quartos-meireles-bairros-fortaleza-com-garagem-70m2-aluguel-RS2700-id-2562524561/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "FURNISHED",
#               "BARBECUE_GRILL",
#               "ELEVATOR",
#               "GATED_COMMUNITY",
#               "AIR_CONDITIONING",
#               "PARTY_HALL",
#               "CONCIERGE_24H",
#               "AMERICAN_KITCHEN",
#               "ELECTRONIC_GATE"
#             ],
#             "usableAreas": [
#               "60"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Apartamento Duplex 60 m2, com 02 su\u00edtes, totalmente mobiliado, com 01 vaga de garagem, em \u00f3tima localiza\u00e7\u00e3o(Meirelles). Com ar- condicionado nos quartos, andar alto, vista lateral mar, posi\u00e7\u00e3o sol da manh\u00e3.<br>Pacote ALUGUEL/CONDOM\u00cdNIO/IPTU: R$ 3.500,00<br>J\u00e1 incluso no condom\u00ednio: \u00e1gua e g\u00e1s.",
#             "title": "Apartamento DUPLEX MOBILIADO, 02 su\u00edtes, em Meireles - Fortaleza - Cear\u00e1",
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "id": "2515185773",
#             "portal": "GRUPOZAP",
#             "parkingSpaces": [
#               1
#             ],
#             "address": {
#               "country": "BR",
#               "zipCode": "60170210",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "200",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.490351,
#                 "source": "GOOGLE",
#                 "lat": -3.727192
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Jos\u00e9 Napole\u00e3o",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Meireles",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Meireles",
#               "poisList": [
#                 "BS:\u00d4nibus para Cumbuco",
#                 "TS:Mucuripe",
#                 "TS:Papicu",
#                 "TS:Iate",
#                 "TS:\u00d4nibus para Cumbuco",
#                 "CS:Napadaria",
#                 "CS:Cort Carnes Nobres",
#                 "CS:Uri Mercado",
#                 "CS:Minimercado Bempertim",
#                 "CS:Padaria Primeira Linha",
#                 "PH:Farm\u00e1cia TeleJuca",
#                 "PH:Farm\u00e1cia i9",
#                 "PH:Aldesul",
#                 "PH:Pharmapele",
#                 "PH:Farm\u00e1cia Tele Juc\u00e1"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               2
#             ],
#             "publicationType": "PREMIUM",
#             "externalId": "5WFQM4GZ",
#             "bathrooms": [
#               2
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "69"
#             ],
#             "advertiserId": "a239c50b-0319-1aa0-6ef7-3837586b4063",
#             "bedrooms": [
#               2
#             ],
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "3300"
#                 },
#                 "yearlyIptu": "200",
#                 "price": "2500",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "800"
#               }
#             ],
#             "showPrice": true,
#             "status": "ACTIVE",
#             "advertiserContact": {
#               "phones": [
#                 "11981751746"
#               ]
#             },
#             "videoTourLink": "",
#             "whatsappNumber": "11981751746",
#             "stamps": []
#           },
#           "account": {
#             "id": "a239c50b-0319-1aa0-6ef7-3837586b4063",
#             "name": "ANTONIO RODRIGUES",
#             "licenseNumber": "",
#             "showAddress": true,
#             "legacyVivarealId": 300490,
#             "phones": {
#               "primary": "11981751746",
#               "mobile": "11981751746"
#             }
#           },
#           "medias": [
#             {
#               "id": "8221493a085f1789e8619f37da92baa5",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/8221493a085f1789e8619f37da92baa5/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "978b47e82153f07346b11efea6a1d0a9",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/978b47e82153f07346b11efea6a1d0a9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "bbc5fb69aff7a388b4ed8c9970a22bbd",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/bbc5fb69aff7a388b4ed8c9970a22bbd/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "6ce75af7e39746f1739a7430b22ef6ca",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/6ce75af7e39746f1739a7430b22ef6ca/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "25e2b14f16d2bee8c8afa97c5ec52e31",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/25e2b14f16d2bee8c8afa97c5ec52e31/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "9e7613e033a867c01017f0099572e412",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/9e7613e033a867c01017f0099572e412/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d6cf61548dfc094d1e768791939b8d6f",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/d6cf61548dfc094d1e768791939b8d6f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ffff94bcbb4a2a3150b7468ee1a7451a",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/ffff94bcbb4a2a3150b7468ee1a7451a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "894aa968e6dc599a6244c45e241af8a4",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/894aa968e6dc599a6244c45e241af8a4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "31abdab7bdf1a0dc4770463175e6328c",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/31abdab7bdf1a0dc4770463175e6328c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "295e55259a6aa893b0d40b7920e8e3a6",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/295e55259a6aa893b0d40b7920e8e3a6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "61e7df02a1e69efc6b504adfbe55c9ad",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/61e7df02a1e69efc6b504adfbe55c9ad/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1827fb697b84af7901ff9d312ddaca88",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1827fb697b84af7901ff9d312ddaca88/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "ANTONIO RODRIGUES",
#             "href": "/300490/antonio-rodrigues/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Meireles",
#               "street": "Rua Jos\u00e9 Napole\u00e3o",
#               "streetNumber": "200"
#             },
#             "name": "Apartamento com 2 Quartos para alugar, 60m\u00b2",
#             "href": "/imovel/apartamento-2-quartos-meireles-bairros-fortaleza-com-garagem-60m2-aluguel-RS2500-id-2515185773/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "AIR_CONDITIONING",
#               "PORCELAIN"
#             ],
#             "usableAreas": [
#               "35"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA\u00c7\u00c3O EM LED;<br>TETO EM GESSO;<br>02 ARES CONDICIONADOS 18.000 BTU instalados;<br>01 VIDEO PORTEIRO; <br><br>LOCALIZA\u00c7\u00c3O ESPETACULAR!!!<br><br>Complexo P\u00e1tio Dom Luis, \u00e9 um empreendimento completo. Al\u00e9m de um Centro comercial com espa\u00e7o para 82 lojas, o complexo possui duas torres comerciais com 759 salas e duas torres residenciais com 92 apartamentos localizados na \u00e1rea mais nobre de Fortaleza.",
#             "title": "Sala comercial, localiza\u00e7\u00e3o INENARR\u00c1VEL / para aluguel tem 35m em Meireles - Fortaleza - Cear\u00e1",
#             "unitTypes": [
#               "OFFICE"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "id": "2534494892",
#             "portal": "GRUPOZAP",
#             "parkingSpaces": [],
#             "address": {
#               "country": "BR",
#               "zipCode": "60160230",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "1200",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.490084,
#                 "source": "GOOGLE",
#                 "lat": -3.736109
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Avenida Dom Lu\u00eds",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Meireles",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Meireles",
#               "poisList": [
#                 "TS:Papicu",
#                 "TS:Ant\u00f4nio Sales",
#                 "TS:Mucuripe",
#                 "CS:Cort Carnes Nobres",
#                 "CS:Finop\u00e3es",
#                 "CS:Padaria Primeira Linha",
#                 "CS:Le Gumis",
#                 "CS:Minimercado Bempertim",
#                 "PH:Farm\u00e1cia Tele Juc\u00e1",
#                 "PH:Farm\u00e1cia Aldesul",
#                 "PH:Farm\u00e1cia TeleJuca",
#                 "PH:Aldesul",
#                 "PH:Farm\u00e1cia i9",
#                 "VP:Faro Fino",
#                 "VP:Bichos & Cia"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [],
#             "publicationType": "PREMIUM",
#             "externalId": "FW367WSA",
#             "bathrooms": [
#               1
#             ],
#             "usageTypes": [
#               "COMMERCIAL"
#             ],
#             "totalAreas": [
#               "35"
#             ],
#             "advertiserId": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#             "bedrooms": [],
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "3075"
#                 },
#                 "yearlyIptu": "330",
#                 "price": "2500",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "575"
#               }
#             ],
#             "showPrice": true,
#             "status": "ACTIVE",
#             "advertiserContact": {
#               "phones": [
#                 "85985685000"
#               ]
#             },
#             "videoTourLink": "",
#             "whatsappNumber": "85985685000",
#             "stamps": []
#           },
#           "account": {
#             "id": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#             "name": "DSF Escrit\u00f3rio",
#             "logoUrl": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/vr.images.sp/0f08930e5548898fe535cb43f603302c.jpg",
#             "licenseNumber": "",
#             "showAddress": true,
#             "legacyVivarealId": 229354,
#             "phones": {
#               "primary": "85985685000",
#               "mobile": "85985685000"
#             }
#           },
#           "medias": [
#             {
#               "id": "651176dcf3588c168a824cfe90203148",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/651176dcf3588c168a824cfe90203148/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "7db0c0d2db4f44397ddb6f269886555c",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/7db0c0d2db4f44397ddb6f269886555c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "9c791f275588449863c0bfac0c01a3c3",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/9c791f275588449863c0bfac0c01a3c3/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "927fd603edca39217d1decf8074c44a0",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/927fd603edca39217d1decf8074c44a0/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "71acba26d861055f94ab41c58868ba99",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/71acba26d861055f94ab41c58868ba99/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5ee1011ed2e0f9d1d8769096557dba58",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5ee1011ed2e0f9d1d8769096557dba58/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "4aba6a7251aa6e0223cc6db2f8b02d21",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/4aba6a7251aa6e0223cc6db2f8b02d21/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ab9c3290362f43922be3abbe078c7026",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/ab9c3290362f43922be3abbe078c7026/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "17dafa6a331a06a3519a0e13bbee5e8a",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/17dafa6a331a06a3519a0e13bbee5e8a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c1cca4e5d846bbc5b2483ae5c123bfa8",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c1cca4e5d846bbc5b2483ae5c123bfa8/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ac55c843526149ffec2afc4a66b926db",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/ac55c843526149ffec2afc4a66b926db/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "110a78eb271a950fddc15efa7f6ea76a",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/110a78eb271a950fddc15efa7f6ea76a/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "DSF Escrit\u00f3rio",
#             "href": "/229354/dsf-escritorio/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "street": "Avenida Dom Lu\u00eds",
#               "streetNumber": "1200",
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Meireles"
#             },
#             "name": "Sala Comercial para alugar, 35m\u00b2",
#             "href": "/imovel/sala-comercial-meireles-bairros-fortaleza-35m2-aluguel-RS2500-id-2534494892/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [],
#             "usableAreas": [
#               "33"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Salas com piso em porcelanato bianco, com forro de gesso e ilumina\u00e7\u00e3o prontos, no empreendimento mais lindo e moderno da Av Santos Dumont, bem no cora\u00e7\u00e3o da Aldeota!<br>\u2800<br>\u2022 28 salas por andar;<br>\u2022 Heliponto;<br>\u2022 Elevadores inteligentes: 15 (sendo 01 panor\u00e2mico);<br>\u2022 Sistema de seguran\u00e7a eletr\u00f4nico com equipamentos: alarme, c\u00e2meras digitais e sistema de grava\u00e7\u00e3o em HD;<br>\u2022 Academia;<br>\u2022 Audit\u00f3rio equipado;<br>\u2022 8 pavimentos de garagem com estacionamento para quase mil ve\u00edculos.",
#             "title": "Scopa Platinum Corporate - Salas amplas com WC",
#             "unitTypes": [
#               "OFFICE"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "id": "2516799902",
#             "portal": "GRUPOZAP",
#             "parkingSpaces": [
#               1
#             ],
#             "address": {
#               "country": "BR",
#               "zipCode": "60115191",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "1153",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.50933,
#                 "source": "GOOGLE",
#                 "lat": -3.733264
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Monsenhor Bruno",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Aldeota",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Aldeota",
#               "poisList": [
#                 "BS:\u00d4nibus para Cumbuco",
#                 "BS:Terminal Cora\u00e7\u00e3o de Jesus",
#                 "TS:\u00d4nibus para Cumbuco",
#                 "TS:Terminal Cora\u00e7\u00e3o de Jesus",
#                 "CS:Head Machine",
#                 "CS:Costa Mendes Delicatessen",
#                 "CS:P\u00e3o e P\u00e3es",
#                 "CS:Fiorella Panificadora e Confeitaria",
#                 "CS:SO \u00c1gua",
#                 "PH:Farm\u00e1cia Santa Branca",
#                 "PH:Carrefour Drogaria",
#                 "PH:Roval Farm\u00e1cia de Manipula\u00e7\u00e3o",
#                 "PH:Pharmapele",
#                 "PH:Farm\u00e1cia Sobreira"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [],
#             "publicationType": "PREMIUM",
#             "externalId": "FQSV6NGN",
#             "bathrooms": [
#               1
#             ],
#             "usageTypes": [
#               "COMMERCIAL"
#             ],
#             "totalAreas": [],
#             "advertiserId": "11c4ded5-8ea5-2404-2183-e5e985813374",
#             "bedrooms": [],
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "2178"
#                 },
#                 "yearlyIptu": "1143",
#                 "price": "1750",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "428"
#               }
#             ],
#             "showPrice": true,
#             "status": "ACTIVE",
#             "advertiserContact": {
#               "phones": [
#                 "85991180986"
#               ]
#             },
#             "videoTourLink": "",
#             "whatsappNumber": "85991180986",
#             "stamps": []
#           },
#           "account": {
#             "id": "11c4ded5-8ea5-2404-2183-e5e985813374",
#             "name": "Vida Im\u00f3veis S/A",
#             "licenseNumber": "",
#             "showAddress": false,
#             "legacyVivarealId": 654505,
#             "phones": {
#               "primary": "85991180986",
#               "mobile": "85991180986"
#             }
#           },
#           "medias": [
#             {
#               "id": "343866a6f19599e359cdc2e945992795",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/343866a6f19599e359cdc2e945992795/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a5aa0119e9e915096b94128a11b83d1d",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/a5aa0119e9e915096b94128a11b83d1d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "cd61ffbac45738c47047eecba32be7b1",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/cd61ffbac45738c47047eecba32be7b1/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "27a94a166795f68748a0c16bddec41c4",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/27a94a166795f68748a0c16bddec41c4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "031fb9fbe25e35bb10a449123fefba1b",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/031fb9fbe25e35bb10a449123fefba1b/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "9a558ae260c024b1827a3e4bad0b5523",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/9a558ae260c024b1827a3e4bad0b5523/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c845b9effd6b9eef9b465cfd3c528245",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c845b9effd6b9eef9b465cfd3c528245/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "0d30d21609238c79fa52e3c7fbd5d30d",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/0d30d21609238c79fa52e3c7fbd5d30d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "fd40b63c697eeedfa5b1362e8ed9cb3d",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/fd40b63c697eeedfa5b1362e8ed9cb3d/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "Vida Im\u00f3veis S/A",
#             "href": "/654505/vida-imoveis-s-a/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Aldeota",
#               "street": "Rua Monsenhor Bruno",
#               "streetNumber": "1153"
#             },
#             "name": "Sala Comercial para alugar, 33m\u00b2",
#             "href": "/imovel/sala-comercial-aldeota-bairros-fortaleza-com-garagem-33m2-aluguel-RS1750-id-2516799902/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [],
#             "usableAreas": [
#               "30"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "COMPSA \u2013 COMPARTILHAMENTO DE SALAS: <br>I. MOBILIADAS OU A MOBILIAR <br>II. CUSTO OR\u00c7AMENTADO POR HORA, EXPEDIENTES OU INTEGRAL <br>III. DESTINADO A PROFISSIONAIS LIBERAIS: \u00c1REA DE SA\u00daDE; ARQUITETO; ADVOGADOS; EMGENHEIROS; ADMINISTRADORES; CONTABILISTA ETC.<br>IV. OP\u00c7\u00c3O DE SERVI\u00c7OS DE RECEP\u00c7\u00c3O E/OU BUROCR\u00c1TICOS<br><br>Estrutura F\u00edsica<br>1- Rampas de acesso, recep\u00e7\u00e3o corredores, portas e banheiros adaptados e plataforma de acessibilidade em aten\u00e7\u00e3o \u00e0s pessoas com dificuldade de locomo\u00e7\u00e3o<br>2- 10 Salas com tamanhos entre 13 e 22m<br>3- 01 sala com banheiro privativo<br>4- 02 banheiros acess\u00edveis na recep\u00e7\u00e3o, o feminino adaptado para crian\u00e7as<br>5- 02 banheiros para profissionais e funcion\u00e1rios, um com \u00e1rea de banho<br>6- Cozinha: micro-ondas, cafeteira etc <br>7- \u00c1rea de acolhimento infantil na recep\u00e7\u00e3o<br>8- Vagas de estacionamento na frente e lateral n\u00e3o privativas<br>9- Estacionamento comercial na frente da cl\u00ednica<br><br>SALAS MOBILIADAS<br>O que est\u00e1 incluso no aluguel das salas mobiliadas:<br>1. Sala mobiliada com mobili\u00e1rio novo, primeiro uso, com manuten\u00e7\u00e3o<br>2. Gaveta individualizada para material dos profissionais<br>3. Ar condicionado<br>4. Material b\u00e1sico de higiene nas salas: Papel toalha, Sabonete l\u00edquido e \u00e1lcool gel<br>5. Energia<br>6. Luz<br>7. IPTU<br>8. Internet wireless nas salas e recep\u00e7\u00e3o, para profissionais e clientes<br>9. Limpeza di\u00e1ria<br><br>O que \u00e9 opcional:<br>1. Trabalho de recepcionista, com agendamentos.<br>2. Impressora nas salas<br>3. Len\u00e7ol rolo<br>4. Batas e/ou shorts descart\u00e1veis para \u00e1rea de sa\u00fade. <br>5. Disponibilidade de servi\u00e7os complementares burocr\u00e1ticos a combinar<br><br> 1- Salas n\u00e3o mobiliadas<br>a. Tipo 1 <br>b. Tipos 2 e 3 <br>b. Com atendente e sem atendente<br>c. Valor a negociar<br> <br><br> Salas Mobiliadas <br>Tipo 1 <br>i. $30,00 a hora ou fra\u00e7\u00e3o; <br>ii. Expediente manh\u00e3 - Valor mensal<br> 01 expediente semanal = $470,00 por expediente; 02 expedientes semanais = $450,00 por expediente . A partir de 03 expedientes semanais \u2013 $430,00 por expediente<br>iii. Expediente Tarde - Valor mensal <br> 01 expediente semanal = $520,00 por expediente. 02 expedientes = $500 por expediente. A partir de 03 expedientes semanais - $480,00 por expediente<br>Tipo 2 <br>i. $40,00 a hora ou fra\u00e7\u00e3o; <br>ii. Expediente manh\u00e3 <br> 01 expediente semanal = $520,00 por expediente . 02 expedientes = $500,00 por expediente. A partir de 03 \u2013 $480,00 por expediente<br>iii. Expediente Tarde \u2013 01 expediente semanal = $570,00 por expediente. 02 expedientes = $550 por expediente. A partir de 03 - $530,00 por expediente",
#             "title": "COMPSA - Compartilhamento de Salas - Hora, Expediente ou Integral",
#             "unitTypes": [
#               "OFFICE"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "propertyType": "UNIT",
#             "unitSubTypes": [
#               "CLINIC"
#             ],
#             "id": "2532715897",
#             "portal": "GRUPOZAP",
#             "parkingSpaces": [
#               0
#             ],
#             "address": {
#               "country": "BR",
#               "zipCode": "60140120",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "1264",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.493051,
#                 "source": "GOOGLE",
#                 "lat": -3.743591
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Carolina Sucupira",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Aldeota",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Aldeota",
#               "poisList": [
#                 "TS:Ant\u00f4nio Sales",
#                 "TS:Papicu",
#                 "TS:Pontes Vieira",
#                 "CS:Fazendinha",
#                 "CS:Finop\u00e3es",
#                 "CS:Le Gumis",
#                 "CS:Cort Carnes Nobres",
#                 "CS:Padaria Primeira Linha",
#                 "PH:Farm\u00e1cia Aldesul",
#                 "PH:Farm\u00e1cia Tele Juc\u00e1",
#                 "PH:Farm\u00e1cia Santa Branca",
#                 "PH:Aldesul",
#                 "PH:Carrefour Drogaria",
#                 "VP:Bichos & Cia",
#                 "VP:Faro Fino"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               0
#             ],
#             "publicationType": "PREMIUM",
#             "externalId": "GY3AMWXI",
#             "bathrooms": [
#               0
#             ],
#             "usageTypes": [
#               "COMMERCIAL"
#             ],
#             "totalAreas": [],
#             "advertiserId": "2cb4a334-9204-a7c6-6c50-0f503453322a",
#             "bedrooms": [
#               0
#             ],
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "500"
#                 },
#                 "price": "500",
#                 "businessType": "RENTAL"
#               }
#             ],
#             "showPrice": true,
#             "status": "ACTIVE",
#             "advertiserContact": {
#               "phones": [
#                 "85988312527",
#                 "85998340077"
#               ]
#             },
#             "videoTourLink": "",
#             "whatsappNumber": "85998340077",
#             "stamps": []
#           },
#           "account": {
#             "id": "2cb4a334-9204-a7c6-6c50-0f503453322a",
#             "name": "COMPSA - Compartilhamento de Salas - Hora, Expediente, Integral",
#             "licenseNumber": "",
#             "showAddress": false,
#             "legacyVivarealId": 672268,
#             "phones": {
#               "primary": "85988312527",
#               "mobile": "85998340077"
#             }
#           },
#           "medias": [
#             {
#               "id": "e6d6b21648124e76989739333b57b506",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/e6d6b21648124e76989739333b57b506/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1cf355c79d6ab626597d8d9c44ddae6d",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1cf355c79d6ab626597d8d9c44ddae6d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "56557c3c0046505842d8b26053de91f9",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/56557c3c0046505842d8b26053de91f9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "445258b95734db85f8897c0070088f45",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/445258b95734db85f8897c0070088f45/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "de105839722ba9e3fad36c17ac77b260",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/de105839722ba9e3fad36c17ac77b260/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "37a94597c1a72440c51c09120d0b54f8",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/37a94597c1a72440c51c09120d0b54f8/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f0d5561fa5f278ade0aa3a39aa8964be",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/f0d5561fa5f278ade0aa3a39aa8964be/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "8945c0a23a432094176b5ae84873cfe1",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/8945c0a23a432094176b5ae84873cfe1/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b277d848d15660f641cea0b431a7c610",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b277d848d15660f641cea0b431a7c610/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d41632b73c5aec46bb5735f4d771cdee",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/d41632b73c5aec46bb5735f4d771cdee/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "82603ea33937fbae518300ac39bc57c0",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/82603ea33937fbae518300ac39bc57c0/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b4695069e4bc6aa7a37448efa26bfc63",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b4695069e4bc6aa7a37448efa26bfc63/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c17838d6d75263a1cfc097c081521e67",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c17838d6d75263a1cfc097c081521e67/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "3a70dcf21767206ea264843ce215c2e1",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/3a70dcf21767206ea264843ce215c2e1/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "af158677c756801cb20bd54740fea2fa",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/af158677c756801cb20bd54740fea2fa/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "dd974d4f195128cec7bdc2a4b49851cb",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/dd974d4f195128cec7bdc2a4b49851cb/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "3de158f275575f49a0abf8c096ed0a8a",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/3de158f275575f49a0abf8c096ed0a8a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2e68eb6e6b7441415cc1bea4a9d605e9",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2e68eb6e6b7441415cc1bea4a9d605e9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b4189cb3237c6a792c9c8414c464b071",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b4189cb3237c6a792c9c8414c464b071/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "8655f8456676c951cb0fa9375e61709c",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/8655f8456676c951cb0fa9375e61709c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "62314eb00269184f3f1a7edcae13e3bb",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/62314eb00269184f3f1a7edcae13e3bb/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "COMPSA - Compartilhamento de Salas - Hora, Expediente, Integral",
#             "href": "/672268/compsa-compartilhamento-de-salas-hora-expediente-integral/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
# ...
#             "showAddress": false,
#             "legacyVivarealId": 762527,
#             "phones": {
#               "primary": "16981134238",
#               "mobile": "16981134238"
#             }
#           },
#           "medias": [
#             {
#               "id": "5f114873848635b39b6358763426f554",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5f114873848635b39b6358763426f554/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "473486ca6e8c4bb51c4269bfc22f3b1f",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/473486ca6e8c4bb51c4269bfc22f3b1f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "7e59ff7dab93f7bb771285266988212f",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/7e59ff7dab93f7bb771285266988212f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "6530f74a414a619f2a28de9ab60d59d2",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/6530f74a414a619f2a28de9ab60d59d2/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "92cd0e322f9ca06e854dd83754c20e3c",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/92cd0e322f9ca06e854dd83754c20e3c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "935ecfde57619fcd8924c00b5d2b563a",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/935ecfde57619fcd8924c00b5d2b563a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "eff1e403e9d885b6ba0c621037bd6245",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/eff1e403e9d885b6ba0c621037bd6245/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "140411aca151228df7512f8dced9e5ec",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/140411aca151228df7512f8dced9e5ec/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "9c33001ef83d7ba83ce8ea98b637a2e8",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/9c33001ef83d7ba83ce8ea98b637a2e8/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b653916fd4ea69ca921a516797a08285",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b653916fd4ea69ca921a516797a08285/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a281e9ddc58e13c1a8446453ed6f564d",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/a281e9ddc58e13c1a8446453ed6f564d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c4f877c6d91dd68c9d0a0cd20a31aecc",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c4f877c6d91dd68c9d0a0cd20a31aecc/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e5248903e75a0769c94ee2f9409fa6ac",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/e5248903e75a0769c94ee2f9409fa6ac/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "47131ce123aa20309d9a06cb76d65ad4",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/47131ce123aa20309d9a06cb76d65ad4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "99f38a24542d9c2dd0884913f95414bf",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/99f38a24542d9c2dd0884913f95414bf/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "de78587df4bfef2e9c080fd9dc9094ce",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/de78587df4bfef2e9c080fd9dc9094ce/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c66da127c0359732353c0da0dba5e8a9",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c66da127c0359732353c0da0dba5e8a9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "71a9e7c39c56bcdb97a1a19385d6190e",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/71a9e7c39c56bcdb97a1a19385d6190e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "3051ac8d2148c2af870ff29549acde94",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/3051ac8d2148c2af870ff29549acde94/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "259c93ad1d5d87fbe45b9e8c4b2ad0d1",
#               "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/259c93ad1d5d87fbe45b9e8c4b2ad0d1/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "Renan Memoria",
#             "href": "/762527/renan-memoria/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Meireles",
#               "street": "Avenida Dom Lu\u00eds",
#               "streetNumber": "1200"
#             },
#             "name": "Consult\u00f3rio para alugar, 90m\u00b2",
#             "href": "/imovel/consultorio-meireles-bairros-fortaleza-90m2-aluguel-RS4000-id-2560237302/",
#             "rel": ""
#           }
#         }
#       ]
#     },
#     "totalCount": 7586
#   },
#   "page": {
#     "widgets": [
#       {
#         "links": [
#           {
#             "data": {},
#             "name": "Aluguel",
#             "href": "/aluguel/",
#             "rel": "INDEX"
#           },
#           {
#             "data": {},
#             "name": "CE",
#             "href": "/aluguel/ceara/",
#             "rel": "INDEX"
#           },
#           {
#             "data": {},
#             "name": "Im\u00f3veis para alugar em Fortaleza",
#             "href": "",
#             "rel": "INDEX"
#           }
#         ],
#         "header": null,
#         "footer": null,
#         "category": "BREADCRUMB"
#       },
#       {
#         "links": [
#           {
#             "data": {},
#             "name": "Im\u00f3veis \u00e0 venda",
#             "href": "/venda/ceara/fortaleza/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Apartamentos para alugar",
#             "href": "/aluguel/ceara/fortaleza/apartamento_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Casas para alugar",
#             "href": "/aluguel/ceara/fortaleza/casa_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Casas de Condom\u00ednio para alugar",
#             "href": "/aluguel/ceara/fortaleza/condominio_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Coberturas para alugar",
#             "href": "/aluguel/ceara/fortaleza/cobertura_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Consult\u00f3rios para alugar",
#             "href": "/aluguel/ceara/fortaleza/consultorio_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Flats para alugar",
#             "href": "/aluguel/ceara/fortaleza/flat_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Galp\u00f5es/Dep\u00f3sitos/Armaz\u00e9ns para alugar",
#             "href": "/aluguel/ceara/fortaleza/galpao_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Im\u00f3veis Comerciais para alugar",
#             "href": "/aluguel/ceara/fortaleza/imovel-comercial_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Kitnets para alugar",
#             "href": "/aluguel/ceara/fortaleza/kitnet_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Lotes/Terrenos para alugar",
#             "href": "/aluguel/ceara/fortaleza/lote-terreno_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Lotes/Terrenos para alugar",
#             "href": "/aluguel/ceara/fortaleza/lote-terreno_residencial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Pontos Comerciais para alugar",
#             "href": "/aluguel/ceara/fortaleza/ponto-comercial_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Pr\u00e9dios Comerciais para alugar",
#             "href": "/aluguel/ceara/fortaleza/predio_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Salas Comerciais para alugar",
#             "href": "/aluguel/ceara/fortaleza/sala_comercial/",
#             "rel": ""
#           },
#           {
#             "data": {},
#             "name": "Sobrados para alugar",
#             "href": "/aluguel/ceara/fortaleza/sobrado_residencial/",
#             "rel": ""
#           }
#         ],
#         "header": {
#           "data": {},
#           "name": "Veja tamb\u00e9m em Fortaleza",
#           "href": "",
#           "rel": ""
#         },
#         "footer": {
#           "data": {},
#           "name": "Veja mais im\u00f3veis para alugar em Fortaleza",
#           "href": "/sitemap/aluguel/ceara/fortaleza/",
#           "rel": ""
#         },
#         "category": "SEE_ALSO"
#       },
#       {
#         "links": [
#           {
#             "data": {},
#             "name": "<h4>Encontre im\u00f3veis para aluguel em Fortaleza - Cear\u00e1</h4> <p>Veja nossa lista de propriedades para aluguel e encontre as melhores op\u00e7\u00f5es para alugar im\u00f3veis em Fortaleza. Conhe\u00e7a as diversas oportunidades de aluguel de im\u00f3veis, e alugue sua propriedade em  Fortaleza - Cear\u00e1.</p> <p>Consulte  nossas listas de propriedades para aluguel em diversos bairros e regi\u00f5es de Fortaleza. Veja im\u00f3veis para aluguel das melhores imobili\u00e1rias de Fortaleza - Cear\u00e1.</p> <p>Anuncie seus im\u00f3veis para aluguel em Fortaleza - Cear\u00e1</p>",
#             "href": "",
#             "rel": ""
#           }
#         ],
#         "header": null,
#         "footer": null,
#         "category": "CONTENT_FROM_LOCATION"
#       }
#     ],
#     "metaContent": {
#       "robots": "INDEX, FOLLOW",
#       "title": "Im\u00f3veis para alugar em Fortaleza, CE - Viva Real",
#       "description": "Mais de 7.586 im\u00f3veis para alugar em Fortaleza, Cear\u00e1. Acesse as melhores ofertas de aluguel de im\u00f3veis em Fortaleza.",
#       "primaryHeading": "Im\u00f3veis para alugar em Fortaleza - CE",
#       "secondaryHeading": "",
#       "shouldCountAds": false
#     },
#     "uriFragments": {
#       "unitSubTypes": [],
#       "business": "RENTAL",
#       "address": {
#         "pois": [],
#         "valuableZones": [],
#         "poisList": [],
#         "country": "Brasil",
#         "state": "Cear\u00e1",
#         "city": "Fortaleza",
#         "district": "",
#         "zone": "",
#         "neighborhood": "",
#         "street": "",
#         "streetNumber": "",
#         "complement": "",
#         "zipCode": "",
#         "level": "Level_NONE",
#         "point": {
#           "lat": -3.73272,
#           "lon": -38.527013,
#           "source": "GeoPointSource_NONE"
#         },
#         "geoJson": "",
#         "precision": "Precision_NONE",
#         "name": "",
#         "locationId": "BR>Ceara>NULL>Fortaleza",
#         "source": "AddressSource_NONE",
#         "confidence": "ConfidenceLevel_NONE",
#         "ibgeCityId": "",
#         "stateAcronym": ""
#       },
#       "unitType": "UnitType_NONE",
#       "usageType": "UsageType_NONE",
#       "amenity": "Amenity_NONE",
#       "propertyType": "PropertyType_NONE",
#       "listingType": "USED",
#       "constructionStatus": "ConstructionStatus_NONE",
#       "bedrooms": 0,
#       "advertiserId": "",
#       "listingId": "",
#       "condominiumUuid": "",
#       "condominiumName": "",
#       "advertiserLegacyId": 0,
#       "pricingInfo": null,
#       "condominiumShortUuid": "",
#       "condominium": null,
#       "unitTypeV3": "UnitType_NONE",
#       "advertiser": {
#         "id": "",
#         "legacyVivaRealId": 0,
#         "legacyZapId": 0,
#         "name": ""
#       },
#       "campaign": {
#         "name": ""
#       },
#       "pointRadius": ""
#     },
#     "uriCategory": {
#       "levels": [
#         "CITY"
#       ],
#       "name": "",
#       "page": "RESULT",
#       "portal": "VIVAREAL"
#     },
#     "uriPagination": {
#       "page": 1,
#       "from": 0,
#       "size": 100,
#       "total": 7586
#     },
#     "link": {
#       "data": {},
#       "name": "Fortaleza",
#       "href": "/aluguel/ceara/fortaleza/",
#       "rel": ""
#     },
#     "condominium": null,
#     "redirectRule": null
#   },
#   "seasonalCampaigns": [],
#   "fullUriFragments": {
#     "addresses": [
#       {
#         "state": "Cear\u00e1",
#         "city": "Fortaleza",
#         "locationId": "BR>Ceara>NULL>Fortaleza",
#         "point": {
#           "lat": -3.73272,
#           "lon": -38.527013
#         }
#       }
#     ],
#     "business": "RENTAL",
#     "listingType": "USED",
#     "parentId": "null"
#   },
#   "account": null,
#   "facets": {
#     "amenities": {
#       "KITCHEN": 1837,
#       "SERVICE_AREA": 1279,
#       "ELEVATOR": 696,
#       "GATED_COMMUNITY": 663,
#       "INTERCOM": 643,
#       "POOL": 624,
#       "PARTY_HALL": 575,
#       "BALCONY": 515,
#       "BARBECUE_GRILL": 510,
#       "PETS_ALLOWED": 489,
#       "PLAYGROUND": 487,
#       "GARAGE": 482,
#       "AIR_CONDITIONING": 448,
#       "GARDEN": 411,
#       "CONCIERGE_24H": 318,
#       "GYM": 308,
#       "SPORTS_COURT": 292,
#       "ELECTRONIC_GATE": 286,
#       "SECURITY_24_HOURS": 278,
#       "FURNISHED": 275,
#       "LAUNDRY": 229,
#       "GOURMET_SPACE": 226,
#       "ALARM_SYSTEM": 202,
#       "BACKYARD": 196,
#       "GOURMET_BALCONY": 193,
#       "HOME_OFFICE": 185,
#       "WATCHMAN": 168,
#       "AMERICAN_KITCHEN": 160,
#       "NEAR_SHOPPING_CENTER": 152,
#       "SAUNA": 141,
#       "KITCHEN_CABINETS": 140,
#       "NEAR_ACCESS_ROADS": 125,
#       "DISABLED_ACCESS": 115,
#       "SAFETY_CIRCUIT": 108,
#       "NEAR_HOSPITAL": 100,
#       "NEAR_SCHOOL": 100,
#       "NEAR_PUBLIC_TRANSPORT": 97,
#       "CLOSET": 96,
#       "ADULT_GAME_ROOM": 95,
#       "INTERNET_ACCESS": 88,
#       "CABLE_TV": 86,
#       "DEPOSIT": 84,
#       "GAMES_ROOM": 80,
#       "SEA_VIEW": 75,
#       "COPA": 71,
#       "BEDROOM_WARDROBE": 69,
#       "SECURITY_CAMERA": 68,
#       "BICYCLES_PLACE": 60,
#       "PARKING": 60,
#       "BUILTIN_WARDROBE": 59,
#       "RECEPTION": 57,
#       "CINEMA": 49,
#       "SPA": 49,
#       "RECREATION_AREA": 43,
#       "BATHROOM_CABINETS": 42,
#       "BLINDEX_BOX": 40,
#       "ELECTRIC_GENERATOR": 35,
#       "INTEGRATED_ENVIRONMENTS": 33,
#       "ADULT_POOL": 32,
#       "NATURAL_VENTILATION": 31,
#       "ENTRANCE_HALL": 27,
#       "CHILDRENS_POOL": 26,
#       "COWORKING": 25,
#       "NUMBER_OF_FLOORS": 22,
#       "LARGE_ROOM": 21,
#       "SERVICE_BATHROOM": 21,
#       "DINNER_ROOM": 20,
#       "PANORAMIC_VIEW": 20,
#       "TENNIS_COURT": 20,
#       "DECK": 14,
#       "LARGE_KITCHEN": 13,
#       "COOKER": 12,
#       "GREEN_SPACE": 11,
#       "SECURITY_CABIN": 10,
#       "SQUASH": 10
#     }
#   }
# }

# %% [markdown]
# Analisando os dados, podemos ver que os dados das residências ficam aninhados em 'search' > 'result' > 'listings', que é uma lista com os resultados. Abaixo, mostramos o primeiro elemento dessa lista, ou seja, um imóvel para alugar. Aqui, é possível notar que os dados da residência de fato ficam dentro do campo `listing`

# %%
listings = vivareal_sample_json["search"]["result"]["listings"]
jsonprint(listings[0])
# Out:
# {
#   "listing": {
#     "displayAddressType": "ALL",
#     "amenities": [
#       "ELEVATOR",
#       "GATED_COMMUNITY",
#       "GARDEN",
#       "PLAYGROUND",
#       "PARTY_HALL",
#       "CONCIERGE_24H",
#       "ELECTRONIC_GATE"
#     ],
#     "usableAreas": [
#       "70"
#     ],
#     "constructionStatus": "ConstructionStatus_NONE",
#     "listingType": "USED",
#     "description": "IM\u00d3VEL IMPEC\u00c1VEL! L I N D A V I S T A M A R! <br><br>\u00c1rea aproximada 70,00 m\u00b2;<br>01 Su\u00edtes (Vista Mar, Arm\u00e1rios Projetados Fixos, Banheiro Box Vidro);<br>01 Dormit\u00f3rio (Vista Mar, Arm\u00e1rios Projetados Fixos, Banheiro Box Vidro);<br>01 Sala de Estar / Jantar (Vista Mar);<br>01 Cozinha (Arm\u00e1rios Projetados Fixos);<br>02 Vagas de Garagens (COBERTAS) Obs.: Bem ESPA\u00c7OSA;<br><br>Condom\u00ednio incluso (G\u00e1s);",
#     "title": "Apartamento para aluguel tem 70 metros quadrados com 2 quartos em Meireles - Fortaleza - Cear\u00e1",
#     "unitTypes": [
#       "APARTMENT"
#     ],
#     "nonActivationReason": "NonActivationReason_NONE",
#     "propertyType": "UNIT",
#     "unitSubTypes": [],
#     "id": "2562524561",
#     "portal": "GRUPOZAP",
#     "parkingSpaces": [
#       2
#     ],
#     "address": {
#       "country": "BR",
#       "zipCode": "60170000",
#       "geoJson": "",
#       "city": "Fortaleza",
#       "streetNumber": "160",
#       "level": "STREET",
#       "precision": "ROOFTOP",
#       "confidence": "VALID_STREET",
#       "stateAcronym": "CE",
#       "source": "CORREIOS",
#       "point": {
#         "lon": -38.495875,
#         "source": "GOOGLE",
#         "lat": -3.72788
#       },
#       "ibgeCityId": "",
#       "zone": "",
#       "street": "Avenida Desembargador Moreira",
#       "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Meireles",
#       "district": "",
#       "name": "",
#       "state": "Cear\u00e1",
#       "neighborhood": "Meireles",
#       "poisList": [
#         "BS:\u00d4nibus para Cumbuco",
#         "TS:\u00d4nibus para Cumbuco",
#         "TS:Papicu",
#         "TS:Mucuripe",
#         "CS:Uri Mercado",
#         "CS:Minimercado Bempertim",
#         "CS:Cort Carnes Nobres",
#         "CS:Napadaria",
#         "CS:Aquablu",
#         "PH:Farm\u00e1cia i9",
#         "PH:Farm\u00e1cia TeleJuca",
#         "PH:Pharmapele",
#         "PH:Farm\u00e1cia Aldesul",
#         "PH:Aldesul"
#       ],
#       "complement": "",
#       "pois": [],
#       "valuableZones": []
#     },
#     "suites": [
#       2
#     ],
#     "publicationType": "PREMIUM",
#     "externalId": "QGC3OEKO",
#     "bathrooms": [
#       2
#     ],
#     "usageTypes": [
#       "RESIDENTIAL"
#     ],
#     "totalAreas": [
#       "70"
#     ],
#     "advertiserId": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#     "bedrooms": [
#       2
#     ],
#     "pricingInfos": [
#       {
#         "rentalInfo": {
#           "period": "MONTHLY",
#           "warranties": [],
#           "monthlyRentalTotalPrice": "3430"
#         },
#         "yearlyIptu": "110",
#         "price": "2700",
#         "businessType": "RENTAL",
#         "monthlyCondoFee": "730"
#       }
#     ],
#     "showPrice": true,
#     "status": "ACTIVE",
#     "advertiserContact": {
#       "phones": [
#         "85985685000"
#       ]
#     },
#     "videoTourLink": "",
#     "whatsappNumber": "85985685000",
#     "stamps": []
#   },
#   "account": {
#     "id": "ff52eb4d-636c-e327-d8f0-7e576aa266c6",
#     "name": "DSF Escrit\u00f3rio",
#     "logoUrl": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/vr.images.sp/0f08930e5548898fe535cb43f603302c.jpg",
#     "licenseNumber": "",
#     "showAddress": true,
#     "legacyVivarealId": 229354,
#     "phones": {
#       "primary": "85985685000",
#       "mobile": "85985685000"
#     }
#   },
#   "medias": [
#     {
#       "id": "4002c07c7518e073ce268a04f6cfb04f",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/4002c07c7518e073ce268a04f6cfb04f/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "1d1b1306b5ce2f0947d6f3212388499b",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1d1b1306b5ce2f0947d6f3212388499b/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "b6b93d85eb4308e04691e0c80a1cf109",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/b6b93d85eb4308e04691e0c80a1cf109/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "2456a692845b0a54049dabcff57487ac",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2456a692845b0a54049dabcff57487ac/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "1b191ac0f84a627504c745d6058c3c6e",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1b191ac0f84a627504c745d6058c3c6e/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "2bd97b3c097d26c3a25306e1e86f01f0",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2bd97b3c097d26c3a25306e1e86f01f0/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "5f3fcab5fcdc201c5de248ebafb4f657",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5f3fcab5fcdc201c5de248ebafb4f657/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "f58db1169dccfa16b88d7c7bdfd7df58",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/f58db1169dccfa16b88d7c7bdfd7df58/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "8cff5fa909b6f23dacb9df3f6f9376ac",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/8cff5fa909b6f23dacb9df3f6f9376ac/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "4086958514e35d9311a7a55fa921a56e",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/4086958514e35d9311a7a55fa921a56e/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "a7cdfacd6c4df2abb755185e26a5c586",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/a7cdfacd6c4df2abb755185e26a5c586/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "1017e1fb8f8d7d9bd03689cc8b0f0931",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1017e1fb8f8d7d9bd03689cc8b0f0931/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "2e349bdcb1daa84b78b1e418a67e2271",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/2e349bdcb1daa84b78b1e418a67e2271/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "c37f0eb5cf0bf72e062c7ec2b0b482e4",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/c37f0eb5cf0bf72e062c7ec2b0b482e4/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "04539b4c33850af938371cf6fb897f60",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/04539b4c33850af938371cf6fb897f60/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "5f44be42298deffaf3ba703ae67a32f7",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/5f44be42298deffaf3ba703ae67a32f7/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "43fce6664eff42147447db1624b71193",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/43fce6664eff42147447db1624b71193/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "aeb7dc795d4b8905414be602db3c9558",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/aeb7dc795d4b8905414be602db3c9558/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "d9c7937e70bf381db10a303d897e4d69",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/d9c7937e70bf381db10a303d897e4d69/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "82797a706dfecc3cc92e4186c605c94e",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/82797a706dfecc3cc92e4186c605c94e/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "e8cef6ebf71326719c0ee5ec3a84c938",
#       "url": "https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/e8cef6ebf71326719c0ee5ec3a84c938/{description}.jpg",
#       "type": "IMAGE"
#     }
#   ],
#   "accountLink": {
#     "data": {},
#     "name": "DSF Escrit\u00f3rio",
#     "href": "/229354/dsf-escritorio/",
#     "rel": ""
#   },
#   "link": {
#     "data": {
#       "state": "Cear\u00e1",
#       "city": "Fortaleza",
#       "zone": "Bairros",
#       "neighborhood": "Meireles",
#       "street": "Avenida Desembargador Moreira",
#       "streetNumber": "160"
#     },
#     "name": "Apartamento com 2 Quartos para alugar, 70m\u00b2",
#     "href": "/imovel/apartamento-2-quartos-meireles-bairros-fortaleza-com-garagem-70m2-aluguel-RS2700-id-2562524561/",
#     "rel": ""
#   }
# }

# %% [markdown]
# Para facilitar nossas análises e lidar com os dados, montaremos um *dataframe* contendo os dados obtidos em todas as requisições, isso pode ser feito utilizando o método `from_records` da classe DataFrame, que constrói um *dataframe* a partir de uma lista de objetos com estrutura em comum. Por enquanto, armazenaremos este dataframe em uma lista de dataframes, que será utilizada mais a frente.

# %%
vivareal_df = df.from_records(map(lambda el: el['listing'], listings))
vivareal_dfs = [vivareal_df]

# %%
# sample df from first request
vivareal_df.head()
# Out:
#   displayAddressType                                          amenities  \
# 0                ALL  [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...
# 1                ALL  [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...
# 2                ALL                      [AIR_CONDITIONING, PORCELAIN]
# 3                ALL                                                 []
# 4                ALL                                                 []
#
#   usableAreas       constructionStatus listingType  \
# 0        [70]  ConstructionStatus_NONE        USED
# 1        [60]  ConstructionStatus_NONE        USED
# 2        [35]  ConstructionStatus_NONE        USED
# 3        [33]  ConstructionStatus_NONE        USED
# 4        [30]  ConstructionStatus_NONE        USED
#
#                                          description  \
# 0  IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1  Apartamento Duplex 60 m2, com 02 suítes, total...
# 2  ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3  Salas com piso em porcelanato bianco, com forr...
# 4  COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
#
#                                                title    unitTypes  \
# 0  Apartamento para aluguel tem 70 metros quadrad...  [APARTMENT]
# 1  Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...  [APARTMENT]
# 2  Sala comercial, localização INENARRÁVEL / para...     [OFFICE]
# 3     Scopa Platinum Corporate - Salas amplas com WC     [OFFICE]
# 4  COMPSA - Compartilhamento de Salas - Hora, Exp...     [OFFICE]
#
#         nonActivationReason propertyType unitSubTypes          id    portal  \
# 0  NonActivationReason_NONE         UNIT           []  2562524561  GRUPOZAP
# 1  NonActivationReason_NONE         UNIT           []  2515185773  GRUPOZAP
# 2  NonActivationReason_NONE         UNIT           []  2534494892  GRUPOZAP
# 3  NonActivationReason_NONE         UNIT           []  2516799902  GRUPOZAP
# 4  NonActivationReason_NONE         UNIT     [CLINIC]  2532715897  GRUPOZAP
#
#   parkingSpaces                                            address suites  \
# 0           [2]  {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]
# 1           [1]  {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]
# 2            []  {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []
# 3           [1]  {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []
# 4           [0]  {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]
#
#   publicationType externalId bathrooms     usageTypes totalAreas  \
# 0         PREMIUM   QGC3OEKO       [2]  [RESIDENTIAL]       [70]
# 1         PREMIUM   5WFQM4GZ       [2]  [RESIDENTIAL]       [69]
# 2         PREMIUM   FW367WSA       [1]   [COMMERCIAL]       [35]
# 3         PREMIUM   FQSV6NGN       [1]   [COMMERCIAL]         []
# 4         PREMIUM   GY3AMWXI       [0]   [COMMERCIAL]         []
#
#                            advertiserId bedrooms  \
# 0  ff52eb4d-636c-e327-d8f0-7e576aa266c6      [2]
# 1  a239c50b-0319-1aa0-6ef7-3837586b4063      [2]
# 2  ff52eb4d-636c-e327-d8f0-7e576aa266c6       []
# 3  11c4ded5-8ea5-2404-2183-e5e985813374       []
# 4  2cb4a334-9204-a7c6-6c50-0f503453322a      [0]
#
#                                         pricingInfos  showPrice  status  \
# 0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 1  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 2  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 3  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 4  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
#
#                             advertiserContact videoTourLink whatsappNumber  \
# 0                 {'phones': ['85985685000']}                  85985685000
# 1                 {'phones': ['11981751746']}                  11981751746
# 2                 {'phones': ['85985685000']}                  85985685000
# 3                 {'phones': ['85991180986']}                  85991180986
# 4  {'phones': ['85988312527', '85998340077']}                  85998340077
#
#   stamps
# 0     []
# 1     []
# 2     []
# 3     []
# 4     []

# %% [markdown]
# Abaixo, carregamos um *dataframe* para cada requisição, e salvamos este *dataframe* em uma lista, que será muito útil no passo seguinte.

# %%
for i in trange(1, number_of_vivareal_files):
  fp = open(get_vivareal_file_path(i), "r")
  vivareal_json = json_load(fp)
  vivareal_listings = vivareal_json["search"]["result"]["listings"]
  vivareal_listings = map(lambda el: el['listing'], vivareal_listings)
  vivareal_df = df.from_records(vivareal_listings)
  vivareal_dfs.append(vivareal_df)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 116.39it/s]

# %% [markdown]
# A coluna usageTypes, indica qual a finalidade do imóvel, se é para residir ou se é um imóvel comercial. Para este trabalho, estamos interessados em imóveis residenciais, portanto, analisaremos quais os valores possíveis para este campo, a quantidade de imóveis que não são residenciais, e por fim, droparemos aqueles imóveis que não são residenciais.

# %% [markdown]
# Em posse da lista com todos os *dataframes* para cada requisição, podemos utilizar o método `concat` do pandas. Este método recebe uma lista de dataframes e então cria um único dataframe unindo todos os *dataframes* da lista! Que é exatamente o que queremos aqui :)

# %%
vivareal_df_raw = pd.concat(vivareal_dfs)
print(f"Quantidade de linhas no dataset do vivareal: {len(vivareal_df_raw)}\n\n")
vivareal_df_raw.head()
# Out:
# Quantidade de linhas no dataset do vivareal: 7586
#   displayAddressType                                          amenities  \
# 0                ALL  [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...
# 1                ALL  [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...
# 2                ALL                      [AIR_CONDITIONING, PORCELAIN]
# 3                ALL                                                 []
# 4                ALL                                                 []
#
#   usableAreas       constructionStatus listingType  \
# 0        [70]  ConstructionStatus_NONE        USED
# 1        [60]  ConstructionStatus_NONE        USED
# 2        [35]  ConstructionStatus_NONE        USED
# 3        [33]  ConstructionStatus_NONE        USED
# 4        [30]  ConstructionStatus_NONE        USED
#
#                                          description  \
# 0  IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1  Apartamento Duplex 60 m2, com 02 suítes, total...
# 2  ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3  Salas com piso em porcelanato bianco, com forr...
# 4  COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
#
#                                                title    unitTypes  \
# 0  Apartamento para aluguel tem 70 metros quadrad...  [APARTMENT]
# 1  Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...  [APARTMENT]
# 2  Sala comercial, localização INENARRÁVEL / para...     [OFFICE]
# 3     Scopa Platinum Corporate - Salas amplas com WC     [OFFICE]
# 4  COMPSA - Compartilhamento de Salas - Hora, Exp...     [OFFICE]
#
#         nonActivationReason propertyType unitSubTypes          id    portal  \
# 0  NonActivationReason_NONE         UNIT           []  2562524561  GRUPOZAP
# 1  NonActivationReason_NONE         UNIT           []  2515185773  GRUPOZAP
# 2  NonActivationReason_NONE         UNIT           []  2534494892  GRUPOZAP
# 3  NonActivationReason_NONE         UNIT           []  2516799902  GRUPOZAP
# 4  NonActivationReason_NONE         UNIT     [CLINIC]  2532715897  GRUPOZAP
#
#   parkingSpaces                                            address suites  \
# 0           [2]  {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]
# 1           [1]  {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]
# 2            []  {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []
# 3           [1]  {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []
# 4           [0]  {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]
#
#   publicationType externalId bathrooms     usageTypes totalAreas  \
# 0         PREMIUM   QGC3OEKO       [2]  [RESIDENTIAL]       [70]
# 1         PREMIUM   5WFQM4GZ       [2]  [RESIDENTIAL]       [69]
# 2         PREMIUM   FW367WSA       [1]   [COMMERCIAL]       [35]
# 3         PREMIUM   FQSV6NGN       [1]   [COMMERCIAL]         []
# 4         PREMIUM   GY3AMWXI       [0]   [COMMERCIAL]         []
#
#                            advertiserId bedrooms  \
# 0  ff52eb4d-636c-e327-d8f0-7e576aa266c6      [2]
# 1  a239c50b-0319-1aa0-6ef7-3837586b4063      [2]
# 2  ff52eb4d-636c-e327-d8f0-7e576aa266c6       []
# 3  11c4ded5-8ea5-2404-2183-e5e985813374       []
# 4  2cb4a334-9204-a7c6-6c50-0f503453322a      [0]
#
#                                         pricingInfos  showPrice  status  \
# 0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 1  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 2  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 3  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 4  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
#
#                             advertiserContact videoTourLink whatsappNumber  \
# 0                 {'phones': ['85985685000']}                  85985685000
# 1                 {'phones': ['11981751746']}                  11981751746
# 2                 {'phones': ['85985685000']}                  85985685000
# 3                 {'phones': ['85991180986']}                  85991180986
# 4  {'phones': ['85988312527', '85998340077']}                  85998340077
#
#   stamps
# 0     []
# 1     []
# 2     []
# 3     []
# 4     []

# %% [markdown]
# Abaixo, podemos ver o nome de todas as colunas do DataFrame e seus respectivos tipos.

# %%
vivareal_df_raw.dtypes
# Out:
# displayAddressType     object
# amenities              object
# usableAreas            object
# constructionStatus     object
# listingType            object
# description            object
# title                  object
# unitTypes              object
# nonActivationReason    object
# propertyType           object
# unitSubTypes           object
# id                     object
# portal                 object
# parkingSpaces          object
# address                object
# suites                 object
# publicationType        object
# externalId             object
# bathrooms              object
# usageTypes             object
# totalAreas             object
# advertiserId           object
# bedrooms               object
# pricingInfos           object
# showPrice                bool
# status                 object
# advertiserContact      object
# videoTourLink          object
# whatsappNumber         object
# stamps                 object
# dtype: object

# %% [markdown]
# ### ZapImoveis
#
# Abaixo, repetiremos os mesmos procedimentos com os dados do zap imóveis.

# %%
# filter non-request files
number_of_zapimoveis_files = len(list(filter(lambda e: e.startswith("request-"), os.listdir(ZAP_IMOVEIS_PATH))))

fp = open(get_zapimoveis_file_path(0), "r")
zapimoveis_sample_json = json_load(fp)
fp.close()

# %%
jsonprint(zapimoveis_sample_json)
# Out:
# {
#   "search": {
#     "result": {
#       "listings": [
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "GYM",
#               "POOL",
#               "PLAYGROUND",
#               "SPORTS_COURT",
#               "PARTY_HALL"
#             ],
#             "usableAreas": [
#               "75"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Adriano Freire Im\u00f3veis aluga apartamento no Mont Blanc Residence, com 3 quartos (sendo 2 su\u00edtes), sala de estar e jantar, cozinha, banheiro social, \u00e1rea de servi\u00e7o e 2 vagas de garagem. M\u00f3veis fixos nos quartos e cozinha, vista por cima do Parque do Coc\u00f3. <br><br><br>O condom\u00ednio disp\u00f5e de: Piscina Adulto com Raia, Piscina Infantil, Playground, Sal\u00e3o de Festas, Quadra, Recep\u00e7\u00e3o, Home Theater, Sal\u00e3o de Jogos, Fitness, Lavanderia, Terra\u00e7o e Portaria 24h. <br><br><br>Localiza\u00e7\u00e3o: Av. das Adenanteras, 311, pr\u00f3ximo a Milfrios Distribuidora. <br><br><br>Mais informa\u00e7\u00f5es ou agendamento de visita, fale conosco pelo WhatsApp Comercial: .<br><br><br>Atualizado em",
#             "title": "Apartamento com 3 quartos, no MontBlanc Residence - AP7541",
#             "stamps": [],
#             "createdAt": "2022-05-23T19:48:19.423Z",
#             "floors": [],
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "providerId": "19381",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "unitsOnTheFloor": 0,
#             "legacyId": "",
#             "id": "2563928464",
#             "portal": "GRUPOZAP",
#             "unitFloor": 0,
#             "parkingSpaces": [
#               2
#             ],
#             "updatedAt": "2022-05-23T19:48:20.942Z",
#             "address": {
#               "country": "BR",
#               "zipCode": "60190560",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "311",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.473308,
#                 "source": "GOOGLE",
#                 "lat": -3.753349
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Avenida das Adenanteras",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Cidade 2000",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Cidade 2000",
#               "poisList": [
#                 "CS:Portugalia",
#                 "PH:Farm\u00e1cia Santa Cec\u00edlia",
#                 "CH:Consult\u00f3rio Dr Marcilio e Dra Isabel",
#                 "SC:Ciclo Adventure Fortaleza",
#                 "SC:Ciclope\u00e7as Popular",
#                 "SC:Thesco Bike",
#                 "SC:Caf\u00e9 das Artes",
#                 "SC:manix"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               2
#             ],
#             "publicationType": "STANDARD",
#             "externalId": "AP7541",
#             "bathrooms": [
#               3
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "75"
#             ],
#             "advertiserId": "aaa31266-c13f-74ad-1f85-5efc14307444",
#             "advertiserContact": {
#               "phones": [
#                 "8530132400",
#                 "85981133290"
#               ]
#             },
#             "whatsappNumber": "85981133290",
#             "bedrooms": [
#               3
#             ],
#             "acceptExchange": false,
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "3100"
#                 },
#                 "yearlyIptu": "165",
#                 "price": "2400",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "700"
#               }
#             ],
#             "showPrice": true,
#             "resale": false,
#             "buildings": 0,
#             "capacityLimit": [],
#             "status": "ACTIVE"
#           },
#           "account": {
#             "id": "aaa31266-c13f-74ad-1f85-5efc14307444",
#             "name": "Adriano Freire Im\u00f3veis",
#             "logoUrl": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/vr.images.sp/1cecdaf362f9d7859017d55e50614778.jpg",
#             "licenseNumber": "18703-J-CE",
#             "showAddress": true,
#             "legacyVivarealId": 136066,
#             "legacyZapId": 2053384
#           },
#           "medias": [
#             {
#               "id": "ed8f7f0c812b145ca13c4db052d49cf6",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ed8f7f0c812b145ca13c4db052d49cf6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "10558fa18652a1137a94e53f0e500761",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/10558fa18652a1137a94e53f0e500761/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f6b338059a29e1fe1e667d8765df054e",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f6b338059a29e1fe1e667d8765df054e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "aa6a55f446b21d5284fe7c1406ccd319",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/aa6a55f446b21d5284fe7c1406ccd319/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "06100b50555e3c842977ae598a4a9f83",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/06100b50555e3c842977ae598a4a9f83/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c09411c671a8201c7fb238db3ff5574f",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c09411c671a8201c7fb238db3ff5574f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "82da3c4c53ee4e05566f452a23262cc4",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/82da3c4c53ee4e05566f452a23262cc4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d4803b839fe55fe89612a1f341fd764c",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d4803b839fe55fe89612a1f341fd764c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b6ab469e270c1eba5a36ec5a4a64560f",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b6ab469e270c1eba5a36ec5a4a64560f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b6b427c45a0d72eec9a5a1b495dca9f0",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b6b427c45a0d72eec9a5a1b495dca9f0/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f549ceba1ad932c8d162c03825b3d7a9",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f549ceba1ad932c8d162c03825b3d7a9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ff7c0ca34c5b5a78ee182843ddb4614b",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ff7c0ca34c5b5a78ee182843ddb4614b/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ffd8af9f1033b5b7814d7297f87a1e1e",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ffd8af9f1033b5b7814d7297f87a1e1e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "cb2017cf769d70ff34acdd44f6885741",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/cb2017cf769d70ff34acdd44f6885741/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "Adriano Freire Im\u00f3veis",
#             "href": "/imobiliaria/136066/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "street": "Avenida das Adenanteras",
#               "streetNumber": "311",
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Cidade 2000"
#             },
#             "name": "Apartamento com 3 Quartos para alugar, 75m\u00b2",
#             "href": "/imovel/aluguel-apartamento-3-quartos-com-piscina-cidade-2000-fortaleza-ce-75m2-id-2563928464/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "CONCIERGE_24H",
#               "ELECTRONIC_GATE",
#               "GATED_COMMUNITY",
#               "PETS_ALLOWED"
#             ],
#             "usableAreas": [
#               "130"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Apartamento no bairro de F\u00e1tima com 3 quartos, sendo 2 su\u00edtes, ampla sala, varanda, cozinha, arm\u00e1rios nos quartos. Pr\u00e9dio com elevador, playground, deck, piscina, portaria 24h.<br>Rua Jo\u00e3o Araripe, 120 apto 1003 - A - Edif\u00edcio Village Sunshine Boulevard I",
#             "title": "Excelente apto 3 quartos, sendo 2 su\u00edtes Bairro de F\u00e1tima",
#             "stamps": [],
#             "createdAt": "2022-05-23T18:02:43.478Z",
#             "floors": [],
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "providerId": "",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "unitsOnTheFloor": 0,
#             "legacyId": "",
#             "id": "2563918208",
#             "portal": "GRUPOZAP",
#             "unitFloor": 0,
#             "parkingSpaces": [
#               2
#             ],
#             "updatedAt": "2022-05-23T18:15:22.131Z",
#             "address": {
#               "country": "BR",
#               "zipCode": "60410356",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "120",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.532794,
#                 "source": "GOOGLE",
#                 "lat": -3.759511
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Jo\u00e3o Araripe",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Parreao",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Parre\u00e3o",
#               "poisList": [
#                 "BS:Ponto de \u00d4nibus da Rodovi\u00e1ria de Fortaleza",
#                 "BS:Final da Linha (Vila Uni\u00e3o)",
#                 "TS:Borges de Melo",
#                 "TS:Vila Uni\u00e3o",
#                 "TS:Esta\u00e7\u00e3o F\u00e1tima",
#                 "TS:Final da Linha (Vila Uni\u00e3o)",
#                 "CS:Pingo Doce Cafeteria",
#                 "CS:Delicias de A\u00e7a\u00ed",
#                 "CS:Panificadora E Confeitaria Bom Gosto",
#                 "CS:Panificadora Piamarta",
#                 "CS:Costa Mendes Delicatessen (Damas)",
#                 "PH:Pague Menos (Borges de Melo)",
#                 "PH:Farma Castro",
#                 "PH:Extrafarma (Expedicion\u00e1rios)",
#                 "PH:Farm\u00e1cia Portela",
#                 "PH:Farm\u00e1cia Local"
#               ],
#               "complement": "Edif\u00edcio A Apartamento 1003",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               2
#             ],
#             "publicationType": "PREMIUM",
#             "externalId": "1TV8U1A",
#             "bathrooms": [
#               3
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [],
#             "advertiserId": "5106bb84-0c28-6112-9cec-481f62782e38",
#             "advertiserContact": {
#               "phones": [
#                 "8530239132",
#                 "85999257101"
#               ]
#             },
#             "whatsappNumber": "85999257101",
#             "bedrooms": [
#               3
#             ],
#             "acceptExchange": false,
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [
#                     "SECURITY_DEPOSIT",
#                     "GUARANTOR"
#                   ],
#                   "monthlyRentalTotalPrice": "2350"
#                 },
#                 "yearlyIptu": "0",
#                 "price": "1600",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "750"
#               }
#             ],
#             "showPrice": true,
#             "resale": false,
#             "buildings": 0,
#             "capacityLimit": [],
#             "status": "ACTIVE"
#           },
#           "account": {
#             "id": "5106bb84-0c28-6112-9cec-481f62782e38",
#             "name": "ASSESSORIA JUR. E ADM. DE IM\u00d3VEIS",
#             "licenseNumber": "",
#             "showAddress": true,
#             "legacyVivarealId": 227370,
#             "legacyZapId": 2771871
#           },
#           "medias": [
#             {
#               "id": "2ee34c6b92bceab5b37c398ea6bed650",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/2ee34c6b92bceab5b37c398ea6bed650/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "ASSESSORIA JUR. E ADM. DE IM\u00d3VEIS",
#             "href": "/imobiliaria/227370/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "state": "Cear\u00e1",
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Parre\u00e3o",
#               "street": "Rua Jo\u00e3o Araripe",
#               "streetNumber": "120"
#             },
#             "name": "Apartamento com 3 Quartos para alugar, 130m\u00b2",
#             "href": "/imovel/aluguel-apartamento-3-quartos-com-acesso-24-horas-parreao-fortaleza-ce-130m2-id-2563918208/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [],
#             "usableAreas": [
#               "73"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Excelente localiza\u00e7\u00e3o, com terra\u00e7o, churrasqueira, 01 dormit\u00f3rio , 02 su\u00edtes (sendo uma revers\u00edvel), varanda na sala e na s\u00fa\u00edte, 02 vagas de garagem.",
#             "title": "Excelente localiza\u00e7\u00e3o, com terra\u00e7o, churrasqueira, 01 dormit\u00f3rio , 02 su\u00edtes (sendo uma revers\u00edvel),",
#             "stamps": [],
#             "createdAt": "2022-05-23T23:16:11.096Z",
#             "floors": [],
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "providerId": "43332",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "unitsOnTheFloor": 0,
#             "legacyId": "",
#             "id": "2563941482",
#             "portal": "GRUPOZAP",
#             "unitFloor": 0,
#             "parkingSpaces": [
#               2
#             ],
#             "updatedAt": "2022-05-23T23:19:45.384Z",
#             "address": {
#               "country": "BR",
#               "zipCode": "60115222",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "2055",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.510736,
#                 "source": "GOOGLE",
#                 "lat": -3.740723
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Avenida Rui Barbosa",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Joaquim Tavora",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Joaquim T\u00e1vora",
#               "poisList": [
#                 "BS:\u00d4nibus para Cumbuco",
#                 "TS:Pontes Vieira",
#                 "TS:\u00d4nibus para Cumbuco",
#                 "TS:Esta\u00e7\u00e3o F\u00e1tima",
#                 "CS:Fiorella Panificadora e Confeitaria",
#                 "CS:Biscuiart Festas",
#                 "CS:Head Machine",
#                 "CS:Emp\u00f3rio Caf\u00e9",
#                 "CS:Costa Mendes Delicatessen",
#                 "PH:Farm\u00e1cia Santa Branca",
#                 "PH:Carrefour Drogaria",
#                 "PH:Roval Farm\u00e1cia de Manipula\u00e7\u00e3o",
#                 "PH:Farm\u00e1cia Sobreira",
#                 "PH:Farm\u00e1cia Aldesul"
#               ],
#               "complement": "Edif\u00edcio Alda Cardoso Linhares Apartamento 1903",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               2
#             ],
#             "publicationType": "STANDARD",
#             "externalId": "L2338",
#             "bathrooms": [
#               5
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "73"
#             ],
#             "advertiserId": "21f8bf92-c80f-c0cb-1399-e7287bde5ca1",
#             "advertiserContact": {
#               "phones": [
#                 "8533053000"
#               ]
#             },
#             "whatsappNumber": "",
#             "bedrooms": [
#               3
#             ],
#             "acceptExchange": false,
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "1400"
#                 },
#                 "price": "1400",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "0"
#               }
#             ],
#             "showPrice": true,
#             "resale": false,
#             "buildings": 0,
#             "capacityLimit": [],
#             "status": "ACTIVE"
#           },
#           "account": {
#             "id": "21f8bf92-c80f-c0cb-1399-e7287bde5ca1",
#             "name": "CESAR REGO IMOVEIS",
#             "logoUrl": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/vr.images.sp/9304c81baad5a4fc65ed267253e0b687.jpg",
#             "licenseNumber": "03856-F-CE",
#             "showAddress": true,
#             "legacyVivarealId": 229039,
#             "legacyZapId": 2573505
#           },
#           "medias": [
#             {
#               "id": "21804e2325dff0b0f1ffcd0ca7a7374e",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/21804e2325dff0b0f1ffcd0ca7a7374e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "70c8a210e31593368ba33800eb1ec1da",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/70c8a210e31593368ba33800eb1ec1da/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "159d83ddb711010d745f8a9a8c08f511",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/159d83ddb711010d745f8a9a8c08f511/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "fc224967eb8a6bd884eb29931ac7efdd",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/fc224967eb8a6bd884eb29931ac7efdd/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "76385127533afd4ae9d86a8e302deb54",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/76385127533afd4ae9d86a8e302deb54/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c30487e9234bee049d85dfb21bcfb394",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c30487e9234bee049d85dfb21bcfb394/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "692017a78e621a7e1734ac4c7b55a1a2",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/692017a78e621a7e1734ac4c7b55a1a2/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e31082009138a8e36524da2ea5e9370b",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e31082009138a8e36524da2ea5e9370b/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "cc4c7f609b23c5c5cbb95cda9b24482b",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/cc4c7f609b23c5c5cbb95cda9b24482b/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e58dd7fa219bade1c6a9388a2d0f96ab",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e58dd7fa219bade1c6a9388a2d0f96ab/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d798ded9aad40098fbf5363f74f9e424",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d798ded9aad40098fbf5363f74f9e424/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "29a58f4c0c6fec128a010e5ba6635753",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/29a58f4c0c6fec128a010e5ba6635753/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "05b89eb4d853452c780e55b6adc2fb32",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/05b89eb4d853452c780e55b6adc2fb32/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b40b30b2f7e207837d4c6a3b0a4e9099",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b40b30b2f7e207837d4c6a3b0a4e9099/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "bea766f344743abb8f202c27ba9340f2",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/bea766f344743abb8f202c27ba9340f2/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1f53e6be2678eca2c6f8326a755cf2a6",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/1f53e6be2678eca2c6f8326a755cf2a6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e5492152ba3ba4df26c14bb62bc59fd9",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e5492152ba3ba4df26c14bb62bc59fd9/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ef4ea0f67260f2b8a1088ddc14dbf172",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ef4ea0f67260f2b8a1088ddc14dbf172/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "69dd5ae4834873085334aec58c83aefd",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/69dd5ae4834873085334aec58c83aefd/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "6b16aee1eb2d80b0c5d7a52cfda9be09",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/6b16aee1eb2d80b0c5d7a52cfda9be09/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a0fc7fce3c9eee2e667179a3231344cf",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/a0fc7fce3c9eee2e667179a3231344cf/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "cc8b7083bcdc727cd13aa5238b86997a",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/cc8b7083bcdc727cd13aa5238b86997a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5399de1d78b4e1efe74312ebd925af67",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/5399de1d78b4e1efe74312ebd925af67/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2c2f38da0a141d3e029ee3c9a48dc0bb",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/2c2f38da0a141d3e029ee3c9a48dc0bb/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "be1def4b59e0bf9ee8351724c368dfc4",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/be1def4b59e0bf9ee8351724c368dfc4/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "c75bd91960d5f334251c4c8fbf61f193",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c75bd91960d5f334251c4c8fbf61f193/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "dd6cba01cba7fd91b13d9adea00845e8",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/dd6cba01cba7fd91b13d9adea00845e8/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "CESAR REGO IMOVEIS",
#             "href": "/imobiliaria/229039/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Joaquim Tavora",
#               "street": "Avenida Rui Barbosa",
#               "streetNumber": "2055",
#               "state": "Cear\u00e1"
#             },
#             "name": "Apartamento com 3 Quartos para alugar, 73m\u00b2",
#             "href": "/imovel/aluguel-apartamento-3-quartos-joaquim-tavora-fortaleza-ce-73m2-id-2563941482/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [],
#             "usableAreas": [
#               "68"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "\u00d3timo apartamento com 68m\u00b2, com recep\u00e7\u00e3o, academia, sal\u00e3o de festas, varanda, 3 quartos ( sendo 1 su\u00edte), Cond R$ 460,00 (sujeito a altera\u00e7\u00f5es).",
#             "title": "\u00d3timo apartamento com 68m\u00b2, com recep\u00e7\u00e3o, academia, sal\u00e3o de festas, varanda, 3 quartos ( sendo 1 su",
#             "stamps": [],
#             "createdAt": "2022-05-23T23:16:11.109Z",
#             "floors": [],
#             "unitTypes": [
#               "APARTMENT"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "providerId": "43332",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "unitsOnTheFloor": 0,
#             "legacyId": "",
#             "id": "2563938888",
#             "portal": "GRUPOZAP",
#             "unitFloor": 0,
#             "parkingSpaces": [
#               2
#             ],
#             "updatedAt": "2022-05-23T23:22:49.370Z",
#             "address": {
#               "country": "BR",
#               "zipCode": "60125150",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "1000",
#               "level": "STREET",
#               "precision": "ROOFTOP",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.50016,
#                 "source": "GOOGLE",
#                 "lat": -3.733964
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Osvaldo Cruz",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Meireles",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Meireles",
#               "poisList": [
#                 "BS:\u00d4nibus para Cumbuco",
#                 "TS:\u00d4nibus para Cumbuco",
#                 "TS:Papicu",
#                 "TS:Ant\u00f4nio Sales",
#                 "CS:P\u00e3o e P\u00e3es",
#                 "CS:Le Gumis",
#                 "CS:Minimercado Bempertim",
#                 "CS:Uri Mercado",
#                 "CS:Costa Mendes Delicatessen",
#                 "PH:Pharmapele",
#                 "PH:Farm\u00e1cia Aldesul",
#                 "PH:Farm\u00e1cia TeleJuca",
#                 "PH:Farm\u00e1cia i9",
#                 "PH:Farm\u00e1cia Santa Branca"
#               ],
#               "complement": "Edif\u00edcio Place Des Cysne Apartamento 1002",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               1
#             ],
#             "publicationType": "STANDARD",
#             "externalId": "L2037",
#             "bathrooms": [
#               3
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "68"
#             ],
#             "advertiserId": "21f8bf92-c80f-c0cb-1399-e7287bde5ca1",
#             "advertiserContact": {
#               "phones": [
#                 "8533053000"
#               ]
#             },
#             "whatsappNumber": "",
#             "bedrooms": [
#               3
#             ],
#             "acceptExchange": false,
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [],
#                   "monthlyRentalTotalPrice": "1600"
#                 },
#                 "price": "1600",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "0"
#               }
#             ],
#             "showPrice": true,
#             "resale": false,
#             "buildings": 0,
#             "capacityLimit": [],
#             "status": "ACTIVE"
#           },
#           "account": {
#             "id": "21f8bf92-c80f-c0cb-1399-e7287bde5ca1",
#             "name": "CESAR REGO IMOVEIS",
#             "logoUrl": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/vr.images.sp/9304c81baad5a4fc65ed267253e0b687.jpg",
#             "licenseNumber": "03856-F-CE",
#             "showAddress": true,
#             "legacyVivarealId": 229039,
#             "legacyZapId": 2573505
#           },
#           "medias": [
#             {
#               "id": "2c1ce4ff608351c1a4443d83acbb5a1e",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/2c1ce4ff608351c1a4443d83acbb5a1e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "26b71945445591dc7901245e62c7ed35",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/26b71945445591dc7901245e62c7ed35/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "4291ce966eba2a4368ef1350a9a83aed",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/4291ce966eba2a4368ef1350a9a83aed/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b98e9afc844a3eedab65f7a651f60182",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b98e9afc844a3eedab65f7a651f60182/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "12e1035efb013e75f385ab36961a6682",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/12e1035efb013e75f385ab36961a6682/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e6e9632ba4b0f958cc0f54827093232f",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e6e9632ba4b0f958cc0f54827093232f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "fba54af3bae7df14e2ea31f2e3460af1",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/fba54af3bae7df14e2ea31f2e3460af1/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "dfd23c27410cef7a17cce841fdc2cac1",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/dfd23c27410cef7a17cce841fdc2cac1/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f3ec13b8bd0c3c79a2560cfa8c3fef88",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f3ec13b8bd0c3c79a2560cfa8c3fef88/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "e978c51432a53221d5724f1eae7bc0f8",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e978c51432a53221d5724f1eae7bc0f8/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "b273e0e41a6ca26a61d258577b59df1c",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b273e0e41a6ca26a61d258577b59df1c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "26af77567471bbc69a413b5e5162ef9c",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/26af77567471bbc69a413b5e5162ef9c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ad865a7f5c733bc227d62def3d4ab753",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ad865a7f5c733bc227d62def3d4ab753/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "1b0eee7e07129d463063c8b9d8106d59",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/1b0eee7e07129d463063c8b9d8106d59/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "09f5ba18afc6960e95691a1bb0bdee14",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/09f5ba18afc6960e95691a1bb0bdee14/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "d3e4e68ddc0f63350fe5e6899be5d075",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d3e4e68ddc0f63350fe5e6899be5d075/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "783806df10e04be5615214c7609a4db6",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/783806df10e04be5615214c7609a4db6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "8060ff06751024cab242584edaeefd19",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/8060ff06751024cab242584edaeefd19/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "0b7c038e74c19a38dce08e093f7e9e81",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/0b7c038e74c19a38dce08e093f7e9e81/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a047d949c40c253c1172e790d40b2945",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/a047d949c40c253c1172e790d40b2945/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "2ffa1fba7fb7fe49db5586229a854d0c",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/2ffa1fba7fb7fe49db5586229a854d0c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ce613ca887458352f32588d87f32883f",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ce613ca887458352f32588d87f32883f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "df1a9c75134bee436b0941c13d157974",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/df1a9c75134bee436b0941c13d157974/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "bdf1182754ecb0a55b83d034c1146a84",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/bdf1182754ecb0a55b83d034c1146a84/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5db58f0db2e9bcae27a881dcf6951ec5",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/5db58f0db2e9bcae27a881dcf6951ec5/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "0ec38b542530f7b37360ab6b01a474a6",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/0ec38b542530f7b37360ab6b01a474a6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "db403e58c2177ac3c4f6d322a4d4e28f",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/db403e58c2177ac3c4f6d322a4d4e28f/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "06382c442ded712cd8dda528757b51db",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/06382c442ded712cd8dda528757b51db/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "0844356ee466b662c934a5c520f80f0e",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/0844356ee466b662c934a5c520f80f0e/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "53b29dc44b8e6e85c642ea79bed3f8fb",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/53b29dc44b8e6e85c642ea79bed3f8fb/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "5cf821af72b5337d0ee68763302af305",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/5cf821af72b5337d0ee68763302af305/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "f83118c3a729bcc85bbc879fb98dd013",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f83118c3a729bcc85bbc879fb98dd013/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "a47f026d7202fb94cd1fb1d608fbdd9a",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/a47f026d7202fb94cd1fb1d608fbdd9a/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "ec9602eed01f2c1ef1bde3246f73a67d",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ec9602eed01f2c1ef1bde3246f73a67d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "6cfda8ad62dc9a4c6f2ef9819587b08c",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/6cfda8ad62dc9a4c6f2ef9819587b08c/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "7cd7e79705d1ae31130f24f57e38f82d",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/7cd7e79705d1ae31130f24f57e38f82d/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "673a44e6be949c26fb47cefc52d89fa6",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/673a44e6be949c26fb47cefc52d89fa6/{description}.jpg",
#               "type": "IMAGE"
#             },
#             {
#               "id": "214394e845a9b4083ebee9f7a42d7786",
#               "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/214394e845a9b4083ebee9f7a42d7786/{description}.jpg",
#               "type": "IMAGE"
#             }
#           ],
#           "accountLink": {
#             "data": {},
#             "name": "CESAR REGO IMOVEIS",
#             "href": "/imobiliaria/229039/",
#             "rel": ""
#           },
#           "link": {
#             "data": {
#               "city": "Fortaleza",
#               "zone": "Bairros",
#               "neighborhood": "Meireles",
#               "street": "Rua Osvaldo Cruz",
#               "streetNumber": "1000",
#               "state": "Cear\u00e1"
#             },
#             "name": "Apartamento com 3 Quartos para alugar, 68m\u00b2",
#             "href": "/imovel/aluguel-apartamento-3-quartos-meireles-fortaleza-ce-68m2-id-2563938888/",
#             "rel": ""
#           }
#         },
#         {
#           "listing": {
#             "displayAddressType": "ALL",
#             "amenities": [
#               "PETS_ALLOWED"
#             ],
#             "usableAreas": [
#               "276"
#             ],
#             "constructionStatus": "ConstructionStatus_NONE",
#             "listingType": "USED",
#             "description": "Casa com 276m2 a uma quadra da Av. Jovita Feitosa com 3 quartos ( sendo uma suite, dois com arm\u00e1rios ), sala ampla, cozinha, wc social, \u00e1rea de servi\u00e7os, quintal, depend\u00eancia de empregada, quator vagas de garagem.<br><br>Rua Antero Coelho, 71 - Parquel\u00e2ndia.<br><br>Loca\u00e7\u00e3o e chaves pela fax Imobili\u00e1ria.",
#             "title": "Casa com 276m2 a uma quadra da Av. Jovita Feitosa",
#             "stamps": [],
#             "createdAt": "2022-05-23T18:42:50.258Z",
#             "floors": [],
#             "unitTypes": [
#               "HOME"
#             ],
#             "nonActivationReason": "NonActivationReason_NONE",
#             "providerId": "",
#             "propertyType": "UNIT",
#             "unitSubTypes": [],
#             "unitsOnTheFloor": 0,
#             "legacyId": "",
#             "id": "2563921331",
#             "portal": "GRUPOZAP",
#             "unitFloor": 0,
#             "parkingSpaces": [
#               3
#             ],
#             "updatedAt": "2022-05-23T19:21:27.265Z",
#             "address": {
#               "country": "BR",
#               "zipCode": "60450490",
#               "geoJson": "",
#               "city": "Fortaleza",
#               "streetNumber": "71",
#               "level": "STREET",
#               "precision": "RANGE_INTERPOLATED",
#               "confidence": "VALID_STREET",
#               "stateAcronym": "CE",
#               "source": "CORREIOS",
#               "point": {
#                 "lon": -38.551668,
#                 "source": "GOOGLE",
#                 "lat": -3.738422
#               },
#               "ibgeCityId": "",
#               "zone": "",
#               "street": "Rua Antero Coelho",
#               "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Parquelandia",
#               "district": "",
#               "name": "",
#               "state": "Cear\u00e1",
#               "neighborhood": "Parque Arax\u00e1",
#               "poisList": [
#                 "BS:Esta\u00e7\u00e3o Instituto dos Cegos",
#                 "BS:Esta\u00e7\u00e3o Cruz Saldanha",
#                 "BS:Esta\u00e7\u00e3o Padre Frota",
#                 "BS:Esta\u00e7\u00e3o Dom Lino",
#                 "BS:Esta\u00e7\u00e3o Jos\u00e9 Sombra",
#                 "TS:Esta\u00e7\u00e3o Instituto dos Cegos",
#                 "TS:Esta\u00e7\u00e3o Cruz Saldanha",
#                 "TS:Esta\u00e7\u00e3o Padre Frota",
#                 "TS:Esta\u00e7\u00e3o Dom Lino",
#                 "TS:Esta\u00e7\u00e3o Jos\u00e9 Sombra",
#                 "CS:Companhia do P\u00e3o P\u00e3es & Doces",
#                 "CS:Panificadora Pamil",
#                 "CS:Panificadora Arax\u00e1",
#                 "CS:Padaria Parquel\u00e2ndia",
#                 "CS:V\u00f3 Maria Padaria",
#                 "PH:Farm\u00e1cia Cura Ativa",
#                 "PH:Pague Menos (Rodolfo Te\u00f3filo)",
#                 "PH:Pague Menos (Bela Vista)",
#                 "PH:Pague Menos (Jo\u00e3o Pessoa )",
#                 "PH:Farmacia Pague Menos"
#               ],
#               "complement": "",
#               "pois": [],
#               "valuableZones": []
#             },
#             "suites": [
#               1
#             ],
#             "publicationType": "PREMIUM",
#             "externalId": "JP302130",
#             "bathrooms": [
#               3
#             ],
#             "usageTypes": [
#               "RESIDENTIAL"
#             ],
#             "totalAreas": [
#               "276"
#             ],
#             "advertiserId": "87f26ab6-e5ef-7460-ae50-b999a79937de",
#             "advertiserContact": {
#               "phones": [
#                 "8532244445",
#                 "85991418248"
#               ]
#             },
#             "whatsappNumber": "85991418248",
#             "bedrooms": [
#               3
#             ],
#             "acceptExchange": false,
#             "pricingInfos": [
#               {
#                 "rentalInfo": {
#                   "period": "MONTHLY",
#                   "warranties": [
#                     "GUARANTEE_LETTER",
#                     "INSURANCE_GUARANTEE",
#                     "GUARANTOR",
#                     "SECURITY_DEPOSIT"
#                   ],
#                   "monthlyRentalTotalPrice": "2200"
#                 },
#                 "yearlyIptu": "0",
#                 "price": "2200",
#                 "businessType": "RENTAL",
#                 "monthlyCondoFee": "0"
# ...
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "ecff7cc6ca54c13a6b1a35a33bfb598d",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ecff7cc6ca54c13a6b1a35a33bfb598d/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "533e82e6b77ef73ff36f5e5301a760bc",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/533e82e6b77ef73ff36f5e5301a760bc/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "75381d0db5012d037da74bc9493def80",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/75381d0db5012d037da74bc9493def80/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "c8113f5e338a34b15f59802ae1bdaf59",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c8113f5e338a34b15f59802ae1bdaf59/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "97982a0d5f95bb5a4f104a6ede1c572d",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/97982a0d5f95bb5a4f104a6ede1c572d/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "c2a58d3451b6bdb29c56f0917a52faed",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c2a58d3451b6bdb29c56f0917a52faed/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "24dbc534ec8617ae85eb74036d1e1274",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/24dbc534ec8617ae85eb74036d1e1274/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "d428605b51bc04f0b21a4506fea5cf81",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d428605b51bc04f0b21a4506fea5cf81/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "1d8a70c27fac35bf38acb0e07bb8c067",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/1d8a70c27fac35bf38acb0e07bb8c067/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "93cac728f594f4faa1c8d58c326f54a7",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/93cac728f594f4faa1c8d58c326f54a7/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "3d483d0b7807e1adbdb2b8fe06ea6247",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/3d483d0b7807e1adbdb2b8fe06ea6247/{description}.jpg",
#                 "type": "IMAGE"
#               }
#             ],
#             "accountLink": {
#               "data": {},
#               "name": "Fernando A. R. J\u00fanior",
#               "href": "/imobiliaria/563037/",
#               "rel": ""
#             },
#             "link": {
#               "data": {
#                 "streetNumber": "980",
#                 "state": "Cear\u00e1",
#                 "city": "Fortaleza",
#                 "zone": "Bairros",
#                 "neighborhood": "Aldeota",
#                 "street": "Rua Nunes Valente"
#               },
#               "name": "Loja / Sal\u00e3o / Ponto Comercial para venda ou aluguel, 680m\u00b2",
#               "href": "/imovel/venda-loja-salao-aldeota-fortaleza-ce-680m2-id-2535231175/",
#               "rel": ""
#             }
#           },
#           {
#             "listing": {
#               "displayAddressType": "ALL",
#               "amenities": [],
#               "usableAreas": [
#                 "140"
#               ],
#               "constructionStatus": "ConstructionStatus_NONE",
#               "listingType": "USED",
#               "description": "Condom\u00ednio dos Querubins! Excelente apartamento com 3 quartos, sendo 1 su\u00edte com closet, wc social, depend\u00eancia completa, varanda, arm\u00e1rios, 2 vagas, \u00e1rea privativa 140,49m\u00b2. Condom\u00ednio disp\u00f5e de playground, quadra, sal\u00e3o de festa, 2 elevadores, portaria24 horas, circuito interno de c\u00e2meras (\u00e1rea comum). Tudo isso localizado na Rua Pascoal de Castro Alves, pr\u00f3ximo a escolas, supermercados, farm\u00e1cias e muito mais.",
#               "title": "Condom\u00ednio dos Querubins! Excelente apartamento com 3 quartos, sendo 1 su\u00edte com closet, wc social,",
#               "stamps": [
#                 "DATAZAP_APPROVED"
#               ],
#               "createdAt": "2022-01-19T05:54:26.051Z",
#               "floors": [],
#               "unitTypes": [
#                 "APARTMENT"
#               ],
#               "nonActivationReason": "NonActivationReason_NONE",
#               "providerId": "11540",
#               "propertyType": "UNIT",
#               "unitSubTypes": [],
#               "unitsOnTheFloor": 0,
#               "legacyId": "",
#               "id": "2548343758",
#               "portal": "GRUPOZAP",
#               "unitFloor": 0,
#               "parkingSpaces": [
#                 0
#               ],
#               "updatedAt": "2022-05-11T23:45:09.364Z",
#               "address": {
#                 "country": "BR",
#                 "zipCode": "60181225",
#                 "geoJson": "",
#                 "city": "Fortaleza",
#                 "streetNumber": "51",
#                 "level": "STREET",
#                 "precision": "ROOFTOP",
#                 "confidence": "VALID_STREET",
#                 "stateAcronym": "CE",
#                 "source": "CORREIOS",
#                 "point": {
#                   "lon": -38.481494,
#                   "source": "GOOGLE",
#                   "lat": -3.731376
#                 },
#                 "ibgeCityId": "",
#                 "zone": "",
#                 "street": "Rua Pascoal de Castro Alves",
#                 "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Vicente Pinzon",
#                 "district": "",
#                 "name": "",
#                 "state": "Cear\u00e1",
#                 "neighborhood": "Vicente Pinzon",
#                 "poisList": [
#                   "TS:Mucuripe",
#                   "TS:Papicu",
#                   "TS:Iate",
#                   "CS:Padaria Primeira Linha",
#                   "CS:Cort Carnes Nobres",
#                   "CS:Napadaria",
#                   "CS:Uri Mercado",
#                   "CS:Minimercado Bempertim",
#                   "PH:Aldesul",
#                   "PH:Farm\u00e1cia Tele Juc\u00e1",
#                   "PH:Farm\u00e1cia TeleJuca",
#                   "PH:Farm\u00e1cia i9",
#                   "PH:Farm\u00e1cia Aldesul",
#                   "VP:Faro Fino"
#                 ],
#                 "complement": "Condom\u00ednio dos Querubins Apartamento 301",
#                 "pois": [],
#                 "valuableZones": []
#               },
#               "suites": [
#                 1
#               ],
#               "publicationType": "SUPER_PREMIUM",
#               "externalId": "L3701",
#               "bathrooms": [
#                 4
#               ],
#               "usageTypes": [
#                 "RESIDENTIAL"
#               ],
#               "totalAreas": [
#                 "140"
#               ],
#               "advertiserId": "c1fee7e4-fa79-f695-7ce8-514a5578ca9d",
#               "advertiserContact": {
#                 "phones": [
#                   "8540110800",
#                   "85981840046"
#                 ]
#               },
#               "whatsappNumber": "85981840046",
#               "bedrooms": [
#                 3
#               ],
#               "acceptExchange": false,
#               "pricingInfos": [
#                 {
#                   "rentalInfo": {
#                     "period": "MONTHLY",
#                     "warranties": [],
#                     "monthlyRentalTotalPrice": "2200"
#                   },
#                   "price": "900",
#                   "businessType": "RENTAL",
#                   "monthlyCondoFee": "1300"
#                 }
#               ],
#               "showPrice": true,
#               "resale": false,
#               "buildings": 0,
#               "capacityLimit": [],
#               "status": "ACTIVE"
#             },
#             "account": {
#               "id": "c1fee7e4-fa79-f695-7ce8-514a5578ca9d",
#               "name": "Imobili\u00e1ria Torres de Melo Neto LTDA",
#               "logoUrl": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/vr.images.sp/e378c2d2bbef7af6dc70a643f5eac907.jpg",
#               "licenseNumber": "01365-J-CE",
#               "showAddress": true,
#               "legacyVivarealId": 58187,
#               "legacyZapId": 2551663
#             },
#             "medias": [
#               {
#                 "id": "cecb0bd9b71e54c9cbff9751389a105e",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/cecb0bd9b71e54c9cbff9751389a105e/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "0cf472358b1af92bdb071582386efaec",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/0cf472358b1af92bdb071582386efaec/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "20ce2dbc968a00fb4efc2d6078f359b8",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/20ce2dbc968a00fb4efc2d6078f359b8/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "b22ce9ee7cae20479ab8b7a07f8f9f1e",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b22ce9ee7cae20479ab8b7a07f8f9f1e/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "a179f963d946849a18ac099240078aff",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/a179f963d946849a18ac099240078aff/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "45d8f024c719ace59010dc0da02943fd",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/45d8f024c719ace59010dc0da02943fd/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "e4fcf70180f13b51f13c9d5b84c69e70",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/e4fcf70180f13b51f13c9d5b84c69e70/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "2fb44f78b36f9e1d1ef887ec3b0d1a85",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/2fb44f78b36f9e1d1ef887ec3b0d1a85/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "505501209867461b7cd18aa6c33f8ccd",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/505501209867461b7cd18aa6c33f8ccd/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "38a5bda58a519ae22aec8756c9c6fe9e",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/38a5bda58a519ae22aec8756c9c6fe9e/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "273ecbee610a5ba721a2d431ee8558a8",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/273ecbee610a5ba721a2d431ee8558a8/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "57b2e7bcb1642f2bee885dcc2524c3c6",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/57b2e7bcb1642f2bee885dcc2524c3c6/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "8d6040e2d77de26eb674dd60647c9afd",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/8d6040e2d77de26eb674dd60647c9afd/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "7f66eea0a330239fa80075fce60d274d",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/7f66eea0a330239fa80075fce60d274d/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "0bf982fcea32be070057e020e52e97dd",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/0bf982fcea32be070057e020e52e97dd/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "5ccc21a13b3a88c9472c28d5604903cb",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/5ccc21a13b3a88c9472c28d5604903cb/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "d2ffbd6a9f90370cbe5456f97476de91",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d2ffbd6a9f90370cbe5456f97476de91/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "c49db793e90534317832c992b277dfe2",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c49db793e90534317832c992b277dfe2/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "a5cc50df29928b533c29a100e84ab652",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/a5cc50df29928b533c29a100e84ab652/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "d80cc72062372cee8e100da8a5ad3e48",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d80cc72062372cee8e100da8a5ad3e48/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "6f3da67606f7d3d17c0d53c8e7a2c17e",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/6f3da67606f7d3d17c0d53c8e7a2c17e/{description}.jpg",
#                 "type": "IMAGE"
#               },
#               {
#                 "id": "9db34a820781c201bed6bd86681879c9",
#                 "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/9db34a820781c201bed6bd86681879c9/{description}.jpg",
#                 "type": "IMAGE"
#               }
#             ],
#             "accountLink": {
#               "data": {},
#               "name": "Imobili\u00e1ria Torres de Melo Neto LTDA",
#               "href": "/imobiliaria/58187/",
#               "rel": ""
#             },
#             "link": {
#               "data": {
#                 "state": "Cear\u00e1",
#                 "city": "Fortaleza",
#                 "zone": "Bairros",
#                 "neighborhood": "Vicente Pinzon",
#                 "street": "Rua Pascoal de Castro Alves",
#                 "streetNumber": "51"
#               },
#               "name": "Apartamento com 3 Quartos para alugar, 140m\u00b2",
#               "href": "/imovel/aluguel-apartamento-3-quartos-vicente-pinzon-fortaleza-ce-140m2-id-2548343758/",
#               "rel": ""
#             }
#           }
#         ]
#       },
#       "totalCount": 167
#     }
#   }
# }

# %%
listings = zapimoveis_sample_json["search"]["result"]["listings"]
jsonprint(listings[0])
# Out:
# {
#   "listing": {
#     "displayAddressType": "ALL",
#     "amenities": [
#       "GYM",
#       "POOL",
#       "PLAYGROUND",
#       "SPORTS_COURT",
#       "PARTY_HALL"
#     ],
#     "usableAreas": [
#       "75"
#     ],
#     "constructionStatus": "ConstructionStatus_NONE",
#     "listingType": "USED",
#     "description": "Adriano Freire Im\u00f3veis aluga apartamento no Mont Blanc Residence, com 3 quartos (sendo 2 su\u00edtes), sala de estar e jantar, cozinha, banheiro social, \u00e1rea de servi\u00e7o e 2 vagas de garagem. M\u00f3veis fixos nos quartos e cozinha, vista por cima do Parque do Coc\u00f3. <br><br><br>O condom\u00ednio disp\u00f5e de: Piscina Adulto com Raia, Piscina Infantil, Playground, Sal\u00e3o de Festas, Quadra, Recep\u00e7\u00e3o, Home Theater, Sal\u00e3o de Jogos, Fitness, Lavanderia, Terra\u00e7o e Portaria 24h. <br><br><br>Localiza\u00e7\u00e3o: Av. das Adenanteras, 311, pr\u00f3ximo a Milfrios Distribuidora. <br><br><br>Mais informa\u00e7\u00f5es ou agendamento de visita, fale conosco pelo WhatsApp Comercial: .<br><br><br>Atualizado em",
#     "title": "Apartamento com 3 quartos, no MontBlanc Residence - AP7541",
#     "stamps": [],
#     "createdAt": "2022-05-23T19:48:19.423Z",
#     "floors": [],
#     "unitTypes": [
#       "APARTMENT"
#     ],
#     "nonActivationReason": "NonActivationReason_NONE",
#     "providerId": "19381",
#     "propertyType": "UNIT",
#     "unitSubTypes": [],
#     "unitsOnTheFloor": 0,
#     "legacyId": "",
#     "id": "2563928464",
#     "portal": "GRUPOZAP",
#     "unitFloor": 0,
#     "parkingSpaces": [
#       2
#     ],
#     "updatedAt": "2022-05-23T19:48:20.942Z",
#     "address": {
#       "country": "BR",
#       "zipCode": "60190560",
#       "geoJson": "",
#       "city": "Fortaleza",
#       "streetNumber": "311",
#       "level": "STREET",
#       "precision": "ROOFTOP",
#       "confidence": "VALID_STREET",
#       "stateAcronym": "CE",
#       "source": "CORREIOS",
#       "point": {
#         "lon": -38.473308,
#         "source": "GOOGLE",
#         "lat": -3.753349
#       },
#       "ibgeCityId": "",
#       "zone": "",
#       "street": "Avenida das Adenanteras",
#       "locationId": "BR>Ceara>NULL>Fortaleza>Barrios>Cidade 2000",
#       "district": "",
#       "name": "",
#       "state": "Cear\u00e1",
#       "neighborhood": "Cidade 2000",
#       "poisList": [
#         "CS:Portugalia",
#         "PH:Farm\u00e1cia Santa Cec\u00edlia",
#         "CH:Consult\u00f3rio Dr Marcilio e Dra Isabel",
#         "SC:Ciclo Adventure Fortaleza",
#         "SC:Ciclope\u00e7as Popular",
#         "SC:Thesco Bike",
#         "SC:Caf\u00e9 das Artes",
#         "SC:manix"
#       ],
#       "complement": "",
#       "pois": [],
#       "valuableZones": []
#     },
#     "suites": [
#       2
#     ],
#     "publicationType": "STANDARD",
#     "externalId": "AP7541",
#     "bathrooms": [
#       3
#     ],
#     "usageTypes": [
#       "RESIDENTIAL"
#     ],
#     "totalAreas": [
#       "75"
#     ],
#     "advertiserId": "aaa31266-c13f-74ad-1f85-5efc14307444",
#     "advertiserContact": {
#       "phones": [
#         "8530132400",
#         "85981133290"
#       ]
#     },
#     "whatsappNumber": "85981133290",
#     "bedrooms": [
#       3
#     ],
#     "acceptExchange": false,
#     "pricingInfos": [
#       {
#         "rentalInfo": {
#           "period": "MONTHLY",
#           "warranties": [],
#           "monthlyRentalTotalPrice": "3100"
#         },
#         "yearlyIptu": "165",
#         "price": "2400",
#         "businessType": "RENTAL",
#         "monthlyCondoFee": "700"
#       }
#     ],
#     "showPrice": true,
#     "resale": false,
#     "buildings": 0,
#     "capacityLimit": [],
#     "status": "ACTIVE"
#   },
#   "account": {
#     "id": "aaa31266-c13f-74ad-1f85-5efc14307444",
#     "name": "Adriano Freire Im\u00f3veis",
#     "logoUrl": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/vr.images.sp/1cecdaf362f9d7859017d55e50614778.jpg",
#     "licenseNumber": "18703-J-CE",
#     "showAddress": true,
#     "legacyVivarealId": 136066,
#     "legacyZapId": 2053384
#   },
#   "medias": [
#     {
#       "id": "ed8f7f0c812b145ca13c4db052d49cf6",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ed8f7f0c812b145ca13c4db052d49cf6/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "10558fa18652a1137a94e53f0e500761",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/10558fa18652a1137a94e53f0e500761/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "f6b338059a29e1fe1e667d8765df054e",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f6b338059a29e1fe1e667d8765df054e/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "aa6a55f446b21d5284fe7c1406ccd319",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/aa6a55f446b21d5284fe7c1406ccd319/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "06100b50555e3c842977ae598a4a9f83",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/06100b50555e3c842977ae598a4a9f83/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "c09411c671a8201c7fb238db3ff5574f",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/c09411c671a8201c7fb238db3ff5574f/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "82da3c4c53ee4e05566f452a23262cc4",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/82da3c4c53ee4e05566f452a23262cc4/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "d4803b839fe55fe89612a1f341fd764c",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/d4803b839fe55fe89612a1f341fd764c/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "b6ab469e270c1eba5a36ec5a4a64560f",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b6ab469e270c1eba5a36ec5a4a64560f/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "b6b427c45a0d72eec9a5a1b495dca9f0",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/b6b427c45a0d72eec9a5a1b495dca9f0/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "f549ceba1ad932c8d162c03825b3d7a9",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/f549ceba1ad932c8d162c03825b3d7a9/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "ff7c0ca34c5b5a78ee182843ddb4614b",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ff7c0ca34c5b5a78ee182843ddb4614b/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "ffd8af9f1033b5b7814d7297f87a1e1e",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/ffd8af9f1033b5b7814d7297f87a1e1e/{description}.jpg",
#       "type": "IMAGE"
#     },
#     {
#       "id": "cb2017cf769d70ff34acdd44f6885741",
#       "url": "https://resizedimgs.zapimoveis.com.br/{action}/{width}x{height}/named.images.sp/cb2017cf769d70ff34acdd44f6885741/{description}.jpg",
#       "type": "IMAGE"
#     }
#   ],
#   "accountLink": {
#     "data": {},
#     "name": "Adriano Freire Im\u00f3veis",
#     "href": "/imobiliaria/136066/",
#     "rel": ""
#   },
#   "link": {
#     "data": {
#       "street": "Avenida das Adenanteras",
#       "streetNumber": "311",
#       "state": "Cear\u00e1",
#       "city": "Fortaleza",
#       "zone": "Bairros",
#       "neighborhood": "Cidade 2000"
#     },
#     "name": "Apartamento com 3 Quartos para alugar, 75m\u00b2",
#     "href": "/imovel/aluguel-apartamento-3-quartos-com-piscina-cidade-2000-fortaleza-ce-75m2-id-2563928464/",
#     "rel": ""
#   }
# }

# %%
zapimoveis_df = df.from_records(map(lambda el: el['listing'], listings))
zapimoveis_dfs = [zapimoveis_df]

# %%
zapimoveis_df.head()
# Out:
#   displayAddressType                                          amenities  \
# 0                ALL  [GYM, POOL, PLAYGROUND, SPORTS_COURT, PARTY_HALL]
# 1                ALL  [CONCIERGE_24H, ELECTRONIC_GATE, GATED_COMMUNI...
# 2                ALL                                                 []
# 3                ALL                                                 []
# 4                ALL                                     [PETS_ALLOWED]
#
#   usableAreas       constructionStatus listingType  \
# 0        [75]  ConstructionStatus_NONE        USED
# 1       [130]  ConstructionStatus_NONE        USED
# 2        [73]  ConstructionStatus_NONE        USED
# 3        [68]  ConstructionStatus_NONE        USED
# 4       [276]  ConstructionStatus_NONE        USED
#
#                                          description  \
# 0  Adriano Freire Imóveis aluga apartamento no Mo...
# 1  Apartamento no bairro de Fátima com 3 quartos,...
# 2  Excelente localização, com terraço, churrasque...
# 3  Ótimo apartamento com 68m², com recepção, acad...
# 4  Casa com 276m2 a uma quadra da Av. Jovita Feit...
#
#                                                title stamps  \
# 0  Apartamento com 3 quartos, no MontBlanc Reside...     []
# 1  Excelente apto 3 quartos, sendo 2 suítes Bairr...     []
# 2  Excelente localização, com terraço, churrasque...     []
# 3  Ótimo apartamento com 68m², com recepção, acad...     []
# 4  Casa com 276m2 a uma quadra da Av. Jovita Feitosa     []
#
#                   createdAt floors    unitTypes       nonActivationReason  \
# 0  2022-05-23T19:48:19.423Z     []  [APARTMENT]  NonActivationReason_NONE
# 1  2022-05-23T18:02:43.478Z     []  [APARTMENT]  NonActivationReason_NONE
# 2  2022-05-23T23:16:11.096Z     []  [APARTMENT]  NonActivationReason_NONE
# 3  2022-05-23T23:16:11.109Z     []  [APARTMENT]  NonActivationReason_NONE
# 4  2022-05-23T18:42:50.258Z     []       [HOME]  NonActivationReason_NONE
#
#   providerId propertyType unitSubTypes  unitsOnTheFloor legacyId          id  \
# 0      19381         UNIT           []                0           2563928464
# 1                    UNIT           []                0           2563918208
# 2      43332         UNIT           []                0           2563941482
# 3      43332         UNIT           []                0           2563938888
# 4                    UNIT           []                0           2563921331
#
#      portal  unitFloor parkingSpaces                 updatedAt  \
# 0  GRUPOZAP          0           [2]  2022-05-23T19:48:20.942Z
# 1  GRUPOZAP          0           [2]  2022-05-23T18:15:22.131Z
# 2  GRUPOZAP          0           [2]  2022-05-23T23:19:45.384Z
# 3  GRUPOZAP          0           [2]  2022-05-23T23:22:49.370Z
# 4  GRUPOZAP          0           [3]  2022-05-23T19:21:27.265Z
#
#                                              address suites publicationType  \
# 0  {'country': 'BR', 'zipCode': '60190560', 'geoJ...    [2]        STANDARD
# 1  {'country': 'BR', 'zipCode': '60410356', 'geoJ...    [2]         PREMIUM
# 2  {'country': 'BR', 'zipCode': '60115222', 'geoJ...    [2]        STANDARD
# 3  {'country': 'BR', 'zipCode': '60125150', 'geoJ...    [1]        STANDARD
# 4  {'country': 'BR', 'zipCode': '60450490', 'geoJ...    [1]         PREMIUM
#
#   externalId bathrooms     usageTypes totalAreas  \
# 0     AP7541       [3]  [RESIDENTIAL]       [75]
# 1    1TV8U1A       [3]  [RESIDENTIAL]         []
# 2      L2338       [5]  [RESIDENTIAL]       [73]
# 3      L2037       [3]  [RESIDENTIAL]       [68]
# 4   JP302130       [3]  [RESIDENTIAL]      [276]
#
#                            advertiserId  \
# 0  aaa31266-c13f-74ad-1f85-5efc14307444
# 1  5106bb84-0c28-6112-9cec-481f62782e38
# 2  21f8bf92-c80f-c0cb-1399-e7287bde5ca1
# 3  21f8bf92-c80f-c0cb-1399-e7287bde5ca1
# 4  87f26ab6-e5ef-7460-ae50-b999a79937de
#
#                            advertiserContact whatsappNumber bedrooms  \
# 0  {'phones': ['8530132400', '85981133290']}    85981133290      [3]
# 1  {'phones': ['8530239132', '85999257101']}    85999257101      [3]
# 2                 {'phones': ['8533053000']}                     [3]
# 3                 {'phones': ['8533053000']}                     [3]
# 4  {'phones': ['8532244445', '85991418248']}    85991418248      [3]
#
#    acceptExchange                                       pricingInfos  \
# 0           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 1           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 2           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 3           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 4           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
#
#    showPrice  resale  buildings capacityLimit  status
# 0       True   False          0            []  ACTIVE
# 1       True   False          0            []  ACTIVE
# 2       True   False          0            []  ACTIVE
# 3       True   False          0            []  ACTIVE
# 4       True   False          0            []  ACTIVE

# %%
for i in trange(1, number_of_zapimoveis_files):
  fp = open(get_zapimoveis_file_path(i), "r")
  zapimoveis_json = json_load(fp)
  zapimoveis_listings = zapimoveis_json["search"]["result"]["listings"]
  zapimoveis_listings = map(lambda el: el['listing'], zapimoveis_listings)
  zapimoveis_df = df.from_records(zapimoveis_listings)
  zapimoveis_dfs.append(zapimoveis_df)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 78/78 [00:00<00:00, 94.89it/s]

# %%
zapimoveis_df_raw = pd.concat(zapimoveis_dfs)
print(f"Quantidade de linhas no dataset do ZapImoveis: {len(zapimoveis_df_raw)}\n\n")
zapimoveis_df_raw.head()
# Out:
# Quantidade de linhas no dataset do ZapImoveis: 7419
#   displayAddressType                                          amenities  \
# 0                ALL  [GYM, POOL, PLAYGROUND, SPORTS_COURT, PARTY_HALL]
# 1                ALL  [CONCIERGE_24H, ELECTRONIC_GATE, GATED_COMMUNI...
# 2                ALL                                                 []
# 3                ALL                                                 []
# 4                ALL                                     [PETS_ALLOWED]
#
#   usableAreas       constructionStatus listingType  \
# 0        [75]  ConstructionStatus_NONE        USED
# 1       [130]  ConstructionStatus_NONE        USED
# 2        [73]  ConstructionStatus_NONE        USED
# 3        [68]  ConstructionStatus_NONE        USED
# 4       [276]  ConstructionStatus_NONE        USED
#
#                                          description  \
# 0  Adriano Freire Imóveis aluga apartamento no Mo...
# 1  Apartamento no bairro de Fátima com 3 quartos,...
# 2  Excelente localização, com terraço, churrasque...
# 3  Ótimo apartamento com 68m², com recepção, acad...
# 4  Casa com 276m2 a uma quadra da Av. Jovita Feit...
#
#                                                title stamps  \
# 0  Apartamento com 3 quartos, no MontBlanc Reside...     []
# 1  Excelente apto 3 quartos, sendo 2 suítes Bairr...     []
# 2  Excelente localização, com terraço, churrasque...     []
# 3  Ótimo apartamento com 68m², com recepção, acad...     []
# 4  Casa com 276m2 a uma quadra da Av. Jovita Feitosa     []
#
#                   createdAt floors    unitTypes       nonActivationReason  \
# 0  2022-05-23T19:48:19.423Z     []  [APARTMENT]  NonActivationReason_NONE
# 1  2022-05-23T18:02:43.478Z     []  [APARTMENT]  NonActivationReason_NONE
# 2  2022-05-23T23:16:11.096Z     []  [APARTMENT]  NonActivationReason_NONE
# 3  2022-05-23T23:16:11.109Z     []  [APARTMENT]  NonActivationReason_NONE
# 4  2022-05-23T18:42:50.258Z     []       [HOME]  NonActivationReason_NONE
#
#   providerId propertyType unitSubTypes  unitsOnTheFloor legacyId          id  \
# 0      19381         UNIT           []                0           2563928464
# 1                    UNIT           []                0           2563918208
# 2      43332         UNIT           []                0           2563941482
# 3      43332         UNIT           []                0           2563938888
# 4                    UNIT           []                0           2563921331
#
#      portal  unitFloor parkingSpaces                 updatedAt  \
# 0  GRUPOZAP          0           [2]  2022-05-23T19:48:20.942Z
# 1  GRUPOZAP          0           [2]  2022-05-23T18:15:22.131Z
# 2  GRUPOZAP          0           [2]  2022-05-23T23:19:45.384Z
# 3  GRUPOZAP          0           [2]  2022-05-23T23:22:49.370Z
# 4  GRUPOZAP          0           [3]  2022-05-23T19:21:27.265Z
#
#                                              address suites publicationType  \
# 0  {'country': 'BR', 'zipCode': '60190560', 'geoJ...    [2]        STANDARD
# 1  {'country': 'BR', 'zipCode': '60410356', 'geoJ...    [2]         PREMIUM
# 2  {'country': 'BR', 'zipCode': '60115222', 'geoJ...    [2]        STANDARD
# 3  {'country': 'BR', 'zipCode': '60125150', 'geoJ...    [1]        STANDARD
# 4  {'country': 'BR', 'zipCode': '60450490', 'geoJ...    [1]         PREMIUM
#
#   externalId bathrooms     usageTypes totalAreas  \
# 0     AP7541       [3]  [RESIDENTIAL]       [75]
# 1    1TV8U1A       [3]  [RESIDENTIAL]         []
# 2      L2338       [5]  [RESIDENTIAL]       [73]
# 3      L2037       [3]  [RESIDENTIAL]       [68]
# 4   JP302130       [3]  [RESIDENTIAL]      [276]
#
#                            advertiserId  \
# 0  aaa31266-c13f-74ad-1f85-5efc14307444
# 1  5106bb84-0c28-6112-9cec-481f62782e38
# 2  21f8bf92-c80f-c0cb-1399-e7287bde5ca1
# 3  21f8bf92-c80f-c0cb-1399-e7287bde5ca1
# 4  87f26ab6-e5ef-7460-ae50-b999a79937de
#
#                            advertiserContact whatsappNumber bedrooms  \
# 0  {'phones': ['8530132400', '85981133290']}    85981133290      [3]
# 1  {'phones': ['8530239132', '85999257101']}    85999257101      [3]
# 2                 {'phones': ['8533053000']}                     [3]
# 3                 {'phones': ['8533053000']}                     [3]
# 4  {'phones': ['8532244445', '85991418248']}    85991418248      [3]
#
#    acceptExchange                                       pricingInfos  \
# 0           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 1           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 2           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 3           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 4           False  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
#
#    showPrice  resale  buildings capacityLimit  status priceSuggestion
# 0       True   False        0.0            []  ACTIVE             NaN
# 1       True   False        0.0            []  ACTIVE             NaN
# 2       True   False        0.0            []  ACTIVE             NaN
# 3       True   False        0.0            []  ACTIVE             NaN
# 4       True   False        0.0            []  ACTIVE             NaN

# %%
zapimoveis_df_raw.dtypes
# Out:
# displayAddressType      object
# amenities               object
# usableAreas             object
# constructionStatus      object
# listingType             object
# description             object
# title                   object
# stamps                  object
# createdAt               object
# floors                  object
# unitTypes               object
# nonActivationReason     object
# providerId              object
# propertyType            object
# unitSubTypes            object
# unitsOnTheFloor          int64
# legacyId                object
# id                      object
# portal                  object
# unitFloor                int64
# parkingSpaces           object
# updatedAt               object
# address                 object
# suites                  object
# publicationType         object
# externalId              object
# bathrooms               object
# usageTypes              object
# totalAreas              object
# advertiserId            object
# advertiserContact       object
# whatsappNumber          object
# bedrooms                object
# acceptExchange            bool
# pricingInfos            object
# showPrice                 bool
# resale                    bool
# buildings              float64
# capacityLimit           object
# status                  object
# priceSuggestion         object
# dtype: object

# %% [markdown]
# ## Análise preliminar dos dados
#
# Em posse de ambos *dataframes*, podemos realizar análises e correções particulares a cada conjunto de dados, para que no final, seja possível unir ambos os *dataframes* em um único *dataset final*, no qual faremos mais algumas análises e correções, possivelmente.

# %% [markdown]
# Antes de darmos início a essa exploração nos dados, note que o *dataframe* do ZapImoveis possui mais colunas que o *dataframe* do VivaReal, portanto, podemos iniciar a análise pelo ZapImóveis, para identificarmos quais são as colunas extras do *dataset*.

# %%
print(f"Número de colunas do VivaReal: {len(vivareal_df_raw.columns)}")
print(f"Número de colunas do ZapImoveis: {len(zapimoveis_df_raw.columns)}")
# Out:
# Número de colunas do VivaReal: 30
# Número de colunas do ZapImoveis: 41

# %% [markdown]
# ### ZapImoveis

# %% [markdown]
# Primeiramente, vamos listar quais as colunas em comum e as colunas diferentes entre os datasets.

# %%
print(f"Colunas em comum: ")
for column in zapimoveis_df_raw.columns.intersection(vivareal_df_raw.columns).to_list(): print(column)
# Out:
# Colunas em comum:
# displayAddressType
# amenities
# usableAreas
# constructionStatus
# listingType
# description
# title
# stamps
# unitTypes
# nonActivationReason
# propertyType
# unitSubTypes
# id
# portal
# parkingSpaces
# address
# suites
# publicationType
# externalId
# bathrooms
# usageTypes
# totalAreas
# advertiserId
# advertiserContact
# whatsappNumber
# bedrooms
# pricingInfos
# showPrice
# status

# %%
print(f"Colunas diferentes: ")
different_columns = zapimoveis_df_raw.columns.symmetric_difference(vivareal_df_raw.columns)
for column in different_columns.to_list(): print(column)
# Out:
# Colunas diferentes:
# acceptExchange
# buildings
# capacityLimit
# createdAt
# floors
# legacyId
# priceSuggestion
# providerId
# resale
# unitFloor
# unitsOnTheFloor
# updatedAt
# videoTourLink

# %% [markdown]
# Agora, das colunas diferentes entre os dois datasets, vamos verificar quais delas estão no dataframe do zap imóveis

# %%
zapimoveis_different_columns = different_columns.intersection(zapimoveis_df_raw.columns)
for column in zapimoveis_different_columns.to_list(): print(column)
# Out:
# acceptExchange
# buildings
# capacityLimit
# createdAt
# floors
# legacyId
# priceSuggestion
# providerId
# resale
# unitFloor
# unitsOnTheFloor
# updatedAt

# %% [markdown]
# Agora, analisemos os dados presentes nestas colunas. Eles são relevantes em nossa análise? A princípio, podemos identificar alguns que não são necessários, como `updatedAt`, `createdAt`, `providerId` e `legacyId`.

# %%
zapimoveis_df_raw[zapimoveis_different_columns]
# Out:
#     acceptExchange  buildings capacityLimit                 createdAt floors  \
# 0            False        0.0            []  2022-05-23T19:48:19.423Z     []
# 1            False        0.0            []  2022-05-23T18:02:43.478Z     []
# 2            False        0.0            []  2022-05-23T23:16:11.096Z     []
# 3            False        0.0            []  2022-05-23T23:16:11.109Z     []
# 4            False        0.0            []  2022-05-23T18:42:50.258Z     []
# ..             ...        ...           ...                       ...    ...
# 81           False        0.0            []  2021-09-01T06:33:40.088Z     []
# 82           False        0.0            []  2021-02-12T06:40:40.684Z     []
# 83           False        0.0            []  2020-09-02T08:41:41.575Z     []
# 84           False        0.0            []  2021-03-04T07:20:44.855Z     []
# 85           False        0.0            []  2021-01-13T21:36:02.038Z     []
#
#    legacyId priceSuggestion providerId  resale  unitFloor  unitsOnTheFloor  \
# 0                       NaN      19381   False          0                0
# 1                       NaN              False          0                0
# 2                       NaN      43332   False          0                0
# 3                       NaN      43332   False          0                0
# 4                       NaN              False          0                0
# ..      ...             ...        ...     ...        ...              ...
# 81                      NaN      19953   False          0                0
# 82                      NaN      56232   False          0                0
# 83                      NaN      19953   False          0                0
# 84                      NaN      56232   False          0                0
# 85                      NaN      19953   False          0                0
#
#                    updatedAt
# 0   2022-05-23T19:48:20.942Z
# 1   2022-05-23T18:15:22.131Z
# 2   2022-05-23T23:19:45.384Z
# 3   2022-05-23T23:22:49.370Z
# 4   2022-05-23T19:21:27.265Z
# ..                       ...
# 81  2022-05-06T10:09:20.716Z
# 82  2022-02-03T01:01:34.054Z
# 83  2022-02-15T19:30:10.672Z
# 84  2022-02-03T01:01:34.657Z
# 85  2022-02-15T19:30:10.672Z
#
# [7419 rows x 12 columns]

# %% [markdown]
# Para ter uma noção mais precisa do que é armazenado nesses atributos extras, é interessante analisarmos quais os valores que existem no dataset para estas colunas. Vamos usar o método `describe` para ter uma noção rápida sobre os valores numéricos.

# %%
zapimoveis_df_raw[zapimoveis_different_columns].describe()
# Out:
#          buildings    unitFloor  unitsOnTheFloor
# count  7415.000000  7419.000000      7419.000000
# mean      0.050169     0.680550         0.196927
# std       0.407863    18.651126         1.343894
# min       0.000000     0.000000         0.000000
# 25%       0.000000     0.000000         0.000000
# 50%       0.000000     0.000000         0.000000
# 75%       0.000000     0.000000         0.000000
# max      16.000000  1317.000000        28.000000

# %% [markdown]
# Note que em sua grande maioria, estes atributos apresentam valor `0`, um forte indício de que não farão falta em nosso *dataset* final. Para ter mais uma evidência, podemos analisar a frequência dos valores de cada uma dessas colunas, usando o método `value_counts`.

# %%
zapimoveis_df_raw[zapimoveis_different_columns]['buildings'].value_counts()
# Out:
# 0.0     7187
# 1.0      167
# 2.0       34
# 4.0       12
# 3.0        8
# 6.0        2
# 8.0        1
# 10.0       1
# 16.0       1
# 12.0       1
# 7.0        1
# Name: buildings, dtype: int64

# %%
zapimoveis_df_raw[zapimoveis_different_columns]['unitFloor'].value_counts()
# Out:
# 0       6930
# 1        126
# 2         59
# 3         57
# 4         37
# 8         23
# 5         21
# 10        19
# 7         18
# 6         18
# 9         18
# 15        13
# 11        12
# 19        11
# 13        11
# 14        10
# 16         8
# 17         7
# 12         7
# 20         6
# 18         3
# 21         2
# 1317       1
# 23         1
# 905        1
# Name: unitFloor, dtype: int64

# %%
zapimoveis_df_raw[zapimoveis_different_columns]['unitsOnTheFloor'].value_counts()
# Out:
# 0     7165
# 4       74
# 2       35
# 3       24
# 8       21
# 1       19
# 6       14
# 5       13
# 7       10
# 10       9
# 17       8
# 12       7
# 9        4
# 18       3
# 15       3
# 11       3
# 16       2
# 14       1
# 20       1
# 24       1
# 28       1
# 21       1
# Name: unitsOnTheFloor, dtype: int64

# %% [markdown]
# Assim, podemos concluir que esses atributos (buildings, unitsOnTheFloor e unitFloor) não são necessários para nosso *dataframe* final, pois em sua grande maioria assumem o valor 0. Note que alguns casos até aparentam ser erros, como o campo `unitFloor` assumindo valor 1317 (ou seja, um apartamento no andar 1317?!).

# %% [markdown]
# O método `describe` também funciona para atributos do tipo *object* e *boolean*, basta informar no parâmetro `include`. Com isso, podemos avaliar rapidamente a quantidade de valores únicos para cada atributo.

# %%
zapimoveis_df_raw[zapimoveis_different_columns].describe(include = ['O', 'bool'])
# Out:
#        acceptExchange capacityLimit                 createdAt floors legacyId  \
# count            7419          7419                      7419   7419     7419
# unique              2             2                      6957     28       59
# top             False            []  2022-05-23T19:48:19.422Z     []
# freq             7418          7418                         5   7106     7361
#
#                                           priceSuggestion providerId resale  \
# count                                                   6       7419   7419
# unique                                                  6        140      2
# top     {'min': 8.99, 'central': 11.24, 'max': 13.49, ...             False
# freq                                                    1       1408   7413
#
#                        updatedAt
# count                       7419
# unique                      5184
# top     2022-05-18T16:20:13.771Z
# freq                         391

# %% [markdown]
# A partir desses dados, podemos concluir que esses atributos de fato podem ser removidos do dataset sem grandes percas, pois como podemos ver, eles praticamente não são usados. `capacityLimit` assume valor diferente de `[]` apenas uma vez, `floors` tem 28 possibilidades de valores distintos, contudo, em apenas 313 imóveis esse atributo é diferente de `[]`, `priceSuggestion` só está presente para 6 imóveis, `acceptExchange` é `True` apenas uma vez, e `resale` é `True` apenas 6 vezes.

# %% [markdown]
# Portanto, vamos dropar todas essas colunas do dataframe, para isso, utilizamos o método `drop` do dataframe, informando as colunas a serem removidas.

# %%
zapimoveis_correct_columns = zapimoveis_df_raw.drop(columns = zapimoveis_different_columns)

# %%
zapimoveis_correct_columns.columns
# Out:
# Index(['displayAddressType', 'amenities', 'usableAreas', 'constructionStatus',
#        'listingType', 'description', 'title', 'stamps', 'unitTypes',
#        'nonActivationReason', 'propertyType', 'unitSubTypes', 'id', 'portal',
#        'parkingSpaces', 'address', 'suites', 'publicationType', 'externalId',
#        'bathrooms', 'usageTypes', 'totalAreas', 'advertiserId',
#        'advertiserContact', 'whatsappNumber', 'bedrooms', 'pricingInfos',
#        'showPrice', 'status'],
#       dtype='object')

# %% [markdown]
# Agora, podemos recalcular quais as colunas diferentes entre os *datasets*, verificando se existem mais colunas a serem 'padronizadas' entre ambos os *datasets*.

# %%
different_columns = zapimoveis_correct_columns.columns.symmetric_difference(vivareal_df_raw.columns)
for column in different_columns.to_list(): print(column)
# Out:
# videoTourLink

# %% [markdown]
# O único atributo distinto entre os *datasets* é o atributo `videoTourLink`, que pertence ao *dataset* do VivaReal

# %% [markdown]
# ### VivaReal

# %% [markdown]
# Primeiramente, vamos analisar quais os valores assumidos pelo atributo `videoTourLink`

# %%
vivareal_df_raw["videoTourLink"]
# Out:
# 0
# 1
# 2
# 3
# 4
#      ..
# 81
# 82
# 83
# 84
# 85
# Name: videoTourLink, Length: 7586, dtype: object

# %%
vivareal_df_raw["videoTourLink"].unique()
# Out:
# array(['', 'http://comdal.com.br/site/imovel-comercial-na-parangaba/',
#        'https://www.youtube.com/watch?v=YEBBt3tidAc',
#        'https://youtu.be/X1ANUh31zqs',
#        'https://meutour360.com.br/tour-360/rua-d-56-apto-204',
#        'bit.ly/2JHYRLL',
#        'https://www.youtube.com/watch?v=6rU-pQToIA8&t=112s',
#        'https://www.banibconecta.com/site/tour/erandir-ferreira-da-silva/the-loft/autostart',
#        'https://tour360.meupasseiovirtual.com/036232/166458/tourvirtual/',
#        'http://comdal.com.br/site/terreno-na-tiburcio-cavalcante/',
#        'https://www.meutour360.com.br/tour-360/ca1702-rua-joao-lobo-filho-no-327-fortaleza',
#        'https://goo.gl/maps/jALVm72mMzQo953j7',
#        'http://comdal.com.br/site/terreno-avenida-edilson-brasil-soares/',
#        'http://comdal.com.br/site/terreno-posto-sao-geraldo/',
#        'https://tour360.meupasseiovirtual.com/036232/161740/tourvirtual/',
#        'https://tour360.meupasseiovirtual.com/036232/161710/tourvirtual/index.html',
#        'https://foto360graus.com/insideview/APREDIAL/3491/index.htm',
#        'https://www.youtube.com/watch?v=ycI_O-UBpi0',
#        'https://www.meutour360.com.br/tour-360/rua-henrique-ellery-no-121-apto-05-cond-lemos-e-castro-fortaleza',
#        'https://www.instagram.com/reel/CdyEIpgjAfs/',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=KN0015_1',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=ap0237',
#        'https://tour360.meupasseiovirtual.com/036232/162765/tourvirtual/index.html',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=AP0171.4',
#        'https://tour360.meupasseiovirtual.com/036232/161730/tourvirtual/index.html',
#        'https://www.meutour360.com.br/tour-360/rua-desembargador-praxedes-no-742-aptodeg-103-condominio-luna-araujo-fortaleza',
#        'https://tour360.meupasseiovirtual.com/034548/127127/tourvirtual/',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=AP0213_1',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=AP0282',
#        'https://www.youtube.com/watch?v=3AK0VoGm52o',
#        'https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=SA0075',
#        'https://foto360graus.com/insideview/APREDIAL/5867/index.htm',
#        'https://foto360graus.com/insideview/APREDIAL/1472/index.htm',
#        'https://foto360graus.com/insideview/APREDIAL/3785/index.htm',
#        'https://foto360graus.com/insideview/APREDIAL/3477/index.htm',
#        'https://foto360graus.com/insideview/APREDIAL/5471/index.htm',
#        'https://www.banibconecta.com/site/tour/antonia-edivania-do-carmo-silva-moreira/parque-jatahy/autostart',
#        'https://www.banibconecta.com/site/tour/thea-maranny-sampaio-de-oliveira-menezes/premium-411-norte/autostart',
#        'https://fzimoveis.com.br/detalhes-imovel/1250-casa-comercial-otima-localizacao-fortaleza-meireles/',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1303',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/CA0754',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1463',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/LO0172',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/LO0044',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0064',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0059',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0065',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1727',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP0817',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AA298',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/LO0226',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1561',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP2157',
#        'https://hvr.cloud/megaimoveis/SA0284',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP0667',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1826',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AACESARROSSAS261',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/CA0782',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0130',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0067',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1158',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0206',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/PT0027',
#        'https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0061'],
#       dtype=object)

# %%
vivareal_df_raw["videoTourLink"].value_counts()
# Out:
#                                                                                 7520
# https://www.youtube.com/watch?v=YEBBt3tidAc                                        2
# https://tour360.meupasseiovirtual.com/036232/162765/tourvirtual/index.html         2
# https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0130                              2
# https://ws.hvr360.net/tourvirtual/popup/kxg718/AP1463                              1
#                                                                                 ...
# https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=AP0213_1       1
# https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=AP0282         1
# https://www.youtube.com/watch?v=3AK0VoGm52o                                        1
# https://grautour.com/public/plugins/1705191495196031/ver-360.php?id=SA0075         1
# https://ws.hvr360.net/tourvirtual/popup/kxg718/SA0061                              1
# Name: videoTourLink, Length: 64, dtype: int64

# %% [markdown]
# Perceba que a grande maioria dos imóveis presentes no dataset não possui um vídeo apresentando o imóvel, e como esse atributo não é relevante para nossas análises, podemos removê-lo sem maiores problemas.

# %%
vivareal_correct_columns = vivareal_df_raw.drop(columns = ['videoTourLink'])
vivareal_correct_columns.columns
# Out:
# Index(['displayAddressType', 'amenities', 'usableAreas', 'constructionStatus',
#        'listingType', 'description', 'title', 'unitTypes',
#        'nonActivationReason', 'propertyType', 'unitSubTypes', 'id', 'portal',
#        'parkingSpaces', 'address', 'suites', 'publicationType', 'externalId',
#        'bathrooms', 'usageTypes', 'totalAreas', 'advertiserId', 'bedrooms',
#        'pricingInfos', 'showPrice', 'status', 'advertiserContact',
#        'whatsappNumber', 'stamps'],
#       dtype='object')

# %%
different_columns = zapimoveis_correct_columns.columns.symmetric_difference(vivareal_correct_columns.columns)
different_columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## Unindo os dois *dataframes*

# %% [markdown]
# Agora, ambos os *datasets* possuem as mesmas colunas, resta saber se os tipos entre as colunas são compatíveis, para realizar a concatenação dos *dataframes* sem maiores problemas. Para isso, podemos verificar se os *dtypes* de ambos os *dataframes* são iguais.

# %%
vivareal_correct_columns.dtypes.sort_index()
# Out:
# address                object
# advertiserContact      object
# advertiserId           object
# amenities              object
# bathrooms              object
# bedrooms               object
# constructionStatus     object
# description            object
# displayAddressType     object
# externalId             object
# id                     object
# listingType            object
# nonActivationReason    object
# parkingSpaces          object
# portal                 object
# pricingInfos           object
# propertyType           object
# publicationType        object
# showPrice                bool
# stamps                 object
# status                 object
# suites                 object
# title                  object
# totalAreas             object
# unitSubTypes           object
# unitTypes              object
# usableAreas            object
# usageTypes             object
# whatsappNumber         object
# dtype: object

# %%
zapimoveis_correct_columns.dtypes.sort_index()
# Out:
# address                object
# advertiserContact      object
# advertiserId           object
# amenities              object
# bathrooms              object
# bedrooms               object
# constructionStatus     object
# description            object
# displayAddressType     object
# externalId             object
# id                     object
# listingType            object
# nonActivationReason    object
# parkingSpaces          object
# portal                 object
# pricingInfos           object
# propertyType           object
# publicationType        object
# showPrice                bool
# stamps                 object
# status                 object
# suites                 object
# title                  object
# totalAreas             object
# unitSubTypes           object
# unitTypes              object
# usableAreas            object
# usageTypes             object
# whatsappNumber         object
# dtype: object

# %%
vivareal_correct_columns.dtypes.sort_index() == zapimoveis_correct_columns.dtypes.sort_index()
# Out:
# address                True
# advertiserContact      True
# advertiserId           True
# amenities              True
# bathrooms              True
# bedrooms               True
# constructionStatus     True
# description            True
# displayAddressType     True
# externalId             True
# id                     True
# listingType            True
# nonActivationReason    True
# parkingSpaces          True
# portal                 True
# pricingInfos           True
# propertyType           True
# publicationType        True
# showPrice              True
# stamps                 True
# status                 True
# suites                 True
# title                  True
# totalAreas             True
# unitSubTypes           True
# unitTypes              True
# usableAreas            True
# usageTypes             True
# whatsappNumber         True
# dtype: bool

# %% [markdown]
# Observe que a comparação de ambos os `dtypes` retorna `True` para todos os campos, portanto, os tipos dos atributos entre os *datasets* são compatíveis, logo podemos concatená-los sem problemas! Para realizar a concatenação, utilizamos novamente o método `concat` do pandas.

# %%
rents_df = pd.concat([vivareal_correct_columns, zapimoveis_correct_columns])
rents_df
# Out:
#    displayAddressType                                          amenities  \
# 0                 ALL  [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...
# 1                 ALL  [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...
# 2                 ALL                      [AIR_CONDITIONING, PORCELAIN]
# 3                 ALL                                                 []
# 4                 ALL                                                 []
# ..                ...                                                ...
# 81                ALL                                                 []
# 82       NEIGHBORHOOD                                                 []
# 83                ALL                  [KITCHEN, BACKYARD, SERVICE_AREA]
# 84       NEIGHBORHOOD                                                 []
# 85             STREET                            [KITCHEN, SERVICE_AREA]
#
#    usableAreas       constructionStatus listingType  \
# 0         [70]  ConstructionStatus_NONE        USED
# 1         [60]  ConstructionStatus_NONE        USED
# 2         [35]  ConstructionStatus_NONE        USED
# 3         [33]  ConstructionStatus_NONE        USED
# 4         [30]  ConstructionStatus_NONE        USED
# ..         ...                      ...         ...
# 81      [7000]  ConstructionStatus_NONE        USED
# 82        [15]  ConstructionStatus_NONE        USED
# 83       [594]  ConstructionStatus_NONE        USED
# 84       [297]  ConstructionStatus_NONE        USED
# 85       [200]  ConstructionStatus_NONE        USED
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                       unitTypes       nonActivationReason propertyType  \
# 0                   [APARTMENT]  NonActivationReason_NONE         UNIT
# 1                   [APARTMENT]  NonActivationReason_NONE         UNIT
# 2                      [OFFICE]  NonActivationReason_NONE         UNIT
# 3                      [OFFICE]  NonActivationReason_NONE         UNIT
# 4                      [OFFICE]  NonActivationReason_NONE         UNIT
# ..                          ...                       ...          ...
# 81  [COMMERCIAL_ALLOTMENT_LAND]  NonActivationReason_NONE         UNIT
# 82                     [OFFICE]  NonActivationReason_NONE         UNIT
# 83                       [HOME]  NonActivationReason_NONE         UNIT
# 84                   [BUSINESS]  NonActivationReason_NONE         UNIT
# 85        [COMMERCIAL_PROPERTY]  NonActivationReason_NONE         UNIT
#
#    unitSubTypes          id    portal parkingSpaces  \
# 0            []  2562524561  GRUPOZAP           [2]
# 1            []  2515185773  GRUPOZAP           [1]
# 2            []  2534494892  GRUPOZAP            []
# 3            []  2516799902  GRUPOZAP           [1]
# 4      [CLINIC]  2532715897  GRUPOZAP           [0]
# ..          ...         ...       ...           ...
# 81           []  2532936392  GRUPOZAP           [0]
# 82           []  2510762525  GRUPOZAP           [0]
# 83           []  2494679159  GRUPOZAP          [12]
# 84           []  2512728603  GRUPOZAP           [0]
# 85           []  2507751481  GRUPOZAP           [2]
#
#                                               address suites publicationType  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]         PREMIUM
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]         PREMIUM
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []         PREMIUM
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []         PREMIUM
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]         PREMIUM
# ..                                                ...    ...             ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...    [0]        STANDARD
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...    [0]        STANDARD
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...    [2]        STANDARD
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...    [0]        STANDARD
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...    [3]        STANDARD
#
#    externalId bathrooms     usageTypes totalAreas  \
# 0    QGC3OEKO       [2]  [RESIDENTIAL]       [70]
# 1    5WFQM4GZ       [2]  [RESIDENTIAL]       [69]
# 2    FW367WSA       [1]   [COMMERCIAL]       [35]
# 3    FQSV6NGN       [1]   [COMMERCIAL]         []
# 4    GY3AMWXI       [0]   [COMMERCIAL]         []
# ..        ...       ...            ...        ...
# 81     TE0094       [0]   [COMMERCIAL]     [7000]
# 82     SA0066       [1]   [COMMERCIAL]       [15]
# 83     CA0136       [4]  [RESIDENTIAL]      [594]
# 84     PT0105       [1]   [COMMERCIAL]      [297]
# 85     CA0474       [5]   [COMMERCIAL]      [200]
#
#                             advertiserId bedrooms  \
# 0   ff52eb4d-636c-e327-d8f0-7e576aa266c6      [2]
# 1   a239c50b-0319-1aa0-6ef7-3837586b4063      [2]
# 2   ff52eb4d-636c-e327-d8f0-7e576aa266c6       []
# 3   11c4ded5-8ea5-2404-2183-e5e985813374       []
# 4   2cb4a334-9204-a7c6-6c50-0f503453322a      [0]
# ..                                   ...      ...
# 81  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [0]
# 82  c27910a9-7ff5-fbc7-b3a8-8deca3b971d2      [0]
# 83  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [5]
# 84  c27910a9-7ff5-fbc7-b3a8-8deca3b971d2      [0]
# 85  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [6]
#
#                                          pricingInfos  showPrice  status  \
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# ..                                                ...        ...     ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
#
#                              advertiserContact whatsappNumber stamps
# 0                  {'phones': ['85985685000']}    85985685000     []
# 1                  {'phones': ['11981751746']}    11981751746     []
# 2                  {'phones': ['85985685000']}    85985685000     []
# 3                  {'phones': ['85991180986']}    85991180986     []
# 4   {'phones': ['85988312527', '85998340077']}    85998340077     []
# ..                                         ...            ...    ...
# 81                  {'phones': ['8530551111']}                    []
# 82   {'phones': ['8534444810', '85981472775']}    85981472775     []
# 83                  {'phones': ['8530551111']}                    []
# 84   {'phones': ['8534444810', '85981472775']}    85981472775     []
# 85                  {'phones': ['8530551111']}                    []
#
# [15005 rows x 29 columns]

# %% [markdown]
# ## Tratamento final de dados

# %% [markdown]
# ### Definindo atributos de interesse

# %% [markdown]
# Como queremos montar um dataset de casas para alugar, é interessante termos pelo menos os seguintes dados:
#
# - Preço do aluguel
# - Preço do condomínio
# - Valor do iptu
# - Número de quartos
# - Benefícios disponíveis
# - Número de vagas de estacionamento
# - Bairro
# - Número de suítes
# - Número de banheiros
# - Área em m²
# - Latitude e longitude ; preferir usableAreas do que totalAreas
#
# O nome da rua do imóvel também pode ser útil, mas aqui, vamos deixá-lo de fora, pois ter a latitude e longitude deve ser mais útil (pois talvez seja possível criar clusters, por exemplo, analisar imóveis próximos).
#
# Abaixo, vamos investigar se existem mais atributos úteis no dataset ou não, e por fim, remover aqueles que não serão utilizados.

# %%
rents_df
# Out:
#    displayAddressType                                          amenities  \
# 0                 ALL  [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...
# 1                 ALL  [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...
# 2                 ALL                      [AIR_CONDITIONING, PORCELAIN]
# 3                 ALL                                                 []
# 4                 ALL                                                 []
# ..                ...                                                ...
# 81                ALL                                                 []
# 82       NEIGHBORHOOD                                                 []
# 83                ALL                  [KITCHEN, BACKYARD, SERVICE_AREA]
# 84       NEIGHBORHOOD                                                 []
# 85             STREET                            [KITCHEN, SERVICE_AREA]
#
#    usableAreas       constructionStatus listingType  \
# 0         [70]  ConstructionStatus_NONE        USED
# 1         [60]  ConstructionStatus_NONE        USED
# 2         [35]  ConstructionStatus_NONE        USED
# 3         [33]  ConstructionStatus_NONE        USED
# 4         [30]  ConstructionStatus_NONE        USED
# ..         ...                      ...         ...
# 81      [7000]  ConstructionStatus_NONE        USED
# 82        [15]  ConstructionStatus_NONE        USED
# 83       [594]  ConstructionStatus_NONE        USED
# 84       [297]  ConstructionStatus_NONE        USED
# 85       [200]  ConstructionStatus_NONE        USED
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                       unitTypes       nonActivationReason propertyType  \
# 0                   [APARTMENT]  NonActivationReason_NONE         UNIT
# 1                   [APARTMENT]  NonActivationReason_NONE         UNIT
# 2                      [OFFICE]  NonActivationReason_NONE         UNIT
# 3                      [OFFICE]  NonActivationReason_NONE         UNIT
# 4                      [OFFICE]  NonActivationReason_NONE         UNIT
# ..                          ...                       ...          ...
# 81  [COMMERCIAL_ALLOTMENT_LAND]  NonActivationReason_NONE         UNIT
# 82                     [OFFICE]  NonActivationReason_NONE         UNIT
# 83                       [HOME]  NonActivationReason_NONE         UNIT
# 84                   [BUSINESS]  NonActivationReason_NONE         UNIT
# 85        [COMMERCIAL_PROPERTY]  NonActivationReason_NONE         UNIT
#
#    unitSubTypes          id    portal parkingSpaces  \
# 0            []  2562524561  GRUPOZAP           [2]
# 1            []  2515185773  GRUPOZAP           [1]
# 2            []  2534494892  GRUPOZAP            []
# 3            []  2516799902  GRUPOZAP           [1]
# 4      [CLINIC]  2532715897  GRUPOZAP           [0]
# ..          ...         ...       ...           ...
# 81           []  2532936392  GRUPOZAP           [0]
# 82           []  2510762525  GRUPOZAP           [0]
# 83           []  2494679159  GRUPOZAP          [12]
# 84           []  2512728603  GRUPOZAP           [0]
# 85           []  2507751481  GRUPOZAP           [2]
#
#                                               address suites publicationType  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]         PREMIUM
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]         PREMIUM
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []         PREMIUM
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []         PREMIUM
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]         PREMIUM
# ..                                                ...    ...             ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...    [0]        STANDARD
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...    [0]        STANDARD
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...    [2]        STANDARD
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...    [0]        STANDARD
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...    [3]        STANDARD
#
#    externalId bathrooms     usageTypes totalAreas  \
# 0    QGC3OEKO       [2]  [RESIDENTIAL]       [70]
# 1    5WFQM4GZ       [2]  [RESIDENTIAL]       [69]
# 2    FW367WSA       [1]   [COMMERCIAL]       [35]
# 3    FQSV6NGN       [1]   [COMMERCIAL]         []
# 4    GY3AMWXI       [0]   [COMMERCIAL]         []
# ..        ...       ...            ...        ...
# 81     TE0094       [0]   [COMMERCIAL]     [7000]
# 82     SA0066       [1]   [COMMERCIAL]       [15]
# 83     CA0136       [4]  [RESIDENTIAL]      [594]
# 84     PT0105       [1]   [COMMERCIAL]      [297]
# 85     CA0474       [5]   [COMMERCIAL]      [200]
#
#                             advertiserId bedrooms  \
# 0   ff52eb4d-636c-e327-d8f0-7e576aa266c6      [2]
# 1   a239c50b-0319-1aa0-6ef7-3837586b4063      [2]
# 2   ff52eb4d-636c-e327-d8f0-7e576aa266c6       []
# 3   11c4ded5-8ea5-2404-2183-e5e985813374       []
# 4   2cb4a334-9204-a7c6-6c50-0f503453322a      [0]
# ..                                   ...      ...
# 81  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [0]
# 82  c27910a9-7ff5-fbc7-b3a8-8deca3b971d2      [0]
# 83  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [5]
# 84  c27910a9-7ff5-fbc7-b3a8-8deca3b971d2      [0]
# 85  ad5fe715-fe78-13a9-9ad1-0d1926f4b893      [6]
#
#                                          pricingInfos  showPrice  status  \
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# ..                                                ...        ...     ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...       True  ACTIVE
#
#                              advertiserContact whatsappNumber stamps
# 0                  {'phones': ['85985685000']}    85985685000     []
# 1                  {'phones': ['11981751746']}    11981751746     []
# 2                  {'phones': ['85985685000']}    85985685000     []
# 3                  {'phones': ['85991180986']}    85991180986     []
# 4   {'phones': ['85988312527', '85998340077']}    85998340077     []
# ..                                         ...            ...    ...
# 81                  {'phones': ['8530551111']}                    []
# 82   {'phones': ['8534444810', '85981472775']}    85981472775     []
# 83                  {'phones': ['8530551111']}                    []
# 84   {'phones': ['8534444810', '85981472775']}    85981472775     []
# 85                  {'phones': ['8530551111']}                    []
#
# [15005 rows x 29 columns]

# %%
rents_df.describe()
# Out:
#        displayAddressType amenities usableAreas       constructionStatus  \
# count               15005     15005       15005                    15005
# unique                  3      1695         807                        1
# top                   ALL        []        [30]  ConstructionStatus_NONE
# freq                 9939      7784         944                    15005
#
#        listingType                            description  \
# count        15005                                  15005
# unique           1                                   6651
# top           USED  GARAGEM para alugar no bairro ALDEOTA
# freq         15005                                    174
#
#                                              title    unitTypes  \
# count                                        15005        15005
# unique                                        5490           19
# top     SALA para alugar na cidade de FORTALEZA-CE  [APARTMENT]
# freq                                           530         5251
#
#              nonActivationReason propertyType unitSubTypes          id  \
# count                      15005        15005        15005       15005
# unique                         1            1           17        7588
# top     NonActivationReason_NONE         UNIT           []  2563919083
# freq                       15005        15005        14499           3
#
#           portal parkingSpaces  \
# count      15005         15005
# unique         2            38
# top     GRUPOZAP           [0]
# freq       15004          7689
#
#                                                   address suites  \
# count                                               15005  15005
# unique                                               7076     18
# top     {'country': 'BR', 'zipCode': '60160230', 'geoJ...    [0]
# freq                                                   22   8679
#
#        publicationType externalId bathrooms     usageTypes totalAreas  \
# count            15005      15005     15005          15005      15005
# unique               3       6987        25              3        843
# top           STANDARD     PT0022       [1]  [RESIDENTIAL]         []
# freq             11526         12      6815           7711       1508
#
#                                 advertiserId bedrooms  \
# count                                  15005    15005
# unique                                   396       25
# top     61169048-ace0-3daa-e89c-3048088b59b5      [0]
# freq                                    1852     6515
#
#                                              pricingInfos showPrice  status  \
# count                                               15005     15005   15005
# unique                                               4513         1       1
# top     [{'rentalInfo': {'period': 'MONTHLY', 'warrant...      True  ACTIVE
# freq                                                  172     15005   15005
#
#                  advertiserContact whatsappNumber stamps
# count                        15005          15005  15005
# unique                         397            364      2
# top     {'phones': ['8534664343']}                    []
# freq                          1852           6082  14296

# %% [markdown]
# Atualmente, o *dataset* possui 29 colunas, porém, diversas não serão necessárias para nosso trabalho, abaixo, vamos listar algumas dessas colunas que serão removidas.
#
# - `displayAddressType`, pois apenas controla como o endereço deve ser exibido na interface dos sites
# - `constructionStatus`, aqui, não estamos preocupados se as residências ainda estão em construção ou não, apenas no preço do aluguel
# - `listingType`, esse atributo sempre assume o valor `USED`, talvez ele seria relevante, pois seria possível analisar se imóveis novos tem aluguel significativamente diferente das casas usadas
# - `nonActivationReason`, pois assume sempre o mesmo valor
# - `propertyType`, por sempre assumir o mesmo valor
# - `portal`, apenas informa a origem do dado
# - `publicationType`, só informa qual o tipo daquela publicação nos sistemas
# - `advertiserId`, id do anunciante, irrelevante para nosso objetivo
# - `showPrice`, é sempre true e também não é relevante para nosso trabalho
# - `status`, é sempre `ACTIVE` e também não é relevante para nosso trabalho
# - `advertiserContact` e `whatsappNumber`, são informações de contato dos anunciantes, que são irrelevante para o nosso trabalho
#
# Além disso, existem mais algumas colunas que podemos remover, mas que antes precisamos realizar mais algumas análises sobre elas para tomar a decisão
#
# - `id` e `externalId`, pois podemos usar o id para procurar imóveis duplicados
# - `description` e `title`, também podemos usá-los para identificar imóveis duplicados, com base nas descrições idênticas por exemplo. Além disso, pode fazer sentido manter esses atributos para auxiliar nas análises, pois os membros podem fornecer *insights* sobre os dados, embora não devam ser utilizados na criação do modelo final
# - `stamps`, pois só com base no nome do atributo não conseguimos informar a sua finalidade
# - `unitSubTypes`, pois o campo `unitTypes` já informa o tipo da unidade (se é apartamento, casa, etc), enquanto `unitSubTypes` parece trazer um detalhamento mais fino a respeito do tipo da unidade, isso pode ser útil, mas vai depender dos valores presentes nesse atributo

# %% [markdown]
# Abaixo, removemos as colunas que já decidimos descartar

# %%
columns_to_drop = ["displayAddressType", 
                   "constructionStatus", 
                   "listingType", 
                   "nonActivationReason", 
                   "propertyType", 
                   "portal", 
                   "publicationType", 
                   "advertiserId", 
                   "showPrice",
                   "status", 
                   "advertiserContact",
                   "whatsappNumber"
                   ]

rents_df = rents_df.drop(columns=columns_to_drop)
rents_df
# Out:
#                                             amenities usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...        [70]
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...        [60]
# 2                       [AIR_CONDITIONING, PORCELAIN]        [35]
# 3                                                  []        [33]
# 4                                                  []        [30]
# ..                                                ...         ...
# 81                                                 []      [7000]
# 82                                                 []        [15]
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]       [594]
# 84                                                 []       [297]
# 85                            [KITCHEN, SERVICE_AREA]       [200]
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                       unitTypes unitSubTypes          id parkingSpaces  \
# 0                   [APARTMENT]           []  2562524561           [2]
# 1                   [APARTMENT]           []  2515185773           [1]
# 2                      [OFFICE]           []  2534494892            []
# 3                      [OFFICE]           []  2516799902           [1]
# 4                      [OFFICE]     [CLINIC]  2532715897           [0]
# ..                          ...          ...         ...           ...
# 81  [COMMERCIAL_ALLOTMENT_LAND]           []  2532936392           [0]
# 82                     [OFFICE]           []  2510762525           [0]
# 83                       [HOME]           []  2494679159          [12]
# 84                   [BUSINESS]           []  2512728603           [0]
# 85        [COMMERCIAL_PROPERTY]           []  2507751481           [2]
#
#                                               address suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]   GY3AMWXI
# ..                                                ...    ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...    [0]     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...    [0]     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...    [2]     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...    [0]     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...    [3]     CA0474
#
#    bathrooms     usageTypes totalAreas bedrooms  \
# 0        [2]  [RESIDENTIAL]       [70]      [2]
# 1        [2]  [RESIDENTIAL]       [69]      [2]
# 2        [1]   [COMMERCIAL]       [35]       []
# 3        [1]   [COMMERCIAL]         []       []
# 4        [0]   [COMMERCIAL]         []      [0]
# ..       ...            ...        ...      ...
# 81       [0]   [COMMERCIAL]     [7000]      [0]
# 82       [1]   [COMMERCIAL]       [15]      [0]
# 83       [4]  [RESIDENTIAL]      [594]      [5]
# 84       [1]   [COMMERCIAL]      [297]      [0]
# 85       [5]   [COMMERCIAL]      [200]      [6]
#
#                                          pricingInfos stamps
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# ..                                                ...    ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...     []
#
# [15005 rows x 17 columns]

# %% [markdown]
# Agora, analizamos os valores possíveis para a coluna `stamps`, note que a mesma é uma lista, portanto, fazemos uma transformação para `string` com o método `map` para que o método `value_counts` possa funcionar corretamente.

# %%
rents_df['stamps'].map(str).value_counts()
# Out:
# []                      14296
# ['DATAZAP_APPROVED']      709
# Name: stamps, dtype: int64

# %% [markdown]
# O atributo é usado em apenas cerca de 5% dos imóveis, além disso, aparenta ser apenas uma indicação que o imóvel foi 'aprovado', possivelmente o atributo tem apenas um fim publicitário, portanto, iremos removê-lo.

# %%
rents_df = rents_df.drop(columns=["stamps"])
rents_df
# Out:
#                                             amenities usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...        [70]
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...        [60]
# 2                       [AIR_CONDITIONING, PORCELAIN]        [35]
# 3                                                  []        [33]
# 4                                                  []        [30]
# ..                                                ...         ...
# 81                                                 []      [7000]
# 82                                                 []        [15]
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]       [594]
# 84                                                 []       [297]
# 85                            [KITCHEN, SERVICE_AREA]       [200]
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                       unitTypes unitSubTypes          id parkingSpaces  \
# 0                   [APARTMENT]           []  2562524561           [2]
# 1                   [APARTMENT]           []  2515185773           [1]
# 2                      [OFFICE]           []  2534494892            []
# 3                      [OFFICE]           []  2516799902           [1]
# 4                      [OFFICE]     [CLINIC]  2532715897           [0]
# ..                          ...          ...         ...           ...
# 81  [COMMERCIAL_ALLOTMENT_LAND]           []  2532936392           [0]
# 82                     [OFFICE]           []  2510762525           [0]
# 83                       [HOME]           []  2494679159          [12]
# 84                   [BUSINESS]           []  2512728603           [0]
# 85        [COMMERCIAL_PROPERTY]           []  2507751481           [2]
#
#                                               address suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...    [2]   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...    [2]   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     []   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     []   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...    [0]   GY3AMWXI
# ..                                                ...    ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...    [0]     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...    [0]     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...    [2]     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...    [0]     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...    [3]     CA0474
#
#    bathrooms     usageTypes totalAreas bedrooms  \
# 0        [2]  [RESIDENTIAL]       [70]      [2]
# 1        [2]  [RESIDENTIAL]       [69]      [2]
# 2        [1]   [COMMERCIAL]       [35]       []
# 3        [1]   [COMMERCIAL]         []       []
# 4        [0]   [COMMERCIAL]         []      [0]
# ..       ...            ...        ...      ...
# 81       [0]   [COMMERCIAL]     [7000]      [0]
# 82       [1]   [COMMERCIAL]       [15]      [0]
# 83       [4]  [RESIDENTIAL]      [594]      [5]
# 84       [1]   [COMMERCIAL]      [297]      [0]
# 85       [5]   [COMMERCIAL]      [200]      [6]
#
#                                          pricingInfos
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# ..                                                ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
#
# [15005 rows x 16 columns]

# %% [markdown]
# ### Transformando valores em listas

# %% [markdown]
# Existem diversos atributos do *dataframe* que estão como listas, mesmo que seja uma lista somente com um elemento, portanto, vamos tratar esses casos, para que não sejam mais listas.

# %%
rents_df_copy = rents_df.copy(deep=True)

# %%
rents_df = rents_df_copy.copy(deep=True)

# %%
def list_to_type(el, type_converter):
  if not isinstance(el, list): return type_converter(el)
  if len(el) == 0: return None
  return type_converter(el[0])

def list_to_float(el):
  return list_to_type(el, float)

def list_to_str(el):
  return list_to_type(el, str)

rents_df["usableAreas"] = rents_df["usableAreas"].map(list_to_float)
rents_df["parkingSpaces"] = rents_df["parkingSpaces"].map(list_to_float)
rents_df["suites"] = rents_df["suites"].map(list_to_float)
rents_df["bathrooms"] = rents_df["suites"].map(list_to_float)
rents_df["totalAreas"] = rents_df["totalAreas"].map(list_to_float)
rents_df["bedrooms"] = rents_df["bedrooms"].map(list_to_float)


rents_df["unitTypes"] = rents_df["unitTypes"].map(list_to_str)
rents_df["unitSubTypes"] = rents_df["unitSubTypes"].map(list_to_str)
rents_df["usageTypes"] = rents_df["usageTypes"].map(list_to_str)

rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 81                                                 []       7000.0
# 82                                                 []         15.0
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                     unitTypes unitSubTypes          id  parkingSpaces  \
# 0                   APARTMENT         None  2562524561            2.0
# 1                   APARTMENT         None  2515185773            1.0
# 2                      OFFICE         None  2534494892            NaN
# 3                      OFFICE         None  2516799902            1.0
# 4                      OFFICE       CLINIC  2532715897            0.0
# ..                        ...          ...         ...            ...
# 81  COMMERCIAL_ALLOTMENT_LAND         None  2532936392            0.0
# 82                     OFFICE         None  2510762525            0.0
# 83                       HOME         None  2494679159           12.0
# 84                   BUSINESS         None  2512728603            0.0
# 85        COMMERCIAL_PROPERTY         None  2507751481            2.0
#
#                                               address  suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0   GY3AMWXI
# ..                                                ...     ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...     0.0     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...     0.0     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0     CA0474
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 0         2.0  RESIDENTIAL        70.0       2.0
# 1         2.0  RESIDENTIAL        69.0       2.0
# 2         NaN   COMMERCIAL        35.0       NaN
# 3         NaN   COMMERCIAL         NaN       NaN
# 4         0.0   COMMERCIAL         NaN       0.0
# ..        ...          ...         ...       ...
# 81        0.0   COMMERCIAL      7000.0       0.0
# 82        0.0   COMMERCIAL        15.0       0.0
# 83        2.0  RESIDENTIAL       594.0       5.0
# 84        0.0   COMMERCIAL       297.0       0.0
# 85        3.0   COMMERCIAL       200.0       6.0
#
#                                          pricingInfos
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# ..                                                ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
#
# [15005 rows x 16 columns]

# %% [markdown]
# Agora, resta tratar as colunas `address` (dicionário) e `pricingInfos` (lista). A coluna `amenities` de fato precisa ser uma lista, pois um imóvel pode ter vários benefícios, como ar-condicionado embutido, elevador, etc.

# %% [markdown]
# ### Tratando a coluna de endereço

# %% [markdown]
# Como podemos ver abaixo, a coluna de `address` é um objeto com diversos campos, portanto, abaixo trataremos esse objeto e dele vamos extrair diversas colunas, como a latitude e longitude da residência.

# %%
rents_df.iloc[0]["address"]
# Out:
# {'country': 'BR',
#  'zipCode': '60170000',
#  'geoJson': '',
#  'city': 'Fortaleza',
#  'streetNumber': '160',
#  'level': 'STREET',
#  'precision': 'ROOFTOP',
#  'confidence': 'VALID_STREET',
#  'stateAcronym': 'CE',
#  'source': 'CORREIOS',
#  'point': {'lon': -38.495875, 'source': 'GOOGLE', 'lat': -3.72788},
#  'ibgeCityId': '',
#  'zone': '',
#  'street': 'Avenida Desembargador Moreira',
#  'locationId': 'BR>Ceara>NULL>Fortaleza>Barrios>Meireles',
#  'district': '',
#  'name': '',
#  'state': 'Ceará',
#  'neighborhood': 'Meireles',
#  'poisList': ['BS:Ônibus para Cumbuco',
#   'TS:Ônibus para Cumbuco',
#   'TS:Papicu',
#   'TS:Mucuripe',
#   'CS:Uri Mercado',
#   'CS:Minimercado Bempertim',
#   'CS:Cort Carnes Nobres',
#   'CS:Napadaria',
#   'CS:Aquablu',
#   'PH:Farmácia i9',
#   'PH:Farmácia TeleJuca',
#   'PH:Pharmapele',
#   'PH:Farmácia Aldesul',
#   'PH:Aldesul'],
#  'complement': '',
#  'pois': [],
#  'valuableZones': []}

# %% [markdown]
# O objeto do endereço é bem rico. Ele possui até mesmo pontos de interesse próximos ao imóvel! Entretanto, aqui estamos interessados no bairro (`neighborhood`), e na latitude e longitude. Também vamos armazenar o nome da rua, pois pode ser útil para obter mais alguns insights durante as visualizações (embora, não deva ser usada para criação do modelo final). Alguns imóveis não possuem latitude nem longitude informada, nesse caso, deixaremos o campo como NaN.

# %%
# def cep_to_nominatim_query(cep):
#     endereco = pycep_correios.get_address_from_cep(cep, webservice=pycep_correios.WebService.VIACEP)
#     street = endereco['logradouro'].split("-")[0].strip()
#     return {
#         "city": "Fortaleza",
#         "state": "CE",
#         "country": "Brazil",
#         "format": "jsonv2",
#         "street": street,
#     }

# def cep_to_lat_lon(cep):
#     # print(cep)
#     # print(params)
#     try:
#       params = cep_to_nominatim_query(cep)

#       response = requests.get("https://nominatim.openstreetmap.org/search", params=params)
#       response_json = response.json()
#       if len(response_json) == 0: 
#         print(f"Not found.. {cep}")
#         print(params)
#         return { "lat": None, "lon": None }
#       data = response_json[0]
#       return { "lat": data["lat"], "lon": data["lon"]}
#     except Exception:
#       print(f"Exception on cep {cep}")
#       return { "lat": None, "lon": None }  

def get_from_point(data, key):
  if "point" in data:
    return data["point"][key]
  # return cep_to_lat_lon(data["zipCode"])[key]

rents_df["neighborhood"] = rents_df["address"].map(lambda e: e["neighborhood"])

rents_df["lat"] = rents_df["address"].map(lambda e: get_from_point(e, "lat"))
rents_df["lon"] = rents_df["address"].map(lambda e: get_from_point(e, "lon"))

rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 81                                                 []       7000.0
# 82                                                 []         15.0
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                     unitTypes unitSubTypes          id  parkingSpaces  \
# 0                   APARTMENT         None  2562524561            2.0
# 1                   APARTMENT         None  2515185773            1.0
# 2                      OFFICE         None  2534494892            NaN
# 3                      OFFICE         None  2516799902            1.0
# 4                      OFFICE       CLINIC  2532715897            0.0
# ..                        ...          ...         ...            ...
# 81  COMMERCIAL_ALLOTMENT_LAND         None  2532936392            0.0
# 82                     OFFICE         None  2510762525            0.0
# 83                       HOME         None  2494679159           12.0
# 84                   BUSINESS         None  2512728603            0.0
# 85        COMMERCIAL_PROPERTY         None  2507751481            2.0
#
#                                               address  suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0   GY3AMWXI
# ..                                                ...     ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...     0.0     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...     0.0     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0     CA0474
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 0         2.0  RESIDENTIAL        70.0       2.0
# 1         2.0  RESIDENTIAL        69.0       2.0
# 2         NaN   COMMERCIAL        35.0       NaN
# 3         NaN   COMMERCIAL         NaN       NaN
# 4         0.0   COMMERCIAL         NaN       0.0
# ..        ...          ...         ...       ...
# 81        0.0   COMMERCIAL      7000.0       0.0
# 82        0.0   COMMERCIAL        15.0       0.0
# 83        2.0  RESIDENTIAL       594.0       5.0
# 84        0.0   COMMERCIAL       297.0       0.0
# 85        3.0   COMMERCIAL       200.0       6.0
#
#                                          pricingInfos        neighborhood  \
# 0   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...            Meireles
# 1   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...            Meireles
# 2   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...            Meireles
# 3   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...             Aldeota
# 4   [{'rentalInfo': {'period': 'MONTHLY', 'warrant...             Aldeota
# ..                                                ...                 ...
# 81  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...          Cajazeiras
# 82  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...            Mondubim
# 83  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...          Vila Velha
# 84  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...  Parque Santa Maria
# 85  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...   Conjunto Ceará II
#
#          lat        lon
# 0  -3.727880 -38.495875
# 1  -3.727192 -38.490351
# 2  -3.736109 -38.490084
# 3  -3.733264 -38.509330
# 4  -3.743591 -38.493051
# ..       ...        ...
# 81 -3.800307 -38.506944
# 82       NaN        NaN
# 83 -3.722138 -38.595065
# 84       NaN        NaN
# 85       NaN        NaN
#
# [15005 rows x 19 columns]

# %% [markdown]
# ### Tratando a coluna de preço

# %% [markdown]
# Como podemos ver abaixo, a coluna de `pricingInfos` também está no formato de lista, com um objeto contendo os campos relativos ao preço do imóvel. Vamos verificar transformar essa lista de objetos em um único objeto, e no fim, extrairemos os campos desejados: preço do aluguel, preço do condomínio e o valor do IPTU.

# %% [markdown]
# Primeiramente, é importante observar que por ser uma lista, a coluna `pricingInfos` pode ter mais de 1 valor, abaixo, verificamos se isso ocorre.

# %%
multiple_pricing_infos = rents_df[rents_df["pricingInfos"].map(lambda e: len(e) > 1)]

multiple_pricing_infos
# Out:
#                                             amenities  usableAreas  \
# 30  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, GA...        127.0
# 31  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, GA...        401.0
# 32  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, GA...         70.0
# 38  [POOL, BARBECUE_GRILL, GATED_COMMUNITY, PETS_A...         52.0
# 40                                                 []        112.0
# ..                                                ...          ...
# 80                                          [KITCHEN]         40.0
# 83                            [KITCHEN, SERVICE_AREA]        360.0
# 2                         [BACKYARD, GOURMET_BALCONY]        200.0
# 3   [BARBECUE_GRILL, BACKYARD, SERVICE_AREA, GOURM...         69.0
# 78                                                 []       4047.0
#
#                                           description  \
# 30  Belíssima cobertura com vista panorâmica para ...
# 31  O apartamento no bairro Meireles tem 401 metro...
# 32  Apartamento com 03 Suites Mobiliadas, projetad...
# 38  IMPERDÍVEL! Excelente apartamento para locação...
# 40  Ed. Centurion ( Salas em obra) <br><br>Salas c...
# ..                                                ...
# 80  Localizado próximo à Av. José Bastos, Hospital...
# 83  Localizado a 1 quadra da Av. Eduardo Girão, pr...
# 2   Casa à Venda/Aluguel, 200m² por R$ 350.000. Co...
# 3   Dispõe de 69 m², sala ampla, varanda, cozinha,...
# 78  Terreno de esquina com Av. Godofredo Maciel, p...
#
#                                                 title  \
# 30  Cobertura duplex 3 suítes Vista Mar 50 mts Bei...
# 31  Apartamento para venda possui 401 metros quadr...
# 32  Praia de Iracema Novo Mobiliado Vista Mar Fort...
# 38  Excelente apartamento para locação com 02 quar...
# 40  Escritório para aluguel e venda tem 112,35 met...
# ..                                                ...
# 80  Ponto para alugar com 40 m², próximo ao Hemoce...
# 83  Casa com 4 quartos para alugar no Bairro de Fa...
# 2                         Casa duplex - Próxima a UPA
# 3   Casa com 2 dormitórios, 69 m² - venda por R$ 2...
# 78        Terreno de esquina com Av. Godofredo Maciel
#
#                     unitTypes unitSubTypes          id  parkingSpaces  \
# 30                  APARTMENT    PENTHOUSE  2547274836            2.0
# 31                  APARTMENT         None  2555176845            5.0
# 32                  APARTMENT         None  2557571094            1.0
# 38                  APARTMENT         None  2556522442            1.0
# 40                     OFFICE         None  2562023192            3.0
# ..                        ...          ...         ...            ...
# 80                   BUSINESS         None  2481328178            0.0
# 83                       HOME         None  2539685411            3.0
# 2                        HOME         None  2532217991            1.0
# 3                        HOME         None  2542759712            2.0
# 78  COMMERCIAL_ALLOTMENT_LAND         None  2492133573            0.0
#
#                                               address  suites  \
# 30  {'country': 'BR', 'zipCode': '60125150', 'geoJ...     2.0
# 31  {'country': 'BR', 'zipCode': '60165070', 'geoJ...     4.0
# 32  {'country': 'BR', 'zipCode': '60060390', 'geoJ...     2.0
# 38  {'country': 'BR', 'zipCode': '60749020', 'geoJ...     1.0
# 40  {'country': 'BR', 'zipCode': '60170000', 'geoJ...     0.0
# ..                                                ...     ...
# 80  {'country': 'BR', 'zipCode': '60430170', 'geoJ...     0.0
# 83  {'country': 'BR', 'zipCode': '60415050', 'geoJ...     0.0
# 2   {'country': 'BR', 'zipCode': '60532380', 'geoJ...     0.0
# 3   {'country': 'BR', 'zipCode': '60831227', 'geoJ...     1.0
# 78  {'country': 'BR', 'zipCode': '60762170', 'geoJ...     0.0
#
#                          externalId  bathrooms   usageTypes  totalAreas  \
# 30                            oya22        2.0  RESIDENTIAL         NaN
# 31                        Palmares7        4.0  RESIDENTIAL       401.0
# 32                              007        2.0  RESIDENTIAL         NaN
# 38                       1001257022        1.0  RESIDENTIAL        52.0
# 40  Ed. Centurion Business Center 3        0.0   COMMERCIAL         NaN
# ..                              ...        ...          ...         ...
# 80                           PT0030        0.0   COMMERCIAL        40.0
# 83                           CA0750        0.0  RESIDENTIAL       360.0
# 2                     CA0005_MARCEL        0.0  RESIDENTIAL        10.0
# 3                            CA0738        1.0  RESIDENTIAL       200.0
# 78                           TE0067        0.0   COMMERCIAL      4047.0
#
#     bedrooms                                       pricingInfos  \
# 30       3.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 31       4.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 32       2.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 38       2.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 40       0.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# ..       ...                                                ...
# 80       0.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 83       4.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 2        2.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 3        2.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
# 78       0.0  [{'rentalInfo': {'period': 'MONTHLY', 'warrant...
#
#             neighborhood       lat        lon
# 30              Meireles -3.727110 -38.497674
# 31              Meireles -3.726588 -38.500821
# 32      Praia de Iracema -3.721737 -38.516330
# 38  Prefeito José Walter -3.830788 -38.535257
# 40              Meireles -3.732392 -38.497516
# ..                   ...       ...        ...
# 80       Rodolfo Teófilo -3.747550 -38.550727
# 83                Fátima -3.753538 -38.530332
# 2       Conjunto Ceará I -3.770340 -38.599622
# 3          Lagoa Redonda -3.717606 -38.603029
# 78              Mondubim -3.807363 -38.572981
#
# [925 rows x 19 columns]

# %% [markdown]
# Existem 900 imóveis nessa condição, logo devemos analisar estes casos.

# %%
multiple_pricing_infos["pricingInfos"].iloc[0]
# Out:
# [{'rentalInfo': {'period': 'MONTHLY',
#    'warranties': ['SECURITY_DEPOSIT', 'INSURANCE_GUARANTEE']},
#   'yearlyIptu': '0',
#   'price': '1290000',
#   'businessType': 'SALE',
#   'monthlyCondoFee': '1200'},
#  {'rentalInfo': {'period': 'MONTHLY',
#    'warranties': ['SECURITY_DEPOSIT', 'INSURANCE_GUARANTEE'],
#    'monthlyRentalTotalPrice': '15200'},
#   'yearlyIptu': '0',
#   'price': '14000',
#   'businessType': 'RENTAL',
#   'monthlyCondoFee': '1200'}]

# %% [markdown]
# Ao analisar os dados, podemos ver que isso acontece porque o imóvel está listado tanto pra venda quanto para aluguel, portanto, é o caso de considerarmos apenas os dados de aluguel. Abaixo, realizamos esse tratamento nos dados.

# %%
def treat_pricing_infos(data):
  # get pricing infor for RENTAL
  return next(filter(lambda e: e['businessType'] == 'RENTAL', data))

rents_df["pricingInfos"] = rents_df["pricingInfos"].map(treat_pricing_infos)

rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 81                                                 []       7000.0
# 82                                                 []         15.0
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                     unitTypes unitSubTypes          id  parkingSpaces  \
# 0                   APARTMENT         None  2562524561            2.0
# 1                   APARTMENT         None  2515185773            1.0
# 2                      OFFICE         None  2534494892            NaN
# 3                      OFFICE         None  2516799902            1.0
# 4                      OFFICE       CLINIC  2532715897            0.0
# ..                        ...          ...         ...            ...
# 81  COMMERCIAL_ALLOTMENT_LAND         None  2532936392            0.0
# 82                     OFFICE         None  2510762525            0.0
# 83                       HOME         None  2494679159           12.0
# 84                   BUSINESS         None  2512728603            0.0
# 85        COMMERCIAL_PROPERTY         None  2507751481            2.0
#
#                                               address  suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0   GY3AMWXI
# ..                                                ...     ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...     0.0     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...     0.0     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0     CA0474
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 0         2.0  RESIDENTIAL        70.0       2.0
# 1         2.0  RESIDENTIAL        69.0       2.0
# 2         NaN   COMMERCIAL        35.0       NaN
# 3         NaN   COMMERCIAL         NaN       NaN
# 4         0.0   COMMERCIAL         NaN       0.0
# ..        ...          ...         ...       ...
# 81        0.0   COMMERCIAL      7000.0       0.0
# 82        0.0   COMMERCIAL        15.0       0.0
# 83        2.0  RESIDENTIAL       594.0       5.0
# 84        0.0   COMMERCIAL       297.0       0.0
# 85        3.0   COMMERCIAL       200.0       6.0
#
#                                          pricingInfos        neighborhood  \
# 0   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 1   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 2   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 3   {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Aldeota
# 4   {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Aldeota
# ..                                                ...                 ...
# 81  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Cajazeiras
# 82  {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Mondubim
# 83  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Vila Velha
# 84  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Parque Santa Maria
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...   Conjunto Ceará II
#
#          lat        lon
# 0  -3.727880 -38.495875
# 1  -3.727192 -38.490351
# 2  -3.736109 -38.490084
# 3  -3.733264 -38.509330
# 4  -3.743591 -38.493051
# ..       ...        ...
# 81 -3.800307 -38.506944
# 82       NaN        NaN
# 83 -3.722138 -38.595065
# 84       NaN        NaN
# 85       NaN        NaN
#
# [15005 rows x 19 columns]

# %% [markdown]
# Agora, basta extrair individualmente os atributos desejados: `price`, que é o preço do aluguel, `monthlyCondoFee`, que é o preço mensal do condomínio (se existir a taxa), e `yearlyIptu`, o iptu pago anualmente.

# %%
def getKey(data, key):
  if key in data: return data[key]
  return 0


rents_df["condoFee"] = rents_df["pricingInfos"].map(lambda e: getKey(e, "monthlyCondoFee"))
rents_df["rentPrice"] = rents_df["pricingInfos"].map(lambda e: getKey(e, "price"))
rents_df["iptu"] = rents_df["pricingInfos"].map(lambda e: getKey(e, "yearlyIptu"))

rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 81                                                 []       7000.0
# 82                                                 []         15.0
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 81  Excelente terreno com 3 frentes, 7.000M² de ár...
# 82
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
#
#                                                 title  \
# 0   Apartamento para aluguel tem 70 metros quadrad...
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...
# 2   Sala comercial, localização INENARRÁVEL / para...
# 3      Scopa Platinum Corporate - Salas amplas com WC
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...
# ..                                                ...
# 81          Terreno com 7mil m² para alugar na BR 116
# 82                                     Sala Comercial
# 83          Casa para alugar com 594 m² no Vila Velha
# 84                                    Ponto Comercial
# 85    Casa comercial duplex, no bairro Conjunto Ceará
#
#                     unitTypes unitSubTypes          id  parkingSpaces  \
# 0                   APARTMENT         None  2562524561            2.0
# 1                   APARTMENT         None  2515185773            1.0
# 2                      OFFICE         None  2534494892            NaN
# 3                      OFFICE         None  2516799902            1.0
# 4                      OFFICE       CLINIC  2532715897            0.0
# ..                        ...          ...         ...            ...
# 81  COMMERCIAL_ALLOTMENT_LAND         None  2532936392            0.0
# 82                     OFFICE         None  2510762525            0.0
# 83                       HOME         None  2494679159           12.0
# 84                   BUSINESS         None  2512728603            0.0
# 85        COMMERCIAL_PROPERTY         None  2507751481            2.0
#
#                                               address  suites externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0   QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0   5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN   FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN   FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0   GY3AMWXI
# ..                                                ...     ...        ...
# 81  {'country': 'BR', 'zipCode': '60864012', 'geoJ...     0.0     TE0094
# 82  {'country': 'BR', 'zipCode': '60752483', 'geoJ...     0.0     SA0066
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0     CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0     PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0     CA0474
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 0         2.0  RESIDENTIAL        70.0       2.0
# 1         2.0  RESIDENTIAL        69.0       2.0
# 2         NaN   COMMERCIAL        35.0       NaN
# 3         NaN   COMMERCIAL         NaN       NaN
# 4         0.0   COMMERCIAL         NaN       0.0
# ..        ...          ...         ...       ...
# 81        0.0   COMMERCIAL      7000.0       0.0
# 82        0.0   COMMERCIAL        15.0       0.0
# 83        2.0  RESIDENTIAL       594.0       5.0
# 84        0.0   COMMERCIAL       297.0       0.0
# 85        3.0   COMMERCIAL       200.0       6.0
#
#                                          pricingInfos        neighborhood  \
# 0   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 1   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 2   {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Meireles
# 3   {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Aldeota
# 4   {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Aldeota
# ..                                                ...                 ...
# 81  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Cajazeiras
# 82  {'rentalInfo': {'period': 'MONTHLY', 'warranti...            Mondubim
# 83  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Vila Velha
# 84  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Parque Santa Maria
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...   Conjunto Ceará II
#
#          lat        lon condoFee rentPrice  iptu
# 0  -3.727880 -38.495875      730      2700   110
# 1  -3.727192 -38.490351      800      2500   200
# 2  -3.736109 -38.490084      575      2500   330
# 3  -3.733264 -38.509330      428      1750  1143
# 4  -3.743591 -38.493051        0       500     0
# ..       ...        ...      ...       ...   ...
# 81 -3.800307 -38.506944        0     45000  1715
# 82       NaN        NaN        0       700     0
# 83 -3.722138 -38.595065        0      5000     0
# 84       NaN        NaN        0      1700     0
# 85       NaN        NaN        0     10500     0
#
# [15005 rows x 22 columns]

# %% [markdown]
# ### Investigando linhas duplicadas

# %% [markdown]
# Agora, vamos investigar se existem linhas duplicadas no dataset, para isso, podemos utilizar o método `duplicated` do pandas. Para identificar as linhas duplicadas, vamos usar as colunas `id` e `externalId`.

# %%
# Exibindo todas as linhas duplicadas
rents_df[rents_df.duplicated(subset = ['id', 'externalId'], keep = False)].sort_values(by='id')
# Out:
#                                             amenities  usableAreas  \
# 85                                          [KITCHEN]         20.0
# 85                                          [KITCHEN]         20.0
# 39  [AIR_CONDITIONING, KITCHEN, INTERCOM, CABLE_TV...         45.0
# 41  [AIR_CONDITIONING, KITCHEN, INTERCOM, CABLE_TV...         45.0
# 90                          [SAFETY_CIRCUIT, KITCHEN]         31.0
# ..                                                ...          ...
# 39                                                 []         45.0
# 61  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, BA...         70.0
# 61  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, BA...         70.0
# 31  [POOL, BARBECUE_GRILL, ELEVATOR, GATED_COMMUNI...        120.0
# 31  [POOL, BARBECUE_GRILL, ELEVATOR, GATED_COMMUNI...        120.0
#
#                                           description  \
# 85  Kitinete em bom estado de conservação, medindo...
# 85  Kitinete em bom estado de conservação, medindo...
# 39  Apartamentos em perfeita localização no Cambeb...
# 41  Apartamentos em perfeita localização no Cambeb...
# 90  Loja comercial plana, em bom estado de conserv...
# ..                                                ...
# 39  Sala comercial no 4° andar do Ed. Nordeste Cen...
# 61  Aluguel de apartamento mensal ou diaria de 70 ...
# 61  Aluguel de apartamento mensal ou diaria de 70 ...
# 31  Excelente apto a poucas quadras do shopping Ri...
# 31  Excelente apto a poucas quadras do shopping Ri...
#
#                                                 title  unitTypes unitSubTypes  \
# 85         KITNET para aluguel, Centro - FORTALEZA/CE     KITNET         None
# 85         KITNET para aluguel, Centro - FORTALEZA/CE     KITNET         None
# 39  Apartamento com 2 dormitórios para alugar, 45 ...  APARTMENT         None
# 41  Apartamento com 2 dormitórios para alugar, 45 ...  APARTMENT         None
# 90         LOJA para aluguel, Meireles - FORTALEZA/CE   BUSINESS         None
# ..                                                ...        ...          ...
# 39  SA0023 - Sala comercial 45m², Ed. Nordeste Cen...     OFFICE         None
# 61  Apartamento para aluguel com 70 metros quadrad...  APARTMENT         None
# 61  Apartamento para aluguel com 70 metros quadrad...  APARTMENT         None
# 31  Apartamento projetado no Cond. Mistral com 120...  APARTMENT         None
# 31  Apartamento projetado no Cond. Mistral com 120...  APARTMENT         None
#
#             id  parkingSpaces  \
# 85  1037182362            0.0
# 85  1037182362            0.0
# 39  1037377383            0.0
# 41  1037377383            0.0
# 90  1037456177            0.0
# ..         ...            ...
# 39    93766435            0.0
# 61    94721792            1.0
# 61    94721792            1.0
# 31    95387448            2.0
# 31    95387448            2.0
#
#                                               address  suites externalId  \
# 85  {'country': 'BR', 'zipCode': '60025000', 'geoJ...     0.0       7367
# 85  {'country': 'BR', 'zipCode': '60025000', 'geoJ...     0.0       7367
# 39  {'country': 'BR', 'zipCode': '60841455', 'geoJ...     0.0     AP1296
# 41  {'country': 'BR', 'zipCode': '60841455', 'geoJ...     0.0     AP1296
# 90  {'country': 'BR', 'zipCode': '60165081', 'geoJ...     0.0       3665
# ..                                                ...     ...        ...
# 39  {'country': 'BR', 'zipCode': '60135100', 'geoJ...     0.0     SA0023
# 61  {'country': 'BR', 'zipCode': '60165050', 'geoJ...     1.0         33
# 61  {'country': 'BR', 'zipCode': '60165050', 'geoJ...     1.0         33
# 31  {'country': 'BR', 'zipCode': '60176010', 'geoJ...     3.0  044LOCMIS
# 31  {'country': 'BR', 'zipCode': '60176010', 'geoJ...     3.0  044LOCMIS
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 85        0.0  RESIDENTIAL        20.0       0.0
# 85        0.0  RESIDENTIAL        20.0       0.0
# 39        0.0  RESIDENTIAL        45.0       2.0
# 41        0.0  RESIDENTIAL        45.0       2.0
# 90        0.0   COMMERCIAL        31.0       0.0
# ..        ...          ...         ...       ...
# 39        0.0   COMMERCIAL        45.0       0.0
# 61        1.0  RESIDENTIAL        70.0       2.0
# 61        1.0  RESIDENTIAL        70.0       2.0
# 31        3.0  RESIDENTIAL       120.0       3.0
# 31        3.0  RESIDENTIAL       120.0       3.0
#
#                                          pricingInfos    neighborhood  \
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Centro
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Centro
# 39  {'rentalInfo': {'period': 'MONTHLY', 'warranti...       Messejana
# 41  {'rentalInfo': {'period': 'MONTHLY', 'warranti...       Messejana
# 90  {'rentalInfo': {'period': 'MONTHLY', 'warranti...        Meireles
# ..                                                ...             ...
# 39  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Joaquim Távora
# 61  {'rentalInfo': {'period': 'MONTHLY', 'warranti...        Meireles
# 61  {'rentalInfo': {'period': 'MONTHLY', 'warranti...        Meireles
# 31  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Papicu
# 31  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Papicu
#
#          lat        lon condoFee rentPrice iptu
# 85       NaN        NaN        0       350  316
# 85       NaN        NaN        0       350  316
# 39       NaN        NaN        0       520    0
# 41       NaN        NaN        0       520    0
# 90       NaN        NaN      197       800  671
# ..       ...        ...      ...       ...  ...
# 39 -3.742119 -38.511967      180       700   55
# 61 -3.721492 -38.510060        0      2800    0
# 61 -3.721492 -38.510060        0      2800    0
# 31 -3.736612 -38.471152      922      3000  211
# 31 -3.736612 -38.471152      922      3000  211
#
# [14655 rows x 22 columns]

# %%
rents_df[rents_df.duplicated(subset = ['id', 'externalId'], keep = 'first')].sort_values(by='id')
# Out:
#                                             amenities  usableAreas  \
# 85                                          [KITCHEN]         20.0
# 41  [AIR_CONDITIONING, KITCHEN, INTERCOM, CABLE_TV...         45.0
# 90                          [SAFETY_CIRCUIT, KITCHEN]         31.0
# 37                                          [KITCHEN]         70.0
# 66                                                 []        510.0
# ..                                                ...          ...
# 58                                                 []        132.0
# 38                 [GATED_COMMUNITY, ELECTRONIC_GATE]         50.0
# 39                                                 []         45.0
# 61  [POOL, FURNISHED, BARBECUE_GRILL, ELEVATOR, BA...         70.0
# 31  [POOL, BARBECUE_GRILL, ELEVATOR, GATED_COMMUNI...        120.0
#
#                                           description  \
# 85  Kitinete em bom estado de conservação, medindo...
# 41  Apartamentos em perfeita localização no Cambeb...
# 90  Loja comercial plana, em bom estado de conserv...
# 37  Loja 70,50m² com ponto agregado, mezanino e 01...
# 66  ALUGA-SE EXCELENTE PONTO COMERCIAL (510M2).<br...
# ..                                                ...
# 58  Alugo<br><br>Casa duplex no condomínio Litoral...
# 38  EXCELENTE CASA EM CONDOMÍNIO (sem cobrança de ...
# 39  Sala comercial no 4° andar do Ed. Nordeste Cen...
# 61  Aluguel de apartamento mensal ou diaria de 70 ...
# 31  Excelente apto a poucas quadras do shopping Ri...
#
#                                                 title  unitTypes unitSubTypes  \
# 85         KITNET para aluguel, Centro - FORTALEZA/CE     KITNET         None
# 41  Apartamento com 2 dormitórios para alugar, 45 ...  APARTMENT         None
# 90         LOJA para aluguel, Meireles - FORTALEZA/CE   BUSINESS         None
# 37           LOJA para aluguel, Papicu - FORTALEZA/CE   BUSINESS         None
# 66         EXCELENTE PONTO COMERCIAL (TODO REFORMADO)   BUSINESS         None
# ..                                                ...        ...          ...
# 58  Alugo casa em condomínio fechado 3 suítes na s...       HOME  CONDOMINIUM
# 38  Excelente casa condomínio fechado em uma ótima...       HOME  CONDOMINIUM
# 39  SA0023 - Sala comercial 45m², Ed. Nordeste Cen...     OFFICE         None
# 61  Apartamento para aluguel com 70 metros quadrad...  APARTMENT         None
# 31  Apartamento projetado no Cond. Mistral com 120...  APARTMENT         None
#
#             id  parkingSpaces  \
# 85  1037182362            0.0
# 41  1037377383            0.0
# 90  1037456177            0.0
# 37  1037499332            0.0
# 66  1037588219            0.0
# ..         ...            ...
# 58    93669391            2.0
# 38    93677681            1.0
# 39    93766435            0.0
# 61    94721792            1.0
# 31    95387448            2.0
#
#                                               address  suites externalId  \
# 85  {'country': 'BR', 'zipCode': '60025000', 'geoJ...     0.0       7367
# 41  {'country': 'BR', 'zipCode': '60841455', 'geoJ...     0.0     AP1296
# 90  {'country': 'BR', 'zipCode': '60165081', 'geoJ...     0.0       3665
# 37  {'country': 'BR', 'zipCode': '60175395', 'geoJ...     0.0       7384
# 66  {'country': 'BR', 'zipCode': '60150060', 'geoJ...     0.0       8/19
# ..                                                ...     ...        ...
# 58  {'country': 'BR', 'zipCode': '60835575', 'geoJ...     3.0         98
# 38  {'country': 'BR', 'zipCode': '60871750', 'geoJ...     0.0         77
# 39  {'country': 'BR', 'zipCode': '60135100', 'geoJ...     0.0     SA0023
# 61  {'country': 'BR', 'zipCode': '60165050', 'geoJ...     1.0         33
# 31  {'country': 'BR', 'zipCode': '60176010', 'geoJ...     3.0  044LOCMIS
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 85        0.0  RESIDENTIAL        20.0       0.0
# 41        0.0  RESIDENTIAL        45.0       2.0
# 90        0.0   COMMERCIAL        31.0       0.0
# 37        0.0   COMMERCIAL        70.0       0.0
# 66        0.0   COMMERCIAL         NaN       2.0
# ..        ...          ...         ...       ...
# 58        3.0  RESIDENTIAL       143.0       3.0
# 38        0.0  RESIDENTIAL        50.0       2.0
# 39        0.0   COMMERCIAL        45.0       0.0
# 61        1.0  RESIDENTIAL        70.0       2.0
# 31        3.0  RESIDENTIAL       120.0       3.0
#
#                                          pricingInfos    neighborhood  \
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Centro
# 41  {'rentalInfo': {'period': 'MONTHLY', 'warranti...       Messejana
# 90  {'rentalInfo': {'period': 'MONTHLY', 'warranti...        Meireles
# 37  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Papicu
# 66  {'rentalInfo': {'period': 'MONTHLY', 'warranti...         Aldeota
# ..                                                ...             ...
# 58  {'rentalInfo': {'period': 'MONTHLY', 'warranti...      Sabiaguaba
# 38  {'rentalInfo': {'period': 'MONTHLY', 'warranti...           Coaçu
# 39  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Joaquim Távora
# 61  {'rentalInfo': {'period': 'MONTHLY', 'warranti...        Meireles
# 31  {'rentalInfo': {'period': 'MONTHLY', 'warranti...          Papicu
#
#          lat        lon condoFee rentPrice iptu
# 85       NaN        NaN        0       350  316
# 41       NaN        NaN        0       520    0
# 90       NaN        NaN      197       800  671
# 37       NaN        NaN        0      1500  393
# 66 -3.735915 -38.506204        0      5000  578
# ..       ...        ...      ...       ...  ...
# 58 -3.806992 -38.428464      800      1200  100
# 38 -3.836541 -38.486019        0       750    0
# 39 -3.742119 -38.511967      180       700   55
# 61 -3.721492 -38.510060        0      2800    0
# 31 -3.736612 -38.471152      922      3000  211
#
# [7417 rows x 22 columns]

# %% [markdown]
# Observe que de fato, temos muitas duplicações! A conclusão que podemos tirar aqui, é que o site do ZapImóveis utiliza a mesma base de dados que o site do VivaReal. A quantidade de duplicatas é praticamente a mesma quantidade de linhas presentes no dataset do ZapImóveis! Infelizmente, será necessário remover essas duplicatas. A premissa inicial neste trabalho é de que embora pudessem existir anuncios repetidos, fossem existir mais anúncios presentes somente em uma das bases. Porém, como podemos ver, não é esse o caso. :(
#
# Abaixo, removemos as linhas duplicadas.

# %%
print(f"Tamanho do dataframe antes de remover as duplicações: {len(rents_df)}")

rents_df = rents_df.drop_duplicates(subset = ['id', 'externalId'], keep='first')

print(f"Tamanho do dataframe apos de remover as duplicações: {len(rents_df)}")
# Out:
# Tamanho do dataframe antes de remover as duplicações: 15005
# Tamanho do dataframe apos de remover as duplicações: 7588

# %% [markdown]
# ### Analisando a coluna `unitSubTypes`

# %% [markdown]
# A coluna `unitSubTypes` é interessante, por oferecer mais informações a respeito do tipo de imóvel. Porém, já existe a coluna `unitTypes`, então talvez `unitSubTypes` pode não ser necessária. Portanto, vamos analisar os valores possíveis pra coluna `unitSubTypes`, para poder decidir se essa coluna estará presente no *dataset* final ou não.

# %%
rents_df["unitSubTypes"].describe()
# Out:
# count        262
# unique        15
# top       KITNET
# freq         144
# Name: unitSubTypes, dtype: object

# %%
rents_df["unitSubTypes"].value_counts()
# Out:
# KITNET                 144
# OFFICE                  38
# CONDOMINIUM             15
# VILLAGE_HOUSE           11
# RETAIL_CENTER           10
# FLAT                     9
# CLINIC                   8
# TWO_STORY_HOUSE          6
# PENTHOUSE                5
# SHOPPING                 5
# FLOOR                    4
# GALLERY                  2
# SINGLE_STOREY_HOUSE      2
# STUDIO                   2
# DUPLEX                   1
# Name: unitSubTypes, dtype: int64

# %% [markdown]
# Observe que existem poucas linhas no *dataset* em que a coluna `unitSubTypes` está presente, portanto, vamos remover essa coluna.

# %%
rents_df = rents_df.drop(columns=["unitSubTypes"])
rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
# 34  [BARBECUE_GRILL, GARDEN, POOL, PLAYGROUND, ELE...         54.0
# 54  [POOL, FURNISHED, BARBECUE_GRILL, GATED_COMMUN...         68.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
# 34  Primeira Locação, valor já com condomínio. Apa...
# 54  LOCAÇÃO RESIDENCIAL<br><br>MEIRELES<br>CONDOMÍ...
#
#                                                 title            unitTypes  \
# 0   Apartamento para aluguel tem 70 metros quadrad...            APARTMENT
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...            APARTMENT
# 2   Sala comercial, localização INENARRÁVEL / para...               OFFICE
# 3      Scopa Platinum Corporate - Salas amplas com WC               OFFICE
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...               OFFICE
# ..                                                ...                  ...
# 83          Casa para alugar com 594 m² no Vila Velha                 HOME
# 84                                    Ponto Comercial             BUSINESS
# 85    Casa comercial duplex, no bairro Conjunto Ceará  COMMERCIAL_PROPERTY
# 34  Apartamento de 54 metros quadrados no bairro P...            APARTMENT
# 54                                      Cond. CHRONUS            APARTMENT
#
#             id  parkingSpaces  \
# 0   2562524561            2.0
# 1   2515185773            1.0
# 2   2534494892            NaN
# 3   2516799902            1.0
# 4   2532715897            0.0
# ..         ...            ...
# 83  2494679159           12.0
# 84  2512728603            0.0
# 85  2507751481            2.0
# 34  2455269281            2.0
# 54  2564089923            2.0
#
#                                               address  suites  externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0    QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0    5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN    FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN    FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0    GY3AMWXI
# ..                                                ...     ...         ...
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0      CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0      PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0      CA0474
# 34  {'country': 'BR', 'zipCode': '60760510', 'geoJ...     1.0  ZAP1556053
# 54  {'country': 'BR', 'zipCode': '60165080', 'geoJ...     1.0  CHRONOS302
#
#     bathrooms   usageTypes  totalAreas  bedrooms  \
# 0         2.0  RESIDENTIAL        70.0       2.0
# 1         2.0  RESIDENTIAL        69.0       2.0
# 2         NaN   COMMERCIAL        35.0       NaN
# 3         NaN   COMMERCIAL         NaN       NaN
# 4         0.0   COMMERCIAL         NaN       0.0
# ..        ...          ...         ...       ...
# 83        2.0  RESIDENTIAL       594.0       5.0
# 84        0.0   COMMERCIAL       297.0       0.0
# 85        3.0   COMMERCIAL       200.0       6.0
# 34        1.0  RESIDENTIAL        64.0       2.0
# 54        1.0  RESIDENTIAL         NaN       2.0
#
#                                          pricingInfos           neighborhood  \
# 0   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 1   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 2   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 3   {'rentalInfo': {'period': 'MONTHLY', 'warranti...                Aldeota
# 4   {'rentalInfo': {'period': 'MONTHLY', 'warranti...                Aldeota
# ..                                                ...                    ...
# 83  {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Vila Velha
# 84  {'rentalInfo': {'period': 'MONTHLY', 'warranti...     Parque Santa Maria
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...      Conjunto Ceará II
# 34  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Planalto Ayrton Senna
# 54  {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
#
#          lat        lon condoFee rentPrice  iptu
# 0  -3.727880 -38.495875      730      2700   110
# 1  -3.727192 -38.490351      800      2500   200
# 2  -3.736109 -38.490084      575      2500   330
# 3  -3.733264 -38.509330      428      1750  1143
# 4  -3.743591 -38.493051        0       500     0
# ..       ...        ...      ...       ...   ...
# 83 -3.722138 -38.595065        0      5000     0
# 84       NaN        NaN        0      1700     0
# 85       NaN        NaN        0     10500     0
# 34 -3.833893 -38.567802      275       700   250
# 54 -3.725501 -38.500486      617      2500     0
#
# [7588 rows x 21 columns]

# %% [markdown]
# ### Remoção da coluna `totalAreas`

# %% [markdown]
# No *dataset*, existem duas colunas que indicam a área dos imóveis, `totalAreas` e `usableAreas`. A coluna `totalAreas` indica a área bruta total do imóvel, enquanto `usableAreas` representa a área útil do imóvel. Aqui, estamos interessados apenas na área útil, portanto, removemos a coluna `totalAreas` do *dataset*.

# %%
rents_df = rents_df.drop(columns=["totalAreas"])
rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
# 34  [BARBECUE_GRILL, GARDEN, POOL, PLAYGROUND, ELE...         54.0
# 54  [POOL, FURNISHED, BARBECUE_GRILL, GATED_COMMUN...         68.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
# 34  Primeira Locação, valor já com condomínio. Apa...
# 54  LOCAÇÃO RESIDENCIAL<br><br>MEIRELES<br>CONDOMÍ...
#
#                                                 title            unitTypes  \
# 0   Apartamento para aluguel tem 70 metros quadrad...            APARTMENT
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...            APARTMENT
# 2   Sala comercial, localização INENARRÁVEL / para...               OFFICE
# 3      Scopa Platinum Corporate - Salas amplas com WC               OFFICE
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...               OFFICE
# ..                                                ...                  ...
# 83          Casa para alugar com 594 m² no Vila Velha                 HOME
# 84                                    Ponto Comercial             BUSINESS
# 85    Casa comercial duplex, no bairro Conjunto Ceará  COMMERCIAL_PROPERTY
# 34  Apartamento de 54 metros quadrados no bairro P...            APARTMENT
# 54                                      Cond. CHRONUS            APARTMENT
#
#             id  parkingSpaces  \
# 0   2562524561            2.0
# 1   2515185773            1.0
# 2   2534494892            NaN
# 3   2516799902            1.0
# 4   2532715897            0.0
# ..         ...            ...
# 83  2494679159           12.0
# 84  2512728603            0.0
# 85  2507751481            2.0
# 34  2455269281            2.0
# 54  2564089923            2.0
#
#                                               address  suites  externalId  \
# 0   {'country': 'BR', 'zipCode': '60170000', 'geoJ...     2.0    QGC3OEKO
# 1   {'country': 'BR', 'zipCode': '60170210', 'geoJ...     2.0    5WFQM4GZ
# 2   {'country': 'BR', 'zipCode': '60160230', 'geoJ...     NaN    FW367WSA
# 3   {'country': 'BR', 'zipCode': '60115191', 'geoJ...     NaN    FQSV6NGN
# 4   {'country': 'BR', 'zipCode': '60140120', 'geoJ...     0.0    GY3AMWXI
# ..                                                ...     ...         ...
# 83  {'country': 'BR', 'zipCode': '60345631', 'geoJ...     2.0      CA0136
# 84  {'country': 'BR', 'zipCode': '60873155', 'geoJ...     0.0      PT0105
# 85  {'country': 'BR', 'zipCode': '60531820', 'geoJ...     3.0      CA0474
# 34  {'country': 'BR', 'zipCode': '60760510', 'geoJ...     1.0  ZAP1556053
# 54  {'country': 'BR', 'zipCode': '60165080', 'geoJ...     1.0  CHRONOS302
#
#     bathrooms   usageTypes  bedrooms  \
# 0         2.0  RESIDENTIAL       2.0
# 1         2.0  RESIDENTIAL       2.0
# 2         NaN   COMMERCIAL       NaN
# 3         NaN   COMMERCIAL       NaN
# 4         0.0   COMMERCIAL       0.0
# ..        ...          ...       ...
# 83        2.0  RESIDENTIAL       5.0
# 84        0.0   COMMERCIAL       0.0
# 85        3.0   COMMERCIAL       6.0
# 34        1.0  RESIDENTIAL       2.0
# 54        1.0  RESIDENTIAL       2.0
#
#                                          pricingInfos           neighborhood  \
# 0   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 1   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 2   {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
# 3   {'rentalInfo': {'period': 'MONTHLY', 'warranti...                Aldeota
# 4   {'rentalInfo': {'period': 'MONTHLY', 'warranti...                Aldeota
# ..                                                ...                    ...
# 83  {'rentalInfo': {'period': 'MONTHLY', 'warranti...             Vila Velha
# 84  {'rentalInfo': {'period': 'MONTHLY', 'warranti...     Parque Santa Maria
# 85  {'rentalInfo': {'period': 'MONTHLY', 'warranti...      Conjunto Ceará II
# 34  {'rentalInfo': {'period': 'MONTHLY', 'warranti...  Planalto Ayrton Senna
# 54  {'rentalInfo': {'period': 'MONTHLY', 'warranti...               Meireles
#
#          lat        lon condoFee rentPrice  iptu
# 0  -3.727880 -38.495875      730      2700   110
# 1  -3.727192 -38.490351      800      2500   200
# 2  -3.736109 -38.490084      575      2500   330
# 3  -3.733264 -38.509330      428      1750  1143
# 4  -3.743591 -38.493051        0       500     0
# ..       ...        ...      ...       ...   ...
# 83 -3.722138 -38.595065        0      5000     0
# 84       NaN        NaN        0      1700     0
# 85       NaN        NaN        0     10500     0
# 34 -3.833893 -38.567802      275       700   250
# 54 -3.725501 -38.500486      617      2500     0
#
# [7588 rows x 20 columns]

# %% [markdown]
# ### Tratamento de `NaN`'s

# %% [markdown]
# Existem alguns valores NaN no *dataframe*, abaixo, trataremos as colunas que possuem `NaN`'s.

# %% [markdown]
# Primeiramente, podemos usar o método isna().any() para listar as colunas que possuem valores `NaN`.

# %%
rents_df.isna().any()
# Out:
# amenities        False
# usableAreas       True
# description      False
# title            False
# unitTypes        False
# id               False
# parkingSpaces     True
# address          False
# suites            True
# externalId       False
# bathrooms         True
# usageTypes       False
# bedrooms          True
# pricingInfos     False
# neighborhood     False
# lat               True
# lon               True
# condoFee         False
# rentPrice        False
# iptu             False
# dtype: bool

# %% [markdown]
# Para as colunas `parkingSpaces`, `suites`, `bathrooms` e `bedrooms`, podemos trocar os valores `NaN`'s por 0, pois é um valor que faz sentido para estas colunas, e se não foi informado, provavelmente foi porque era 0, caso contrário, faria sentido ser anunciado, pois é bastante relevante no anúncio de um imóvel conhecer estas informações! Para trocar os valores `NaN` por 0, usaremos o método `fillna` do pandas.

# %%
rents_df["parkingSpaces"] = rents_df["parkingSpaces"].fillna(0)
rents_df["suites"] = rents_df["suites"].fillna(0)
rents_df["bathrooms"] = rents_df["bathrooms"].fillna(0)
rents_df["bedrooms"] = rents_df["bedrooms"].fillna(0)
rents_df.isna().any()
# Out:
# amenities        False
# usableAreas       True
# description      False
# title            False
# unitTypes        False
# id               False
# parkingSpaces    False
# address          False
# suites           False
# externalId       False
# bathrooms        False
# usageTypes       False
# bedrooms         False
# pricingInfos     False
# neighborhood     False
# lat               True
# lon               True
# condoFee         False
# rentPrice        False
# iptu             False
# dtype: bool

# %% [markdown]
# Para a coluna `usableAreas`, não faz sentido termos valores `NaN` trocados por 0, pois não é possível usar um imóvel com área 0. Primeiramente, podemos ver as linhas que possuem área `NaN`.

# %%
rents_df[rents_df["usableAreas"].isna()]["title"].value_counts()
# Out:
# GARAGEM para alugar na cidade de FORTALEZA-CE                 93
# vaga de garagem no prédio comercial Edifício Rocha Aguiar.     2
# Área para alugar por R$ 5.000/mês - Centro - Fortaleza/CE      1
# Name: title, dtype: int64

# %% [markdown]
# Note que são poucos casos, além disso, a maioria se trata de garagens. Como essas informações não são relevantes para nosso *dataset*, removeremos estas linhas.

# %%
rents_df = rents_df[rents_df["usableAreas"].notna()]
rents_df.isna().any()
# Out:
# amenities        False
# usableAreas      False
# description      False
# title            False
# unitTypes        False
# id               False
# parkingSpaces    False
# address          False
# suites           False
# externalId       False
# bathrooms        False
# usageTypes       False
# bedrooms         False
# pricingInfos     False
# neighborhood     False
# lat               True
# lon               True
# condoFee         False
# rentPrice        False
# iptu             False
# dtype: bool

# %% [markdown]
# Por fim, a coluna de latitude e longitude possuem valores `NaN`. Isso se deve ao fato de que nem todos os imóveis possuiam o endereço de forma mais precisa, contudo. Por ora, vamos preencher os valores faltantes com a latitude e longitude de Fortaleza. Entretanto, essa estratégia não é a ideal, e o melhor é tentar aproximar a latitude e longitude por bairro, cep e nome da rua, possivelmente utilizando alguma API com essa finalidade.

# %%
print(f"Quantidade de latitudes NaN: {len(rents_df[rents_df['lat'].isna()])}")
print(f"Quantidade de longitudes NaN: {len(rents_df[rents_df['lon'].isna()])}")
# Out:
# Quantidade de latitudes NaN: 2560
# Quantidade de longitudes NaN: 2560

# %%
rents_df["lat"] = rents_df["lat"].fillna(-3.7304512)
rents_df["lon"] = rents_df["lon"].fillna(-38.5217989)
rents_df.isna().any()
# Out:
# /tmp/ipykernel_132952/599436173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rents_df["lat"] = rents_df["lat"].fillna(-3.7304512)
# /tmp/ipykernel_132952/599436173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rents_df["lon"] = rents_df["lon"].fillna(-38.5217989)
# amenities        False
# usableAreas      False
# description      False
# title            False
# unitTypes        False
# id               False
# parkingSpaces    False
# address          False
# suites           False
# externalId       False
# bathrooms        False
# usageTypes       False
# bedrooms         False
# pricingInfos     False
# neighborhood     False
# lat              False
# lon              False
# condoFee         False
# rentPrice        False
# iptu             False
# dtype: bool

# %% [markdown]
# ### Remoção de colunas intermediárias

# %% [markdown]
# Como as colunas `id` e `externalId` já foram usadas para identificar linhas duplicadas, e as colunas `pricingInfos` e `address` foram usadas para extrair o preço e endereço dos imóveis, podemos removê-las do *dataframe*. Por ora, vamos manter a coluna `title` e `description`, pois elas podem prover informações úteis para análises adicionais.

# %%
rents_df = rents_df.drop(columns=["id", "externalId", "pricingInfos", "address"])
rents_df
# Out:
#                                             amenities  usableAreas  \
# 0   [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1   [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                       [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                  []         33.0
# 4                                                  []         30.0
# ..                                                ...          ...
# 83                  [KITCHEN, BACKYARD, SERVICE_AREA]        594.0
# 84                                                 []        297.0
# 85                            [KITCHEN, SERVICE_AREA]        200.0
# 34  [BARBECUE_GRILL, GARDEN, POOL, PLAYGROUND, ELE...         54.0
# 54  [POOL, FURNISHED, BARBECUE_GRILL, GATED_COMMUN...         68.0
#
#                                           description  \
# 0   IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1   Apartamento Duplex 60 m2, com 02 suítes, total...
# 2   ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3   Salas com piso em porcelanato bianco, com forr...
# 4   COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
# ..                                                ...
# 83  Casa residencial ou comercial com 594 m², loca...
# 84
# 85  Casa comercial duplex de esquina com 6 ambient...
# 34  Primeira Locação, valor já com condomínio. Apa...
# 54  LOCAÇÃO RESIDENCIAL<br><br>MEIRELES<br>CONDOMÍ...
#
#                                                 title            unitTypes  \
# 0   Apartamento para aluguel tem 70 metros quadrad...            APARTMENT
# 1   Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...            APARTMENT
# 2   Sala comercial, localização INENARRÁVEL / para...               OFFICE
# 3      Scopa Platinum Corporate - Salas amplas com WC               OFFICE
# 4   COMPSA - Compartilhamento de Salas - Hora, Exp...               OFFICE
# ..                                                ...                  ...
# 83          Casa para alugar com 594 m² no Vila Velha                 HOME
# 84                                    Ponto Comercial             BUSINESS
# 85    Casa comercial duplex, no bairro Conjunto Ceará  COMMERCIAL_PROPERTY
# 34  Apartamento de 54 metros quadrados no bairro P...            APARTMENT
# 54                                      Cond. CHRONUS            APARTMENT
#
#     parkingSpaces  suites  bathrooms   usageTypes  bedrooms  \
# 0             2.0     2.0        2.0  RESIDENTIAL       2.0
# 1             1.0     2.0        2.0  RESIDENTIAL       2.0
# 2             0.0     0.0        0.0   COMMERCIAL       0.0
# 3             1.0     0.0        0.0   COMMERCIAL       0.0
# 4             0.0     0.0        0.0   COMMERCIAL       0.0
# ..            ...     ...        ...          ...       ...
# 83           12.0     2.0        2.0  RESIDENTIAL       5.0
# 84            0.0     0.0        0.0   COMMERCIAL       0.0
# 85            2.0     3.0        3.0   COMMERCIAL       6.0
# 34            2.0     1.0        1.0  RESIDENTIAL       2.0
# 54            2.0     1.0        1.0  RESIDENTIAL       2.0
#
#              neighborhood       lat        lon condoFee rentPrice  iptu
# 0                Meireles -3.727880 -38.495875      730      2700   110
# 1                Meireles -3.727192 -38.490351      800      2500   200
# 2                Meireles -3.736109 -38.490084      575      2500   330
# 3                 Aldeota -3.733264 -38.509330      428      1750  1143
# 4                 Aldeota -3.743591 -38.493051        0       500     0
# ..                    ...       ...        ...      ...       ...   ...
# 83             Vila Velha -3.722138 -38.595065        0      5000     0
# 84     Parque Santa Maria -3.730451 -38.521799        0      1700     0
# 85      Conjunto Ceará II -3.730451 -38.521799        0     10500     0
# 34  Planalto Ayrton Senna -3.833893 -38.567802      275       700   250
# 54               Meireles -3.725501 -38.500486      617      2500     0
#
# [7492 rows x 16 columns]

# %% [markdown]
# ## Salvando *dataset* final

# %% [markdown]
# Uma vez que realizamos todos os devidos tratamentos nos dados, podemos salvar nosso *dataframe*  em um csv. Para isso, utilizamos o método `to_csv` do *dataframe*. A coluna `usageTypes` indica qual o tipo de uso para o imóvel, que pode ser comercial ou residencial. Com base nisso, vamos gerar dois *datasets*, um com todos os imóveis, e outro apenas com os imóveis residenciais.

# %%
rents_df.head()
# Out:
#                                            amenities  usableAreas  \
# 0  [ELEVATOR, GATED_COMMUNITY, GARDEN, PLAYGROUND...         70.0
# 1  [FURNISHED, BARBECUE_GRILL, ELEVATOR, GATED_CO...         60.0
# 2                      [AIR_CONDITIONING, PORCELAIN]         35.0
# 3                                                 []         33.0
# 4                                                 []         30.0
#
#                                          description  \
# 0  IMÓVEL IMPECÁVEL! L I N D A V I S T A M A R! <...
# 1  Apartamento Duplex 60 m2, com 02 suítes, total...
# 2  ANDAR ALTO;<br>PISO EM PORCELANATO;<br>ILUMINA...
# 3  Salas com piso em porcelanato bianco, com forr...
# 4  COMPSA – COMPARTILHAMENTO DE SALAS: <br>I. MOB...
#
#                                                title  unitTypes  \
# 0  Apartamento para aluguel tem 70 metros quadrad...  APARTMENT
# 1  Apartamento DUPLEX MOBILIADO, 02 suítes, em Me...  APARTMENT
# 2  Sala comercial, localização INENARRÁVEL / para...     OFFICE
# 3     Scopa Platinum Corporate - Salas amplas com WC     OFFICE
# 4  COMPSA - Compartilhamento de Salas - Hora, Exp...     OFFICE
#
#    parkingSpaces  suites  bathrooms   usageTypes  bedrooms neighborhood  \
# 0            2.0     2.0        2.0  RESIDENTIAL       2.0     Meireles
# 1            1.0     2.0        2.0  RESIDENTIAL       2.0     Meireles
# 2            0.0     0.0        0.0   COMMERCIAL       0.0     Meireles
# 3            1.0     0.0        0.0   COMMERCIAL       0.0      Aldeota
# 4            0.0     0.0        0.0   COMMERCIAL       0.0      Aldeota
#
#         lat        lon condoFee rentPrice  iptu
# 0 -3.727880 -38.495875      730      2700   110
# 1 -3.727192 -38.490351      800      2500   200
# 2 -3.736109 -38.490084      575      2500   330
# 3 -3.733264 -38.509330      428      1750  1143
# 4 -3.743591 -38.493051        0       500     0

# %%
full_df = rents_df
residential_df = rents_df[rents_df["usageTypes"] == "RESIDENTIAL"]

full_df.to_csv(BASE_PATH + "/full_rents.csv")
residential_df.to_csv(BASE_PATH + "/residential.csv")
